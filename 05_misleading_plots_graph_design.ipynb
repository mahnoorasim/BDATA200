# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 40px 30px; border-radius: 15px; box-shadow: 0 8px 20px rgba(75,46,131,0.3);">
#   <img src="https://uw-s3-cdn.s3.us-west-2.amazonaws.com/wp-content/uploads/sites/230/2023/11/02134828/Signature_Left_Gold_RGB.png" alt="University of Washington" style="height: 80px; margin-bottom: 20px;">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; font-size: 2.8em; margin: 20px 0 15px 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Misleading Plots &amp; Graph Design</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">BDATA 200 Introduction to Data Studies</p>
#   <p style="color: #B7A6D5; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.1em; margin: 5px 0;">University of Washington</p>
# </div>
#
# <div style="background-color: #F5F5F5; padding: 15px 25px; border-left: 5px solid #4B2E83; border-radius: 5px; margin-top: 25px;">
#   <p style="font-size: 1.1em; color: #333; margin: 0;">
#     <strong style="color: #4B2E83;">Open in Google Colab:</strong>
#   </p>
#   <p style="margin: 10px 0 5px 0;">
#     <a target="_blank" href="https://colab.research.google.com/github/PedroBSB/BDATA200/blob/main/05_misleading_plots_graph_design.ipynb">
#       <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="vertical-align: middle;"/>
#     </a>
#   </p>
# </div>
#
# <div style="background: linear-gradient(to right, #FFF8E1, #FFFEF7); padding: 20px 25px; border-radius: 10px; border: 2px solid #E8B923; margin: 30px 0;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0; font-size: 1.3em;">Student Information</h3>
#   <div style="background-color: white; padding: 15px; border-radius: 5px; margin-top: 15px;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;">
#       <strong style="color: #4B2E83;">Name:</strong> <span style="color: #666;">[Enter your name]</span>
#     </p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;">
#       <strong style="color: #4B2E83;">Student ID:</strong> <span style="color: #666;">[Enter your student ID]</span>
#     </p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;">
#       <strong style="color: #4B2E83;">Date:</strong> <span style="color: #666;">[Enter date]</span>
#     </p>
#   </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #F7F4FB, #FFFFFF); padding: 25px; border-radius: 10px; border: 2px solid #E8E0F5; margin: 25px 0;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; border-bottom: 3px solid #4B2E83; padding-bottom: 10px;">Table of Contents</h2>
#   <ul style="font-size: 1.05em; line-height: 2; color: #333; list-style-type: none; padding-left: 0;">
#     <li><strong>Part 1: Best Practices for Building Graphs</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Choosing the Correct Chart Type</li>
#         <li>Titles, Labels, Legends &amp; Annotations</li>
#         <li>Reducing Clutter &amp; Chartjunk</li>
#         <li>Storytelling with Graphs</li>
#         <li>Exercise 1 — Fix a Cluttered Bar Chart</li>
#         <li>Exercise 2 — Redesign a Bad Multi-Series Plot</li>
#         <li>Exercise 3 — From Chartjunk to Storytelling</li>
#       </ul>
#     </li>
#     <li><strong>Part 2: Color Accessibility &amp; Colorblind-Safe Palettes</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Why Accessibility Matters</li>
#         <li>Common Forms of Color Blindness</li>
#         <li>Colorblind-Safe Palettes &amp; Tools</li>
#         <li>Importing Custom Palettes into Python</li>
#         <li>Exercise 4 — Fix a Red-Green Chart</li>
#         <li>Exercise 5 — Choose Colorblind-Safe Palettes for a Dashboard</li>
#         <li>Exercise 6 — Grayscale Readability Test</li>
#       </ul>
#     </li>
#     <li><strong>Part 3: Color Theory for Data Visualization</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Hue, Saturation &amp; Brightness</li>
#         <li>Categorical, Sequential &amp; Diverging Palettes</li>
#         <li>The 70-20-10 Color Rule</li>
#         <li>Visual Hierarchy &amp; Emphasis</li>
#         <li>Exercise 7 — Apply 70-20-10 to a Bar Chart</li>
#         <li>Exercise 8 — Dashboard Color Consistency</li>
#         <li>Exercise 9 — Highlight the Anomaly</li>
#       </ul>
#     </li>
#     <li><strong>Part 4: Common Misleading Graph Types</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Truncated Axes &amp; Manipulated Scales</li>
#         <li>Cherry-Picked Data &amp; Dual-Axis Deception</li>
#         <li>3D Distortion &amp; Area Exaggeration</li>
#         <li>Overloaded Pie Charts &amp; Unequal Bins</li>
#         <li>Exercise 10 — Detect and Fix Truncated Axes</li>
#         <li>Exercise 11 — Cherry-Picked Data &amp; Dual Axis</li>
#         <li>Exercise 12 — Unequal Bins &amp; 3D Distortion</li>
#       </ul>
#     </li>
#     <li><strong>Part 5: Detecting Statistical Deception</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Missing Sample Size &amp; Uncertainty</li>
#         <li>Mean vs Median Distortion</li>
#         <li>Relative vs Absolute Change</li>
#         <li>Correlation vs Causation</li>
#         <li>Survivorship Bias &amp; Selective Filtering</li>
#         <li>Exercise 13 — Relative vs Absolute: Spot the Deception</li>
#         <li>Exercise 14 — Mean vs Median: Salary Deception</li>
#         <li>Exercise 15 — Correlation vs Causation: The Full Story</li>
#       </ul>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color: #E8D3FF; border-left: 4px solid #4B2E83; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <p style="margin: 0; color: #4B2E83; font-weight: 600;">Setup:</p>
#   <p style="margin: 10px 0 0 0; color: #333;">Run the cell below to import all required libraries and set the visual style used throughout this notebook.</p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mticker
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import warnings
warnings.filterwarnings('ignore')

# Set a consistent style matching the course palette
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['axes.prop_cycle'] = plt.cycler(
    color=['#4B2E83', '#E8B923', '#32006E', '#85714D', '#B7A6D5',
           '#C62828', '#1976D2', '#F57C00', '#388E3C', '#7B1FA2'])
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['font.size'] = 12

np.random.seed(42)
print('Setup complete \u2713')

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Section 1: Best Practices for Building Graphs</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">From Chartjunk to Clear, Honest, Compelling Visualisations</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #F7F4FB, #FFFFFF); padding: 25px; border-radius: 10px; border: 2px solid #E8E0F5; margin: 25px 0;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; border-bottom: 3px solid #4B2E83; padding-bottom: 10px;">Learning Objectives</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7; margin-bottom: 10px;">By the end of this section you will be able to:</p>
#   <ul style="font-size: 1.05em; color: #333; line-height: 2;">
#     <li>Select the <strong>appropriate chart type</strong> for a given data structure and analytical question.</li>
#     <li>Write <strong>clear, informative titles, subtitles, axis labels, and units</strong>.</li>
#     <li>Apply <strong>legend and direct-label</strong> strategies to reduce cognitive load.</li>
#     <li>Order categories <strong>meaningfully</strong> (by value, time, or natural order) rather than arbitrarily.</li>
#     <li>Identify and eliminate <strong>chartjunk</strong> — decorative noise that obscures data.</li>
#     <li>Make deliberate decisions about <strong>white space and aspect ratio</strong>.</li>
#     <li>Use <strong>annotations</strong> to highlight the single most important insight.</li>
#     <li>Craft a graph that tells a <strong>data story</strong> with a clear message.</li>
#     <li>Use an LLM as a <strong>coding and critique partner</strong> in the visualisation workflow.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Choosing the Right Chart Type</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Every chart type answers a different question. Matching the chart to the question is the single most important decision you make as a data visualiser. Choosing wrong — e.g., a pie chart for trend data — can actively mislead readers.</p>
# </div>
#
# | Chart Type | Best For | Avoid When |
# |:-----------|:---------|:-----------|
# | **Bar chart** | Comparing discrete categories | You have more than ~15 categories |
# | **Horizontal bar** | Long category labels; ranking | Showing change over time |
# | **Line chart** | Trends over a continuous axis (time, temperature) | Data points are not connected logically |
# | **Scatter plot** | Relationship / correlation between two numeric variables | One variable is categorical |
# | **Histogram** | Distribution of a single numeric variable | You want to compare across groups (use boxplot instead) |
# | **Box plot** | Distribution comparison across groups; spotting outliers | Your audience is unfamiliar with the chart |
# | **Pie / donut** | Part-of-whole with **≤ 5** clearly different slices | You have many categories or need precision |
# | **Heatmap** | Matrix-shaped relationships (correlation, confusion matrix) | The matrix is too sparse |
#
# > **Rule of thumb:** if you cannot state in one sentence what question your chart answers, redesign it.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Readable Titles and Subtitles</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">A title should answer <strong>"what is the main finding?"</strong> — not just label the data. Compare these two titles for the same chart:</p>
#   <ul style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li style="color: #C62828;"><strong>Weak:</strong> &ldquo;Sales Data 2023&rdquo; — describes the data, not the insight.</li>
#     <li style="color: #388E3C;"><strong>Strong:</strong> &ldquo;Q4 Online Sales Surged 38% Above the Annual Average&rdquo; — states the finding.</li>
#   </ul>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7; margin-top: 12px;">Use a <strong>subtitle</strong> (smaller, lighter text below the title) to provide context: data source, time period, unit of measurement, or a brief caveat. In matplotlib use <code>fig.suptitle()</code> for the main title and <code>ax.set_title()</code> for a panel subtitle, or compose both with <code>ax.set_title()</code> and an annotation.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Axis Labels and Units</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Every axis that carries quantitative information <strong>must be labelled with the variable name and its unit</strong>. Omitting units is one of the most common and costly mistakes in data communication. A reader who sees &ldquo;47&rdquo; on a y-axis cannot know whether that means dollars, thousands of dollars, kilograms, or minutes.</p>
#   <ul style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li>Use plain language: <code>Revenue (USD millions)</code> not <code>rev_usd_m</code>.</li>
#     <li>Keep axis tick labels horizontal wherever possible — rotate only when unavoidable, and never past 45°.</li>
#     <li>Do not truncate the y-axis to exaggerate differences unless you explicitly note the broken axis.</li>
#     <li>Match the scale to the data: avoid vast empty white space at the top of a bar chart.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Legends and Direct Labels</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">A <strong>legend</strong> forces the reader's eye to shuttle back and forth between the chart and the key — each trip costs attention. Wherever space allows, prefer <strong>direct labels</strong>: place the series name next to the line or bar at the last data point.</p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Guidelines:</p>
#   <ul style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li>With <strong>2–3 series</strong>: always try direct labels.</li>
#     <li>With <strong>4–6 series</strong>: use a legend positioned outside the plot area so it does not overlap data.</li>
#     <li>With <strong>7+ series</strong>: reconsider the chart design — you likely need to facet, highlight, or aggregate.</li>
#     <li>Never rely on colour alone to distinguish categories; also vary line style, marker shape, or use direct labels for accessibility.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Ordering Categories</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Alphabetical order is almost never the right choice for a bar chart. The human eye reads ranking effortlessly when bars are sorted, but must actively search when they are not.</p>
#   <ul style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li><strong>Ranked data</strong> (sales, scores, counts): sort descending so the largest value is first.</li>
#     <li><strong>Time data</strong>: always sort chronologically — never alphabetically.</li>
#     <li><strong>Ordinal data</strong> (Low / Medium / High): preserve the natural order.</li>
#     <li><strong>Geographic data</strong>: group by region or sort by value — not alphabetically by country name.</li>
#   </ul>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">In pandas/matplotlib: <code>df.sort_values('value', ascending=False)</code> before plotting, or pass <code>order=</code> to seaborn.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Reducing Clutter — Avoiding Chartjunk</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Edward Tufte coined the term <strong>chartjunk</strong> for visual elements that consume ink without conveying information. Every pixel in a chart should earn its place. Common offenders:</p>
#   <ul style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li><strong>3-D effects</strong> on 2-D data — distort proportions and add nothing.</li>
#     <li><strong>Excessive gridlines</strong> — keep only major horizontal gridlines, and make them light grey.</li>
#     <li><strong>Heavy border boxes</strong> around the plot area — remove the top and right spines (<code>ax.spines['top'].set_visible(False)</code>).</li>
#     <li><strong>Redundant legends</strong> when the chart has only one series.</li>
#     <li><strong>Gradient fills</strong> on bars — use flat, single colours.</li>
#     <li><strong>Clip-art or background images</strong> behind the data.</li>
#     <li><strong>Every bar a different colour</strong> when there is only one variable — use one colour with purposeful highlighting.</li>
#   </ul>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;"><strong>Tufte&rsquo;s data-ink ratio</strong> = (ink used for data) / (total ink). Maximise it.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">White Space and Aspect Ratio</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">White space is not wasted space — it is <strong>breathing room</strong> that guides the eye and reduces fatigue.</p>
#   <ul style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li>Use <code>plt.tight_layout()</code> or <code>fig.subplots_adjust()</code> to prevent labels from being clipped.</li>
#     <li>Avoid cramming multiple charts into a tiny figure — prefer larger individual panels.</li>
#     <li><strong>Aspect ratio</strong> matters: a wide, shallow chart makes trends look flat; a tall, narrow chart exaggerates slopes. The classic guidance (Cleveland, 1993) is to <strong>bank to 45°</strong> — choose width and height so that the dominant line segments average about 45° from horizontal. For most bar charts, a 4:3 or 16:9 ratio works well.</li>
#     <li>Add <strong>padding between bar groups</strong> (<code>width=0.6</code>) so bars do not touch.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Annotation Best Practices</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Annotations are directed attention — they say <em>"look here."</em> Used sparingly, they are powerful. Used indiscriminately, they become noise.</p>
#   <ul style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li>Annotate <strong>one to three</strong> key points at most — the peak, an anomaly, or the policy-change date.</li>
#     <li>Use a short, plain-language label: <em>"COVID lockdown begins"</em> not <em>"Event X."</em></li>
#     <li>Place annotations so they do not overlap data or each other — use <code>ax.annotate()</code> with <code>arrowprops</code> to point at a data point from a clear area.</li>
#     <li>Match annotation font size to the chart hierarchy: smaller than the title, similar to or slightly smaller than axis labels.</li>
#     <li>Avoid boxing every data value — data labels on all bars become clutter unless precision is essential.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Storytelling with Graphs</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Data visualisation is a communication act. Before you open a code editor, answer three questions:</p>
#   <ol style="color: #333; line-height: 1.9; font-size: 1.05em;">
#     <li><strong>Who is the audience?</strong> A subject-matter expert can handle more complexity than a general public audience.</li>
#     <li><strong>What is the single main message?</strong> If you cannot state it in one sentence, you are not ready to plot.</li>
#     <li><strong>What action or decision should the chart enable?</strong> Visualisations exist to help people do something — decide, investigate, or understand.</li>
#   </ol>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Encode the main message visually: highlight the key bar in a contrasting colour while muting all others, draw a reference line at a target value, or use a sequential palette where darker means more. The chart itself should whisper the conclusion before the reader reads a single word.</p>
# </div>

# %% [markdown]
# ---
# ## Demonstration: Bad vs Good — Annotated Examples
#
# The following cells show **intentionally poor** visualisations alongside instructor commentary, then **professional corrected versions**. Study the differences carefully.

# %% [markdown]
# <div style="background-color: #FFEBEE; border-left: 5px solid #C62828; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Bad Example 1 — Overloaded Pie Chart</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;"><strong>What the data shows:</strong> Monthly unit sales for a retail store across 12 months.</p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;"><strong>Why this visualisation fails:</strong></p>
#   <ul style="color: #333; line-height: 1.8; font-size: 1.05em;">
#     <li>A pie chart with <strong>12 slices</strong> is unreadable — humans cannot accurately judge angles between similar-sized slices.</li>
#     <li>There are <strong>no labels</strong> on the slices, forcing the reader to match tiny colour swatches to a legend.</li>
#     <li>The <strong>rainbow colour palette</strong> has no semantic meaning and creates visual chaos.</li>
#     <li>Pie charts communicate <strong>part-of-whole</strong> relationships, but the real question here is <em>trend over time</em> — a fundamentally different question that a pie chart cannot answer.</li>
#     <li>No title, no data source, no units.</li>
#   </ul>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- BAD EXAMPLE 1: Overloaded pie chart ---
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = [4200, 3800, 5100, 5600, 6200, 7100,
         7800, 7400, 6300, 5900, 6800, 8500]

# Garish rainbow colours
bad_colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00',
              '#00FFFF', '#0000FF', '#8B00FF', '#FF00FF',
              '#FF1493', '#00FA9A', '#FF4500', '#1E90FF']

fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sales, colors=bad_colors)  # no labels, no percentages, no title
plt.show()

# %% [markdown]
# <div style="background-color: #E8F5E9; border-left: 5px solid #388E3C; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #388E3C; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Corrected Version 1 — Horizontal Bar Chart (Ranked)</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;"><strong>Improvements made:</strong></p>
#   <ul style="color: #333; line-height: 1.8; font-size: 1.05em;">
#     <li>Switched to a <strong>horizontal bar chart</strong> — bar lengths are far easier to compare than angles.</li>
#     <li>Bars are <strong>sorted by value</strong> (descending) so ranking is immediately visible.</li>
#     <li>A <strong>single colour</strong> is used for all bars, with the peak month (December) highlighted in gold to draw the eye to the main finding.</li>
#     <li>Clear <strong>title stating the insight</strong>, labelled axes with units, and a data-source note.</li>
#     <li>Top and right spines removed; gridlines are light and minimal.</li>
#   </ul>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# --- CORRECTED EXAMPLE 1: Horizontal bar chart, sorted, minimal ---
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales = [4200, 3800, 5100, 5600, 6200, 7100,
         7800, 7400, 6300, 5900, 6800, 8500]

df = pd.DataFrame({'month': months, 'sales': sales})
df = df.sort_values('sales', ascending=True)  # ascending for horizontal (largest at top)

# Highlight the peak month
colors = ['#E8B923' if m == 'Dec' else '#4B2E83' for m in df['month']]

fig, ax = plt.subplots(figsize=(9, 6))
bars = ax.barh(df['month'], df['sales'], color=colors, height=0.6)

# Minimal value labels only on the highlighted bar
for bar, month in zip(bars, df['month']):
    if month == 'Dec':
        ax.text(bar.get_width() + 80, bar.get_y() + bar.get_height() / 2,
                f"{int(bar.get_width()):,} units",
                va='center', fontsize=10, color='#E8B923', fontweight='bold')

# Titles and labels
ax.set_title('December Led Annual Sales with 8,500 Units Sold',
             fontsize=13, color='#4B2E83', fontweight='bold', pad=14)
ax.set_xlabel('Units Sold', fontsize=11, color='#333')
ax.set_ylabel('Month', fontsize=11, color='#333')

# Remove chartjunk
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.grid(True, color='#DDDDDD', linewidth=0.8)
ax.set_axisbelow(True)

fig.text(0.99, -0.01, 'Source: Retail store internal data, 2023',
         ha='right', fontsize=8, color='#888')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #FFEBEE; border-left: 5px solid #C62828; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Bad Example 2 — 3-D Bar Chart with Maximum Chartjunk</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;"><strong>What the data shows:</strong> Average final exam scores by academic department.</p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;"><strong>Why this visualisation fails:</strong></p>
#   <ul style="color: #333; line-height: 1.8; font-size: 1.05em;">
#     <li>The <strong>3-D perspective</strong> distorts bar heights — the back bars appear shorter than they are.</li>
#     <li><strong>Every bar is a different colour</strong> even though there is only one variable (department), implying a categorical distinction that does not exist.</li>
#     <li><strong>Dense, dark gridlines</strong> on every grid unit compete with the bars for attention.</li>
#     <li>The <strong>y-axis has no label</strong> — the reader cannot know the unit.</li>
#     <li>Departments are in <strong>random order</strong>, making comparison unnecessarily difficult.</li>
#     <li>The <strong>x-axis labels are rotated 90°</strong>, forcing the reader to tilt their head.</li>
#   </ul>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# --- BAD EXAMPLE 2: 3-D bar chart, excessive gridlines, random order ---
departments = ['Physics', 'History', 'Nursing', 'CS', 'Business',
               'Art', 'Law', 'Biology']
scores = [72, 68, 81, 76, 70, 65, 79, 74]  # random order, not sorted

bad_colors = ['#FF0000', '#00BB00', '#0000FF', '#FF00FF',
              '#FF8800', '#00CCCC', '#AA00AA', '#888800']

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

xpos = np.arange(len(departments))
ypos = np.zeros(len(departments))
zpos = np.zeros(len(departments))
dx = dy = 0.6
dz = scores

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color=bad_colors, shade=True)
ax.set_xticks(xpos + 0.3)
ax.set_xticklabels(departments, rotation=90, fontsize=8)
# No y-axis label, no title, gridlines default (very heavy in 3D)
plt.show()

# %% [markdown]
# <div style="background-color: #E8F5E9; border-left: 5px solid #388E3C; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #388E3C; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Corrected Version 2 — Clean Vertical Bar Chart with Sorted Categories</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;"><strong>Improvements made:</strong></p>
#   <ul style="color: #333; line-height: 1.8; font-size: 1.05em;">
#     <li><strong>2-D flat bars</strong> — no perspective distortion.</li>
#     <li>Departments are <strong>sorted by score (descending)</strong> so ranking is immediately clear.</li>
#     <li><strong>Single colour palette</strong> for all bars; the highest-scoring department is highlighted in gold.</li>
#     <li>Both axes are fully labelled with units. A <strong>reference line</strong> at the class average draws attention to which departments are above and below average.</li>
#     <li>Gridlines are light and horizontal only; top and right spines removed.</li>
#     <li>X-axis labels at 30° — readable without head-tilting.</li>
#   </ul>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# --- CORRECTED EXAMPLE 2: Clean 2-D sorted bar chart with reference line ---
departments = ['Physics', 'History', 'Nursing', 'CS', 'Business',
               'Art', 'Law', 'Biology']
scores = [72, 68, 81, 76, 70, 65, 79, 74]

df = pd.DataFrame({'department': departments, 'avg_score': scores})
df = df.sort_values('avg_score', ascending=False).reset_index(drop=True)

class_avg = df['avg_score'].mean()

colors = ['#E8B923' if row['department'] == 'Nursing' else '#4B2E83'
          for _, row in df.iterrows()]

fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(df['department'], df['avg_score'], color=colors, width=0.6)

# Reference line at class average
ax.axhline(class_avg, color='#C62828', linewidth=1.4, linestyle='--')
ax.text(len(df) - 0.5, class_avg + 0.4, f'Class avg: {class_avg:.1f}',
        ha='right', va='bottom', fontsize=9, color='#C62828')

# Titles and labels
ax.set_title('Nursing Achieved the Highest Average Exam Score (81 pts)',
             fontsize=13, color='#4B2E83', fontweight='bold', pad=14)
ax.set_xlabel('Academic Department', fontsize=11, color='#333')
ax.set_ylabel('Average Final Exam Score (points, 0–100)', fontsize=11, color='#333')
ax.set_ylim(55, 90)

# Minimal tick rotation
ax.set_xticklabels(df['department'], rotation=30, ha='right', fontsize=10)

# Remove chartjunk
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.grid(True, color='#DDDDDD', linewidth=0.8)
ax.set_axisbelow(True)

fig.text(0.99, -0.02, 'Source: University registrar, Spring 2024',
         ha='right', fontsize=8, color='#888')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Exercises

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 1 — Fix a Cluttered Bar Chart</h3>
# </div>
#
# <div style="background-color: #E8D3FF; border-left: 4px solid #4B2E83; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <p style="margin: 0; color: #4B2E83; font-weight: 600;">Context:</p>
#   <p style="margin: 10px 0 0 0; color: #333;">The code below generates a bar chart of quarterly revenue (in USD thousands) for five product lines. The chart has several serious problems. Your job is to identify every problem and produce a professional corrected version.</p>
# </div>
#
# **Run the cell below first to see how bad the original chart looks.**

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- BROKEN CODE — do NOT edit this cell ---
products = ['Laptops', 'Tablets', 'Monitors', 'Keyboards', 'Headphones']
revenue  = [320, 175, 210, 95, 145]  # USD thousands, Q3 2024

rainbow = ['#FF0000', '#FF8800', '#FFFF00', '#00CC00', '#0000FF']

fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(products, revenue, color=rainbow)

# Excessive gridlines on both axes
ax.xaxis.grid(True, which='both', linewidth=1.5, color='black')
ax.yaxis.grid(True, which='both', linewidth=1.5, color='black')
ax.minorticks_on()

# Rotated unreadable labels
ax.set_xticklabels(products, rotation=90, fontsize=7)

# No title, no axis labels
plt.show()

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have a bar chart of quarterly revenue by product line (USD thousands, Q3 2024).
# The current chart has these problems: rainbow colours with no semantic meaning,
# heavy black gridlines on both axes including minor ticks, x-axis labels rotated 90°,
# no chart title, and no axis labels.
#
# Please rewrite the matplotlib code to fix all of these issues following best
# practices: use a single UW purple (#4B2E83) for all bars (highlight the top bar
# in gold #E8B923), add a descriptive title stating the main insight, label both
# axes with units, remove excessive gridlines (keep only light horizontal ones),
# rotate labels to 30°, and remove the top and right spines.
# ```
#
# 🎯 **Task:**
# 1. List every design problem you can identify in the broken chart above.
# 2. In the code cell below, write a corrected version of the chart.
# 3. Use the LLM prompt above (or adapt it) to ask an AI assistant for help, then evaluate and refine its output.
# 4. Answer the reflection questions below the code cell.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# --- Data (from starter code, but processed for best practices) ---
products = ['Laptops', 'Tablets', 'Monitors', 'Keyboards', 'Headphones']
revenue  = [320, 175, 210, 95, 145]  # USD thousands, Q3 2024

df = pd.DataFrame({'product': products, 'revenue': revenue})
# Sort by revenue in descending order for better readability
df = df.sort_values('revenue', ascending=False).reset_index(drop=True)

# --- Apply UW color palette and highlight top product ---
UW_PURPLE = '#4B2E83'
UW_GOLD   = '#E8B923'

# Highlight the top product (which is now the first row after sorting)
colors = [UW_GOLD if i == 0 else UW_PURPLE for i in range(len(df))]

fig, ax = plt.subplots(figsize=(10, 6))

bars = ax.bar(df['product'], df['revenue'], color=colors, width=0.6) # Added width for padding

# Add data labels on top of each bar
for bar in bars:
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() + 5, # Add some padding above the bar
            f'${bar.get_height():,.0f}K',
            ha='center', va='bottom', fontsize=10, fontweight='bold', color=UW_PURPLE)

# Titles and labels
# Main insight: Laptops are the top performing product line
ax.set_title('Laptops Lead Q3 Revenue for Product Lines, Earning $320K',
             fontsize=14, color=UW_PURPLE, fontweight='bold', pad=15)
ax.set_xlabel('Product Line', fontsize=12, color='#333')
ax.set_ylabel('Revenue (USD thousands)', fontsize=12, color='#333')

# Remove excessive gridlines, keep only light horizontal ones
ax.xaxis.grid(False) # Remove vertical gridlines
ax.yaxis.grid(True, color='#DDDDDD', linewidth=0.8) # Keep light horizontal gridlines
ax.set_axisbelow(True) # Ensure gridlines are behind bars

# Explicitly set x-tick locations before setting labels to prevent UserWarning
ax.set_xticks(range(len(df)))
ax.set_xticklabels(df['product'], rotation=30, ha='right', fontsize=10)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adjust y-axis limit for better spacing with labels
ax.set_ylim(0, df['revenue'].max() * 1.2) # Add some space above the tallest bar

# Add source text
fig.text(0.99, -0.02, 'Source: Company internal data, Q3 2024', # Adjusted position for tight layout
         ha='right', fontsize=8, color='#888', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# *Write your written answer here.*
#
# 1. Design problems identified: Too many colors, axis not labled, grid marks over the bars, cross grid serves no purpose, no highlights.
#
# 2. Changes made in your corrected version and why: Removed the cross grid, added a proper title and label for axis, put exact values above bars, highligheted the largest value.
#
# 3. What did the LLM get right? What did you have to change or improve? The LLM got it pretty correct to the prompt. I didnt have to change much.
#
# 4. What is the single main message your corrected chart communicates?
# This plot describes the lead laptop revenues for Quarter three in 2024, with Laptops generating the largest amount of profit at about 320,000 dollars.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 2 — Redesign a Bad Multi-Series Line Plot</h3>
# </div>
#
# <div style="background-color: #E8D3FF; border-left: 4px solid #4B2E83; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <p style="margin: 0; color: #4B2E83; font-weight: 600;">Context:</p>
#   <p style="margin: 10px 0 0 0; color: #333;">The code below plots weekly website visitors (in thousands) for six product categories over 12 weeks. All six lines are rendered in the same grey colour with no markers and no legend — making it impossible to tell them apart. Your task is to redesign the chart so each series is distinguishable and the most important trend is highlighted.</p>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- BROKEN CODE — do NOT edit this cell ---
np.random.seed(7)
weeks = np.arange(1, 13)

categories = ['Electronics', 'Clothing', 'Books', 'Sports', 'Toys', 'Home']
base = [120, 85, 60, 95, 70, 110]
data = {cat: b + np.cumsum(np.random.randn(12) * 8)
        for cat, b in zip(categories, base)}

fig, ax = plt.subplots(figsize=(10, 6))
for cat, vals in data.items():
    ax.plot(weeks, vals, color='grey', linewidth=1)  # all same colour, no markers
# No legend, no title, no axis labels
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data from the starter code
weeks = np.arange(1, 13)
categories = ['Electronics', 'Clothing', 'Books', 'Sports', 'Toys', 'Home']
base = [120, 85, 60, 95, 70, 110]
data = {cat: b + np.cumsum(np.random.randn(12) * 8) for cat, b in zip(categories, base)}

# Convert to DataFrame for easier manipulation
df_visitors = pd.DataFrame(data, index=weeks)
df_visitors.index.name = 'Week'

# Calculate average visitors for each category
average_visitors = df_visitors.mean()

# Identify the category with the highest average visitors
highest_avg_category = average_visitors.idxmax()
max_avg_visitors = average_visitors.max()

# Define colors
UW_GOLD = '#E8B923' # Highlight color
LIGHT_GREY = '#CCCCCC' # Muted color
TITLE_COLOR = '#4B2E83' # From general style
AXIS_LABEL_COLOR = '#333'
GRIDLINE_COLOR = '#DDDDDD'

fig, ax = plt.subplots(figsize=(12, 7))

for cat in categories:
    if cat == highest_avg_category:
        # Highlighted category
        ax.plot(df_visitors.index, df_visitors[cat], color=UW_GOLD, linewidth=2.5,
                marker='o', markersize=7, label=cat, zorder=3)
    else:
        # Muted categories
        ax.plot(df_visitors.index, df_visitors[cat], color=LIGHT_GREY, linewidth=1,
                alpha=0.5, label=cat, zorder=1)

# Add direct labels at the rightmost data point
for cat in categories:
    last_week_visitors = df_visitors[cat].iloc[-1]
    if cat == highest_avg_category:
        ax.text(df_visitors.index[-1] + 0.2, last_week_visitors, cat,
                color=UW_GOLD, fontsize=10, fontweight='bold', va='center', ha='left')
    else:
        ax.text(df_visitors.index[-1] + 0.2, last_week_visitors, cat,
                color=AXIS_LABEL_COLOR, fontsize=9, va='center', ha='left', alpha=0.7)

# Add title and axis labels
ax.set_title(f'{highest_avg_category} Leads with Average Weekly Website Visitors of {max_avg_visitors:.1f}K',
             fontsize=14, color=TITLE_COLOR, fontweight='bold', pad=15)
ax.set_xlabel('Week', fontsize=12, color=AXIS_LABEL_COLOR)
ax.set_ylabel('Weekly Visitors (thousands)', fontsize=12, color=AXIS_LABEL_COLOR)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add light horizontal gridlines only
ax.xaxis.grid(False)
ax.yaxis.grid(True, color=GRIDLINE_COLOR, linewidth=0.8, zorder=0)

# Adjust x-axis limits to make space for labels
ax.set_xlim(df_visitors.index.min(), df_visitors.index.max() + 2)
ax.set_xticks(weeks)

# Add source text
fig.text(0.99, -0.02, 'Source: Placeholder data', # Added source
         ha='right', fontsize=8, color='#888', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have a multi-series line chart showing weekly website visitors (thousands)
# for 6 product categories over 12 weeks. All lines are currently the same grey
# colour with no markers and no legend.
#
# Please redesign the chart using these guidelines:
# - Highlight the category with the highest average visitors in gold (#E8B923)
#   with a thicker line (linewidth=2.5) and circular markers
# - Show all other categories in light grey (linewidth=1, alpha=0.5, no markers)
# - Use direct labels at the rightmost data point instead of a legend
# - Add a title that states which category leads, proper axis labels with units,
#   and remove top/right spines
# - Add a light horizontal gridline only
# ```
#
# 🎯 **Task:**
# 1. Identify all the problems with the original chart.
# 2. In the code cell below, write a redesigned version. You may use the LLM prompt above for assistance.
# 3. Choose ONE of these redesign strategies and explain your choice:
#    - **Highlight + Grey-out**: emphasise the top category, mute all others.
#    - **Small multiples (facets)**: one panel per category.
#    - **Aggregated view**: show median ± IQR band across all categories, then individual lines.
# 4. Answer the reflection questions.

# %%
# Exercise 2 — Your redesigned multi-series line chart
# Write your solution here

# %% [markdown]
# *Write your written answer here.*
#
# 1. Problems in the original chart: nothing is labeled, no title, no context, no clue where to look first.
#
# 2. Redesign strategy chosen and why: Now it has some plot points specifically pointed out for the leading trend line, which is also highlighted in yellow. there are also clear titles that give the main idea of the photo as well as proper axis labels and different product category names.
#
# 3. Which category has the highest average weekly visitors, and by how much does it lead the second-place category?
# It is the electronics category, leading by roughtly 40 thousand extra users compared to sports.
#
# 4. What is the one sentence message your redesigned chart communicates?
# This plot compares weekly visitors to websites for different categories, with electronics dominating in user counts.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 3 — From Chartjunk to Storytelling</h3>
# </div>
#
# <div style="background-color: #E8D3FF; border-left: 4px solid #4B2E83; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <p style="margin: 0; color: #4B2E83; font-weight: 600;">Context:</p>
#   <p style="margin: 10px 0 0 0; color: #333;">The chart below shows annual customer satisfaction scores (1–10 scale) for four store regions over five years. It has been constructed to maximise visual noise: 3-D bars, a gradient background, unnecessary annotations on every single bar, and a decorative border. Your task is to strip it back to its essence and tell a clear data story.</p>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# --- BROKEN CODE — do NOT edit this cell ---
np.random.seed(3)
years = [2020, 2021, 2022, 2023, 2024]
regions = ['North', 'South', 'East', 'West']

scores = {
    'North': [6.2, 6.5, 7.1, 7.8, 8.3],
    'South': [7.5, 7.3, 7.1, 6.9, 6.7],
    'East':  [5.9, 6.4, 6.8, 7.2, 7.6],
    'West':  [7.8, 7.7, 7.9, 8.0, 8.1],
}

garish_colors = ['#FF3300', '#33FF00', '#0033FF', '#FF33FF']

fig = plt.figure(figsize=(14, 9))
# Gradient background (chartjunk)
ax_bg = fig.add_axes([0, 0, 1, 1])
gradient = np.linspace(0, 1, 256).reshape(1, -1)
ax_bg.imshow(gradient, aspect='auto', cmap='YlOrRd',
             extent=[0, 1, 0, 1], alpha=0.4)
ax_bg.axis('off')

ax = fig.add_subplot(111, projection='3d')
n_years = len(years)
n_regions = len(regions)
xpos_all = []
for ri, (reg, color) in enumerate(zip(regions, garish_colors)):
    xpos = np.arange(n_years) + ri * (n_years + 1)
    xpos_all.append(xpos)
    ax.bar3d(xpos, np.zeros(n_years), np.zeros(n_years),
             0.8, 0.5, scores[reg], color=color, shade=True)
    # Annotation on EVERY bar
    for x, s in zip(xpos, scores[reg]):
        ax.text(x + 0.4, 0.6, s + 0.1, f'{s}', fontsize=6, ha='center')

# Decorative border
for spine in ax.spines.values() if hasattr(ax, 'spines') else []:
    spine.set_linewidth(3)

ax.set_title('CUSTOMER SATISFACTION !!! SCORES BY REGION AND YEAR !!!',
             fontsize=10, color='red', fontstyle='italic')
plt.show()

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have data on annual customer satisfaction scores (scale 1–10) for four store
# regions (North, South, East, West) from 2020 to 2024. The current chart is a
# 3-D bar chart with a gradient background, a different garish colour for each
# region, annotations on every single bar, and an all-caps red italic title.
#
# Please redesign this as a clean 2-D line chart that tells a clear story:
# - The North region has the most interesting trend (steadily rising from 6.2 to 8.3)
# - The South region is declining (7.5 down to 6.7) — highlight both with
#   contrasting colours (#4B2E83 for North, #C62828 for South)
# - Show East and West as muted grey lines (alpha=0.4)
# - Add direct end-point labels for all four regions
# - Use a title that states the diverging trend: North climbing while South slides
# - Add one annotation for each of North and South at their 2024 values
# - Label both axes properly; remove top/right spines; use only light horizontal gridlines
# - Add a footer with data source
# ```
#
# 🎯 **Task:**
# 1. Run the broken code cell and list every chartjunk element you can identify.
# 2. Before writing any code, write a one-sentence story for this chart (what should the reader walk away understanding?).
# 3. In the code cell below, implement the redesigned chart. Use the LLM prompt for assistance.
# 4. Answer the reflection questions below.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data from the original problem description
years = [2020, 2021, 2022, 2023, 2024]
regions = ['North', 'South', 'East', 'West']
scores = {
    'North': [6.2, 6.5, 7.1, 7.8, 8.3],
    'South': [7.5, 7.3, 7.1, 6.9, 6.7],
    'East':  [5.9, 6.4, 6.8, 7.2, 7.6],
    'West':  [7.8, 7.7, 7.9, 8.0, 8.1],
}

# Convert to DataFrame for easier plotting
df_scores = pd.DataFrame(scores, index=years)
df_scores.index.name = 'Year'

# Define colors as per instructions
NORTH_COLOR = '#4B2E83'
SOUTH_COLOR = '#C62828'
MUTED_GREY = '#CCCCCC'

fig, ax = plt.subplots(figsize=(10, 6))

# Plot each region's scores
for region in regions:
    if region == 'North':
        ax.plot(df_scores.index, df_scores[region], color=NORTH_COLOR, linewidth=2.5, marker='o', label=region, zorder=3)
    elif region == 'South':
        ax.plot(df_scores.index, df_scores[region], color=SOUTH_COLOR, linewidth=2.5, marker='s', label=region, zorder=3)
    else:
        ax.plot(df_scores.index, df_scores[region], color=MUTED_GREY, linewidth=1.5, alpha=0.4, label=region, zorder=1)

# Add direct end-point labels for all four regions
for region in regions:
    last_year_score = df_scores[region].iloc[-1]
    if region == 'North':
        ax.text(df_scores.index[-1] + 0.1, last_year_score, region, color=NORTH_COLOR, fontsize=10, fontweight='bold', va='center', ha='left')
        ax.text(df_scores.index[-1] + 0.1, last_year_score - 0.25, f'({last_year_score})', color=NORTH_COLOR, fontsize=9, ha='left')
    elif region == 'South':
        ax.text(df_scores.index[-1] + 0.1, last_year_score, region, color=SOUTH_COLOR, fontsize=10, fontweight='bold', va='center', ha='left')
        ax.text(df_scores.index[-1] + 0.1, last_year_score - 0.25, f'({last_year_score})', color=SOUTH_COLOR, fontsize=9, ha='left')
    else:
        ax.text(df_scores.index[-1] + 0.1, last_year_score, region, color=MUTED_GREY, fontsize=10, va='center', ha='left', alpha=0.8)

# Title and labels
ax.set_title('North Region Customer Satisfaction Climbing While South Slides',
             fontsize=14, color='#4B2E83', fontweight='bold', pad=15)
ax.set_xlabel('Year', fontsize=12, color='#333')
ax.set_ylabel('Customer Satisfaction Score (1-10)', fontsize=12, color='#333')

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add light horizontal gridlines only
ax.xaxis.grid(False) # Ensure no vertical gridlines
ax.yaxis.grid(True, color='#DDDDDD', linewidth=0.8, zorder=0)

# Set x-ticks to show all years
ax.set_xticks(years)
ax.set_xlim(min(years) - 0.5, max(years) + 0.7) # Adjust x-axis limits for labels

# Add a footer with data source
fig.text(0.99, -0.02, 'Source: Simulated customer satisfaction data',
         ha='right', fontsize=8, color='#888', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# *Write your written answer here.*
#
# 1. Chartjunk elements identified in the original chart: Neon colors, unlabled axis, 3d shape adds nothing important to visualizing the data, no title, bars are covered by other 3d prisms.
#
# 2. One-sentence story for your redesigned chart:This chart compares regional customer satisfaction, with customers in the northern region generally the most saisfied with the service.
#
# 3. Which regions are improving and which are declining? What might explain the South region's downward trend?
# The north is generally improving along with the east if you compare recent rating data. Maybe this service is catering more towards the needs of eastern and northern users?
#
# 4. What design choices did you make to guide the reader's eye to the main message?
# Highlighting the highs and lows and providing actual rates for them helps to draw in the redears attention to whats important.
# 5. How did the LLM prompt help? What did you still need to adjust manually?
# I had to adjust a couple visuals it messed up on, where it added arrows to point to the highest and lowest customer satisfaction ratings, but in the process obstructed the title view and made it harder to read.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Section 2: Color Accessibility and Colorblind-Safe Palettes</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Designing visualizations that work for everyone</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #F7F4FB, #FFFFFF); padding: 25px; border-radius: 10px; border: 2px solid #E8E0F5; margin: 25px 0;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; border-bottom: 3px solid #4B2E83; padding-bottom: 10px;">Learning Objectives</h2>
#   <ul style="font-size: 1.05em; line-height: 2; color: #333;">
#     <li>Understand why color accessibility matters and who is affected by color vision deficiencies</li>
#     <li>Identify the most common forms of color blindness and the color combinations they affect</li>
#     <li>Recognize red/green failure modes and fix them with accessible alternatives</li>
#     <li>Evaluate a chart for grayscale readability using markers, line styles, and direct labels</li>
#     <li>Understand why rainbow (jet) colormaps are misleading and choose perceptually uniform alternatives</li>
#     <li>Apply ColorBrewer, viridis, cividis, and seaborn palettes appropriately to sequential, diverging, and categorical data</li>
#     <li>Import custom hex palettes from tools like coolors.co and colorhunt.co into Python</li>
#     <li>Apply inclusive design principles when building multi-panel dashboards</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Why Accessibility Matters</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Approximately <strong>8% of males and 0.5% of females</strong> of Northern European descent have some form of color vision deficiency (CVD). In a classroom of 30 students, there is a very good chance that 2&ndash;3 people cannot distinguish your red from your green. Globally, that is roughly 300 million people. When a chart relies solely on color to encode information, those viewers receive no information at all from that encoding channel. Accessible visualization is not a "nice to have" &mdash; it is a basic requirement for communicating with your full audience. The Web Content Accessibility Guidelines (WCAG 2.1) require a contrast ratio of at least <strong>4.5:1</strong> for normal text and <strong>3:1</strong> for large text and graphical elements. These same principles apply to data graphics.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Common Forms of Color Blindness</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Color blindness is not "seeing in black and white" &mdash; it is a shift or absence of sensitivity in one cone type. The three main types are:
#   </p>
#   <ul style="font-size: 1.05em; color: #555; line-height: 2;">
#     <li><strong>Deuteranopia / Deuteranomaly</strong> &mdash; reduced or absent green cone response (most common, ~5% of males). Red and green appear as shades of yellow-brown.</li>
#     <li><strong>Protanopia / Protanomaly</strong> &mdash; reduced or absent red cone response (~1% of males). Reds appear dark, greens look yellow-green.</li>
#     <li><strong>Tritanopia / Tritanomaly</strong> &mdash; reduced or absent blue cone response (very rare, affects both sexes equally). Blues appear green, yellows appear pink.</li>
#   </ul>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>The practical implication:</strong> red&ndash;green distinctions are the most commonly broken encoding pair in data visualization. A pie chart with a red slice and a green slice is completely ambiguous to ~8% of male viewers. Deuteranopia and protanopia together account for the vast majority of CVD cases.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Grayscale Readability and Contrast</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     A simple but powerful test is to convert your chart to grayscale (or print it on a black-and-white printer) and ask: <em>can the viewer still read every data series?</em> If two categories collapse to the same gray tone, color is doing all the work and your chart fails the test. The fix involves adding redundant encodings:
#   </p>
#   <ul style="font-size: 1.05em; color: #555; line-height: 2;">
#     <li><strong>Markers</strong> on line charts (circle, square, triangle, diamond&hellip;)</li>
#     <li><strong>Line styles</strong> (solid, dashed, dotted, dash-dot)</li>
#     <li><strong>Hatching / fill patterns</strong> on bars and areas</li>
#     <li><strong>Direct labels</strong> placed next to the last data point or bar, eliminating the need for a legend entirely</li>
#     <li><strong>Shape</strong> in scatter plots instead of relying on color alone</li>
#   </ul>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     WCAG 2.1 guideline 1.4.1 states: "Color is not used as the only visual means of conveying information, indicating an action, prompting a response, or distinguishing a visual element."
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Avoiding Rainbow (Jet) Colormaps for Numeric Data</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The <code>jet</code> (rainbow) colormap was the matplotlib default for many years and is still the default in MATLAB. It is <strong>perceptually non-uniform</strong>: equal steps in data value do not correspond to equal steps in perceived color. The green and cyan bands appear much lighter than the red and blue ends, creating false visual boundaries that do not exist in the data. In addition, jet fails for colorblind viewers and converts to a confusing non-monotonic grayscale.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The modern replacements &mdash; <strong>viridis, cividis, plasma, magma, inferno</strong> &mdash; were designed to be:
#   </p>
#   <ul style="font-size: 1.05em; color: #555; line-height: 2;">
#     <li>Perceptually uniform (equal data steps = equal perceived steps)</li>
#     <li>Monotonically increasing in lightness (converts cleanly to grayscale)</li>
#     <li>Distinguishable for the most common forms of CVD</li>
#     <li><code>cividis</code> specifically is optimized for both deuteranopia and protanopia</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">ColorBrewer and Palette Principles</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>ColorBrewer</strong> (colorbrewer2.org), developed by cartographer Cynthia Brewer, provides three families of palettes:
#   </p>
#   <ul style="font-size: 1.05em; color: #555; line-height: 2;">
#     <li><strong>Sequential</strong> &mdash; for ordered data going from low to high (e.g., population density). Use one hue that varies in lightness.</li>
#     <li><strong>Diverging</strong> &mdash; for data with a meaningful midpoint (e.g., temperature anomaly relative to 1990 baseline). Two hues meet at a neutral center.</li>
#     <li><strong>Qualitative</strong> &mdash; for categorical data with no inherent order. Maximally distinct hues at similar lightness levels.</li>
#   </ul>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Many ColorBrewer palettes are labeled as "colorblind safe" on the website. In Python, they are available via <code>matplotlib.cm</code> (e.g., <code>RdYlBu</code>, <code>BuGn</code>) and <code>seaborn</code> (e.g., <code>sns.color_palette('colorblind')</code>, <code>sns.color_palette('Set2')</code>).
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Quick palette resources:</strong>
#     <a href="https://colorhunt.co" style="color: #4B2E83;">colorhunt.co</a> and
#     <a href="https://coolors.co" style="color: #4B2E83;">coolors.co</a> let you browse and copy hex codes for custom palettes.
#     Both sites provide CVD simulation previews. Once you have hex codes, passing them directly to matplotlib or seaborn is straightforward.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Inclusive Dashboard Design Principles</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     When assembling a multi-panel dashboard, apply these principles consistently:
#   </p>
#   <ol style="font-size: 1.05em; color: #555; line-height: 2;">
#     <li><strong>Never encode information in color alone.</strong> Pair color with shape, pattern, or direct annotation.</li>
#     <li><strong>Use the same palette across all panels</strong> so that a color means the same category everywhere.</li>
#     <li><strong>Avoid more than 6&ndash;8 categorical colors.</strong> Beyond that, use facets or small multiples.</li>
#     <li><strong>Check contrast ratios</strong> between text annotations and their backgrounds using a contrast checker.</li>
#     <li><strong>Prefer direct labels over legends</strong> wherever space allows &mdash; legends add a lookup step that slows comprehension.</li>
#     <li><strong>Test with a grayscale print</strong> before publishing.</li>
#     <li><strong>Use CVD simulation tools</strong> (e.g., the <code>colorspacious</code> Python library, Coblis, or the macOS Display Accessibility filter) to preview your charts as a deuteranopic viewer sees them.</li>
#   </ol>
# </div>

# %% [markdown]
# ---
# ## Python Demonstrations
#
# The following cells walk through concrete before/after examples. Run each pair and compare the outputs side by side.

# %%
# Setup — run this cell first
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

np.random.seed(42)

plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['font.size'] = 12

print('Setup complete \u2713')
# Out:
# Setup complete ✓

# %% [markdown]
# <div style="border-left: 5px solid #C62828; background-color: #FFF8F8; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Bad Example 1 — Red/Green Line Chart (No Markers)</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     This chart uses red, green, and a similar blue-green to distinguish three product lines. It has no markers and uses thin lines. For a viewer with deuteranopia or protanopia, the red and green lines collapse to indistinguishable shades of yellow-brown. Even for typical-vision viewers, the thin lines without markers make the chart hard to read in small print or on a low-contrast screen.
#   </p>
# </div>

# %%
# ---- BAD EXAMPLE 1: red/green only, no markers, thin lines ----

months = np.arange(1, 13)
product_a = [42, 45, 50, 47, 55, 60, 58, 63, 61, 67, 71, 75]
product_b = [38, 41, 39, 44, 48, 45, 50, 52, 49, 54, 58, 60]
product_c = [30, 33, 36, 34, 40, 43, 41, 46, 44, 49, 52, 55]

fig, ax = plt.subplots(figsize=(9, 5))

# RED, GREEN, and a similar olive-green — fail for colorblind viewers
ax.plot(months, product_a, color='#D32F2F', linewidth=1.2, label='Product A')
ax.plot(months, product_b, color='#388E3C', linewidth=1.2, label='Product B')
ax.plot(months, product_c, color='#558B2F', linewidth=1.2, label='Product C')

ax.set_title('Monthly Unit Sales by Product Line', fontsize=14, fontweight='bold')
ax.set_xlabel('Month')
ax.set_ylabel('Units Sold (thousands)')
ax.legend()
ax.set_xticks(months)
ax.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun',
                    'Jul','Aug','Sep','Oct','Nov','Dec'])

plt.tight_layout()
plt.suptitle('BAD: Red/green only, no markers', y=1.01,
             color='#C62828', fontsize=11, style='italic')
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #388E3C; background-color: #F4FBF4; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #388E3C; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Corrected Example 1 — Colorblind-Safe Palette + Markers + Line Styles</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The corrected version uses three colors from a colorblind-safe subset of the <code>tab10</code> palette (blue, orange, purple), adds distinct markers and line styles, and places direct labels at the end of each line. The chart now works in grayscale and for all common forms of CVD.
#   </p>
# </div>

# %%
# ---- CORRECTED EXAMPLE 1: colorblind-safe colors + markers + line styles ----

# Colors from a CVD-safe subset: blue, orange, purple
SAFE_BLUE   = '#1976D2'
SAFE_ORANGE = '#F57C00'
SAFE_PURPLE = '#7B1FA2'

fig, ax = plt.subplots(figsize=(9, 5))

ax.plot(months, product_a, color=SAFE_BLUE,   linewidth=2.2,
        marker='o', markersize=6, linestyle='-',  label='Product A')
ax.plot(months, product_b, color=SAFE_ORANGE, linewidth=2.2,
        marker='s', markersize=6, linestyle='--', label='Product B')
ax.plot(months, product_c, color=SAFE_PURPLE, linewidth=2.2,
        marker='^', markersize=6, linestyle=':',  label='Product C')

# Direct labels at the last point — no legend needed
for series, label, color in zip(
        [product_a, product_b, product_c],
        ['Product A', 'Product B', 'Product C'],
        [SAFE_BLUE, SAFE_ORANGE, SAFE_PURPLE]):
    ax.text(12.2, series[-1], label, color=color,
            va='center', fontsize=10, fontweight='bold')

ax.set_title('Monthly Unit Sales by Product Line', fontsize=14, fontweight='bold')
ax.set_xlabel('Month')
ax.set_ylabel('Units Sold (thousands)')
ax.set_xticks(months)
ax.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun',
                    'Jul','Aug','Sep','Oct','Nov','Dec'])
ax.set_xlim(1, 13.8)
ax.legend(loc='upper left')  # kept as backup; direct labels are primary

plt.tight_layout()
plt.suptitle('GOOD: CVD-safe palette + markers + line styles + direct labels',
             y=1.01, color='#388E3C', fontsize=11, style='italic')
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #C62828; background-color: #FFF8F8; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Bad Example 2 — Rainbow (Jet) Heatmap</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The <code>jet</code> colormap appears vibrant but introduces false visual boundaries: the bright yellow-green band makes mid-range values look discontinuously different from adjacent values. It is perceptually non-uniform, fails for colorblind viewers, and converts to a non-monotonic grayscale. Here we apply it to a heatmap of average monthly temperature (°C) across several cities.
#   </p>
# </div>

# %%
# ---- BAD EXAMPLE 2: rainbow/jet heatmap ----

cities = ['Seattle', 'Phoenix', 'Chicago', 'Miami', 'Denver', 'Boston']
month_labels = ['Jan','Feb','Mar','Apr','May','Jun',
                'Jul','Aug','Sep','Oct','Nov','Dec']

# Realistic average monthly temperatures (°C)
temp_data = np.array([
    [4,  5,  7, 10, 14, 17, 20, 20, 17, 12,  7,  4],   # Seattle
    [12, 14, 18, 23, 28, 34, 37, 36, 32, 25, 17, 11],   # Phoenix
    [-4, -2,  4, 11, 17, 22, 25, 24, 19, 12,  4, -2],   # Chicago
    [20, 20, 22, 24, 26, 28, 30, 30, 29, 27, 24, 21],   # Miami
    [-1,  1,  5, 10, 15, 20, 24, 23, 18, 11,  4, -1],   # Denver
    [-2,  0,  4,  9, 15, 20, 23, 22, 18, 12,  6,  0],   # Boston
])

fig, ax = plt.subplots(figsize=(11, 4))
im = ax.imshow(temp_data, cmap='jet', aspect='auto')
plt.colorbar(im, ax=ax, label='Avg Temperature (°C)')
ax.set_xticks(range(12))
ax.set_xticklabels(month_labels)
ax.set_yticks(range(len(cities)))
ax.set_yticklabels(cities)
ax.set_title('Average Monthly Temperature by City', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.suptitle('BAD: jet/rainbow colormap — perceptually non-uniform, CVD-unsafe',
             y=1.02, color='#C62828', fontsize=11, style='italic')
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #388E3C; background-color: #F4FBF4; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #388E3C; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Corrected Example 2 — Viridis Heatmap with Value Annotations</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Replacing <code>jet</code> with <code>viridis</code> (or <code>cividis</code> for maximum CVD safety) gives a perceptually uniform gradient. We also annotate each cell with the numeric value, so the reader does not need to mentally decode color into number. Notice how the gradient now smoothly represents the true ordering of temperatures without any false boundaries.
#   </p>
# </div>

# %%
# ---- CORRECTED EXAMPLE 2: viridis heatmap + cell annotations ----

fig, axes = plt.subplots(1, 2, figsize=(16, 4))

for ax, cmap_name, title_suffix in zip(
        axes,
        ['viridis', 'cividis'],
        ['viridis  (perceptually uniform)', 'cividis  (optimized for deuteranopia/protanopia)']):

    im = ax.imshow(temp_data, cmap=cmap_name, aspect='auto',
                   vmin=temp_data.min(), vmax=temp_data.max())
    plt.colorbar(im, ax=ax, label='Avg Temp (°C)')
    ax.set_xticks(range(12))
    ax.set_xticklabels(month_labels, fontsize=9)
    ax.set_yticks(range(len(cities)))
    ax.set_yticklabels(cities)
    ax.set_title(title_suffix, fontsize=11, fontweight='bold')

    # Annotate each cell with the value
    for r in range(temp_data.shape[0]):
        for c in range(temp_data.shape[1]):
            val = temp_data[r, c]
            text_color = 'white' if val < 15 else 'black'
            ax.text(c, r, f'{val}', ha='center', va='center',
                    fontsize=7.5, color=text_color, fontweight='bold')

plt.suptitle('GOOD: Perceptually uniform colormaps + cell annotations',
             y=1.03, color='#388E3C', fontsize=11, style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo — Importing a Custom Hex Palette from coolors.co into Python</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     coolors.co and colorhunt.co generate palettes you can copy as a list of hex codes. The demo below shows how to paste those hex codes into Python, register them as a seaborn palette, and preview the result. We also simulate a rough deuteranopia view using a luminance-based grayscale transform.
#   </p>
# </div>

# %%
# ---- DEMO: Import hex palette from coolors.co, preview + grayscale simulation ----

# Paste your hex codes from coolors.co here (this is a CVD-safe 5-color palette)
coolors_palette = ['#264653', '#2A9D8F', '#E9C46A', '#F4A261', '#E76F51']

# ---- 1. Register as a seaborn palette and preview ----
sns.set_palette(coolors_palette)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Panel A: color swatches
ax = axes[0]
for i, hex_color in enumerate(coolors_palette):
    ax.barh(i, 1, color=hex_color, height=0.8)
    ax.text(0.5, i, hex_color, ha='center', va='center',
            color='white' if i in [0, 1] else '#333',
            fontweight='bold', fontsize=11)
ax.set_xlim(0, 1)
ax.set_yticks(range(len(coolors_palette)))
ax.set_yticklabels([f'Color {i+1}' for i in range(len(coolors_palette))])
ax.set_title('Custom Palette (coolors.co)', fontweight='bold')
ax.axis('off')
ax.set_frame_on(False)

# Panel B: bar chart using the custom palette
ax = axes[1]
categories = ['North', 'South', 'East', 'West', 'Central']
values = [34, 51, 42, 29, 46]
bars = ax.bar(categories, values, color=coolors_palette, width=0.6)
for bar, val in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.8,
            str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')
ax.set_title('Regional Sales (custom palette)', fontweight='bold')
ax.set_ylabel('Sales ($M)')
ax.set_ylim(0, 60)

# Panel C: grayscale simulation
# Convert hex to luminance using WCAG relative luminance formula
def hex_to_gray(hex_color):
    r, g, b = int(hex_color[1:3], 16)/255, int(hex_color[3:5], 16)/255, int(hex_color[5:7], 16)/255
    # Linearize
    def lin(c): return c/12.92 if c <= 0.03928 else ((c+0.055)/1.055)**2.4
    L = 0.2126*lin(r) + 0.7152*lin(g) + 0.0722*lin(b)
    return (L, L, L)  # RGB gray

gray_palette = [hex_to_gray(c) for c in coolors_palette]

ax = axes[2]
bars_g = ax.bar(categories, values, color=gray_palette, width=0.6,
                edgecolor='#555', linewidth=0.8)
for bar, val in zip(bars_g, values):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.8,
            str(val), ha='center', va='bottom', fontsize=10, fontweight='bold')
ax.set_title('Grayscale simulation', fontweight='bold')
ax.set_ylabel('Sales ($M)')
ax.set_ylim(0, 60)

plt.suptitle('Importing and Testing a Custom Palette from coolors.co',
             fontsize=13, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print('Grayscale luminance values:', [f'{(hex_to_gray(c)[0]):.3f}' for c in coolors_palette])
print('A well-separated palette should have at least 0.10 difference between adjacent luminances.')

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo — Accessible vs Inaccessible Scatter Plots Side by Side</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     This side-by-side scatter plot compares an inaccessible version (only color distinguishes groups) against an accessible version (color + shape + direct annotation). The accessible version works even when printed in black and white.
#   </p>
# </div>

# %%
# ---- DEMO: Accessible vs inaccessible scatter plots ----

# Simulated student data: study hours vs exam score, by major
np.random.seed(7)
n = 50
majors = ['Engineering', 'Business', 'Arts', 'Sciences']
colors_bad  = ['#D32F2F', '#388E3C', '#1565C0', '#F57F17']  # red/green problem
colors_good = ['#1976D2', '#F57C00', '#7B1FA2', '#388E3C']   # CVD-safe
markers     = ['o', 's', '^', 'D']

study_hours = {m: np.random.normal(5 + i, 1.5, n) for i, m in enumerate(majors)}
exam_scores = {m: 50 + study_hours[m] * 4 + np.random.normal(0, 5, n)
               for m in majors}

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# ---- Left: BAD (color only, same marker) ----
ax = axes[0]
for i, major in enumerate(majors):
    ax.scatter(study_hours[major], exam_scores[major],
               color=colors_bad[i], s=50, alpha=0.75, marker='o', label=major)
ax.set_title('BAD: Color only (red/green present)', color='#C62828',
             fontweight='bold', fontsize=12)
ax.set_xlabel('Study Hours per Week')
ax.set_ylabel('Exam Score')
ax.legend(title='Major', framealpha=0.9)
ax.set_xlim(0, 12)

# ---- Right: GOOD (color + shape + direct labels) ----
ax = axes[1]
for i, major in enumerate(majors):
    ax.scatter(study_hours[major], exam_scores[major],
               color=colors_good[i], s=55, alpha=0.75,
               marker=markers[i], label=major)
    # Annotate cluster centroid
    cx = np.mean(study_hours[major])
    cy = np.mean(exam_scores[major])
    ax.text(cx + 0.15, cy, major, color=colors_good[i],
            fontsize=8.5, fontweight='bold', va='center')

ax.set_title('GOOD: Color + shape + direct labels', color='#388E3C',
             fontweight='bold', fontsize=12)
ax.set_xlabel('Study Hours per Week')
ax.set_ylabel('Exam Score')
ax.legend(title='Major', framealpha=0.9)
ax.set_xlim(0, 12)

plt.suptitle('Accessible vs Inaccessible Scatter Plots',
             fontsize=13, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 4 — Fix a Red-Green Chart</h3>
# </div>

# %% [markdown]
# The bar chart below visualizes pass/fail rates for six course sections. It uses <strong>only red and green</strong>, with no patterns or additional encodings. A viewer with deuteranopia or protanopia cannot tell the two categories apart.
#
# 💬 **LLM Prompt**
# ```
# I have a bar chart that uses red for "Fail" and green for "Pass" to show pass/fail rates for six course sections.
# The chart is inaccessible for colorblind viewers.
# Suggest two alternative color pairs that are colorblind-safe for categorical data with two classes.
# Also explain how hatching patterns can be added to matplotlib bars and why they help.
# ```
#
# 🎯 **Task:**
# 1. Run the starter code below to see the problematic chart.
# 2. In the solution cell, recolor the bars using a colorblind-safe color pair.
# 3. Add a distinct hatch pattern to the "Fail" bars (e.g., `hatch='//'` or `hatch='xx'`).
# 4. Add value labels on top of each bar so the percentages are readable without color.
# 5. Ensure the legend still accurately labels both categories.

# %%
# ---- Exercise 4: STARTER CODE (do not modify this cell) ----

sections = ['Sec 01', 'Sec 02', 'Sec 03', 'Sec 04', 'Sec 05', 'Sec 06']
pass_rates = [88, 74, 91, 67, 82, 79]
fail_rates = [100 - p for p in pass_rates]

x = np.arange(len(sections))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 5))

bars_pass = ax.bar(x - width/2, pass_rates, width, color='#388E3C', label='Pass')
bars_fail = ax.bar(x + width/2, fail_rates, width, color='#D32F2F', label='Fail')

ax.set_xticks(x)
ax.set_xticklabels(sections)
ax.set_ylabel('Percentage of Students (%)')
ax.set_title('Pass / Fail Rates by Course Section  [PROBLEMATIC VERSION]',
             fontweight='bold')
ax.set_ylim(0, 110)
ax.legend()

plt.tight_layout()
plt.suptitle('BAD: Red/green only — fails for colorblind viewers',
             y=1.01, color='#C62828', fontsize=10, style='italic')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# ---- Exercise 4: YOUR SOLUTION ----
# Instructions:
# 1. Replace the red/green colors with a colorblind-safe pair
# 2. Add hatch patterns to the Fail bars
# 3. Add value labels above each bar
# 4. Keep a clear legend

# --- starter data (same as above) ---
sections = ['Sec 01', 'Sec 02', 'Sec 03', 'Sec 04', 'Sec 05', 'Sec 06']
pass_rates = [88, 74, 91, 67, 82, 79]
fail_rates = [100 - p for p in pass_rates]

x = np.arange(len(sections))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 5))

# Chosen CVD-safe pair: Blue and Orange
PASS_COLOR = '#1f77b4'  # A shade of blue
FAIL_COLOR = '#ff7f0e'  # A shade of orange

# Add hatch='' argument to the Fail bars
bars_pass = ax.bar(x - width/2, pass_rates, width, color=PASS_COLOR, label='Pass')
bars_fail = ax.bar(x + width/2, fail_rates, width, color=FAIL_COLOR, label='Fail', hatch='//')

# Loop over bars and add text labels above each bar
for bar in bars_pass:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{int(yval)}%', ha='center', va='bottom', fontsize=9)

for bar in bars_fail:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{int(yval)}%', ha='center', va='bottom', fontsize=9)

ax.set_xticks(x)
ax.set_xticklabels(sections)
ax.set_ylabel('Percentage of Students (%)')
ax.set_title('Pass / Fail Rates by Course Section  [YOUR CORRECTED VERSION]',
             fontweight='bold')
ax.set_ylim(0, 115) # Adjusted y-limit to make space for labels
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Questions — Exercise 4**
#
# 1. Which two colors did you choose for Pass and Fail, and why are they colorblind-safe compared to red/green?
#
# Blue and orange are colors that have enough contrast that even those that cannot detect it can still discern from the two plots.
#
# 2. Describe the hatch pattern you applied. In what other chart types (besides bar charts) can hatching be used?
# Hatching could be used to shade areas underneath trend lines or in pie charts if that is ever used.
# 3. If you could use only a single color for both bars, what other visual encodings would you need to add to keep the chart unambiguous?
#
#   Maybe lables or numbers, or a more distinct line pattern around the individual bars itself?

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 5 — Choose a Colorblind-Safe Palette for a Dashboard</h3>
# </div>

# %% [markdown]
# The dashboard below has four subplots, all using the <code>jet</code> (rainbow) colormap. This creates false visual boundaries, makes the data misleading, and fails for colorblind viewers.
#
# 💬 **LLM Prompt**
# ```
# I have a 4-panel matplotlib dashboard. Each panel shows a different data type:
#   Panel 1: sequential heatmap (population density)
#   Panel 2: diverging heatmap (temperature anomaly relative to a baseline)
#   Panel 3: categorical bar chart (5 product categories)
#   Panel 4: sequential scatter plot (colored by a numeric variable)
# All four currently use the jet colormap.
# For each panel, recommend the most appropriate colormap family (sequential, diverging, or qualitative)
# and a specific colorblind-safe colormap name in matplotlib/seaborn. Explain your reasoning.
# ```
#
# 🎯 **Task:**
# 1. Run the starter code to see the problematic dashboard.
# 2. In the solution cell, replace the colormap for each panel with an appropriate colorblind-safe alternative.
# 3. The colormap choice must match the data type: sequential, diverging, or qualitative.
# 4. Add a brief inline comment explaining why you chose each colormap.

# %%
# ---- Exercise 5: STARTER CODE (do not modify this cell) ----

np.random.seed(42)

# Panel 1 data: sequential — population density grid (all positive)
pop_density = np.abs(np.random.randn(8, 10)) * 500 + 100

# Panel 2 data: diverging — temperature anomaly relative to 1990 baseline
temp_anomaly = np.random.randn(6, 10) * 1.5  # centered at 0

# Panel 3 data: categorical — revenue by product category
product_cats = ['Electronics', 'Clothing', 'Food', 'Books', 'Toys']
revenues = [320, 215, 180, 95, 140]
# Using jet colormap via a colormap object for consistent bad example
jet_colors = [plt.cm.jet(i / 4) for i in range(5)]

# Panel 4 data: sequential scatter — house size vs price, colored by age
n_houses = 120
house_size  = np.random.randint(800, 3500, n_houses)
house_price = house_size * 150 + np.random.randn(n_houses) * 40000
house_age   = np.random.randint(0, 50, n_houses)

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Panel 1
im1 = axes[0, 0].imshow(pop_density, cmap='jet', aspect='auto')
plt.colorbar(im1, ax=axes[0, 0], label='Density (people/km²)')
axes[0, 0].set_title('Panel 1: Population Density Grid', fontweight='bold')

# Panel 2
im2 = axes[0, 1].imshow(temp_anomaly, cmap='jet', aspect='auto')
plt.colorbar(im2, ax=axes[0, 1], label='Temp Anomaly (°C)')
axes[0, 1].set_title('Panel 2: Temperature Anomaly vs 1990', fontweight='bold')

# Panel 3
axes[1, 0].bar(product_cats, revenues, color=jet_colors)
axes[1, 0].set_title('Panel 3: Revenue by Product Category ($M)', fontweight='bold')
axes[1, 0].set_ylabel('Revenue ($M)')

# Panel 4
sc = axes[1, 1].scatter(house_size, house_price, c=house_age, cmap='jet',
                         alpha=0.7, s=40)
plt.colorbar(sc, ax=axes[1, 1], label='House Age (years)')
axes[1, 1].set_title('Panel 4: House Size vs Price (colored by age)', fontweight='bold')
axes[1, 1].set_xlabel('Size (sq ft)')
axes[1, 1].set_ylabel('Price ($)')

plt.suptitle('DASHBOARD — BAD: All panels use jet/rainbow colormap',
             fontsize=14, fontweight='bold', color='#C62828', y=1.01)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# --- data (same as starter) ---
np.random.seed(42)
pop_density = np.abs(np.random.randn(8, 10)) * 500 + 100
temp_anomaly = np.random.randn(6, 10) * 1.5
product_cats = ['Electronics', 'Clothing', 'Food', 'Books', 'Toys']
revenues = [320, 215, 180, 95, 140]
n_houses = 120
house_size  = np.random.randint(800, 3500, n_houses)
house_price = house_size * 150 + np.random.randn(n_houses) * 40000
house_age   = np.random.randint(0, 50, n_houses)

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Panel 1 — sequential, all-positive data
# Reasoning: 'viridis' is a perceptually uniform and colorblind-safe sequential colormap.
im1 = axes[0, 0].imshow(pop_density, cmap='viridis', aspect='auto')  # CHANGE cmap
plt.colorbar(im1, ax=axes[0, 0], label='Density (people/km²)')
axes[0, 0].set_title('Panel 1: Population Density Grid', fontweight='bold')

# Panel 2 — diverging, data centered on zero
# Reasoning: 'coolwarm' is a perceptually uniform and colorblind-safe diverging colormap, suitable for anomalies.
im2 = axes[0, 1].imshow(temp_anomaly, cmap='coolwarm', aspect='auto')  # CHANGE cmap
plt.colorbar(im2, ax=axes[0, 1], label='Temp Anomaly (°C)')
axes[0, 1].set_title('Panel 2: Temperature Anomaly vs 1990', fontweight='bold')

# Panel 3 — qualitative (categorical) data
# Reasoning: 'colorblind' from seaborn is a dedicated colorblind-safe qualitative palette.
cat_colors = sns.color_palette('colorblind', n_colors=len(product_cats))  # REPLACE with CVD-safe palette
axes[1, 0].bar(product_cats, revenues, color=cat_colors)
axes[1, 0].set_title('Panel 3: Revenue by Product Category ($M)', fontweight='bold')
axes[1, 0].set_ylabel('Revenue ($M)')

# Panel 4 — sequential (numeric color variable: age)
# Reasoning: 'cividis' is another perceptually uniform and colorblind-safe sequential colormap, great for general numeric data.
sc = axes[1, 1].scatter(house_size, house_price, c=house_age, cmap='cividis',  # CHANGE cmap
                         alpha=0.7, s=40)
plt.colorbar(sc, ax=axes[1, 1], label='House Age (years)')
axes[1, 1].set_title('Panel 4: House Size vs Price (colored by age)', fontweight='bold')
axes[1, 1].set_xlabel('Size (sq ft)')
axes[1, 1].set_ylabel('Price ($)')

plt.suptitle('DASHBOARD — YOUR CORRECTED VERSION',
             fontsize=14, fontweight='bold', color='#388E3C', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Questions — Exercise 5**
#
# 1. Which colormap did you choose for Panel 1 (sequential) and why is it more appropriate than `jet`?
# Panel one has Viridis, It uses a more harmonized color pallete that might be easier to read.
#
# 2. Which colormap did you choose for Panel 2 (diverging)? What visual feature tells the viewer where the midpoint (zero) is?
#
# Panel 2 uses Coolwarm, and the midpoint is marked by a neutral grey color.
#
# 3. How did you build the qualitative palette for Panel 3? Name two sources (tools or Python libraries) where you can find colorblind-safe qualitative palettes.
#
#    sns.color_palletes('colorblind') can generate a colorblind safe pallete. Coolors.co is also a color pallete generator i freuently use in my projects and they have some colorblind safe options too.
#
# 4. What is the difference between `viridis` and `cividis`, and in what situation would you prefer `cividis`?
#
#   I think tat Viridis generally uses more vibriant colors while Cividis uses a lot more neutrals/greens.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 6 — Grayscale Readability Test</h3>
# </div>

# %% [markdown]
# The multi-line chart below shows quarterly revenue growth for five business units over three years. When converted to grayscale, all five lines become similar shades of gray and are indistinguishable. The only encoding is color.
#
# 💬 **LLM Prompt**
# ```
# I have a line chart with 5 series. In grayscale, all lines look the same.
# List the matplotlib parameters I need to set to:
#   1. Add distinct markers to each line
#   2. Use different line styles (solid, dashed, dotted, dash-dot, and a custom dash)
#   3. Place a direct label at the end of each line (instead of a legend)
# Show me a code snippet for placing text annotations next to the last data point of a line.
# ```
#
# 🎯 **Task:**
# 1. Run the starter code to see the grayscale-failing chart.
# 2. In the solution cell:
#    - Add a distinct marker (different shape) to each of the five lines.
#    - Use a different line style for each line.
#    - Add a direct label at the right end of each line (remove or minimize the legend).
#    - Optionally: increase line thickness to improve readability.
# 3. Verify your chart works by mentally converting it to grayscale — can you still identify all five series?

# %%
# ---- Exercise 6: STARTER CODE (do not modify this cell) ----

np.random.seed(11)
quarters = ['Q1-22','Q2-22','Q3-22','Q4-22',
            'Q1-23','Q2-23','Q3-23','Q4-23',
            'Q1-24','Q2-24','Q3-24','Q4-24']
n_q = len(quarters)

# Five business units with somewhat different trends
units = ['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon']
base_revenues = {'Alpha': 100, 'Beta': 85, 'Gamma': 120, 'Delta': 95, 'Epsilon': 110}
growth_rates  = {'Alpha': 1.04, 'Beta': 1.06, 'Gamma': 1.02, 'Delta': 1.05, 'Epsilon': 1.03}

revenues = {}
for unit in units:
    base = base_revenues[unit]
    gr   = growth_rates[unit]
    revenues[unit] = [base * (gr ** i) + np.random.normal(0, 3) for i in range(n_q)]

# Color-only version — all similar hues close in grayscale luminance
bad_colors = ['#2196F3', '#03A9F4', '#00BCD4', '#0097A7', '#006064']

fig, ax = plt.subplots(figsize=(11, 5))
for i, unit in enumerate(units):
    ax.plot(quarters, revenues[unit], color=bad_colors[i],
            linewidth=1.5, label=unit)

ax.set_xticks(range(n_q))
ax.set_xticklabels(quarters, rotation=45, ha='right')
ax.set_ylabel('Revenue ($M)')
ax.set_title('Quarterly Revenue by Business Unit  [GRAYSCALE-FAILING VERSION]',
             fontweight='bold')
ax.legend(loc='upper left')

plt.tight_layout()
plt.suptitle('BAD: Similar blue hues — indistinguishable in grayscale',
             y=1.01, color='#C62828', fontsize=10, style='italic')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- data (same as starter) ---
np.random.seed(11)
quarters = ['Q1-22','Q2-22','Q3-22','Q4-22',
            'Q1-23','Q2-23','Q3-23','Q4-23',
            'Q1-24','Q2-24','Q3-24','Q4-24']
n_q = len(quarters)
units = ['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon']
base_revenues = {'Alpha': 100, 'Beta': 85, 'Gamma': 120, 'Delta': 95, 'Epsilon': 110}
growth_rates  = {'Alpha': 1.04, 'Beta': 1.06, 'Gamma': 1.02, 'Delta': 1.05, 'Epsilon': 1.03}
revenues = {}
for unit in units:
    base = base_revenues[unit]
    gr   = growth_rates[unit]
    revenues[unit] = [base * (gr ** i) + np.random.normal(0, 3) for i in range(n_q)]

# Define a list of 5 CVD-safe colors (using a seaborn 'colorblind' compatible palette)
safe_colors = ['#0072B2', '#D55E00', '#CC79A7', '#009E73', '#F0E442']

# Define a list of 5 distinct markers
markers = ['o', 's', '^', 'D', 'v']

# Define a list of 5 distinct line styles
line_styles = ['-', '--', ':', '-.', (0,(5,2))] # Solid, dashed, dotted, dash-dot, and a custom dash

fig, ax = plt.subplots(figsize=(12, 5))

for i, unit in enumerate(units):
    ax.plot(quarters, revenues[unit],
            color=safe_colors[i],
            marker=markers[i],
            linestyle=line_styles[i],
            linewidth=2.0,
            markersize=6,
            label=unit)

    # Add a direct label at the last data point
    ax.text(n_q - 1 + 0.2, revenues[unit][-1], unit,
            color=safe_colors[i], va='center', fontsize=10, fontweight='bold')

ax.set_xticks(range(n_q))
ax.set_xticklabels(quarters, rotation=45, ha='right')
ax.set_ylabel('Revenue ($M)')
ax.set_title('Quarterly Revenue by Business Unit  [YOUR CORRECTED VERSION]',
             fontweight='bold')
ax.set_xlim(-0.5, n_q + 1.5)  # make room for direct labels
# Remove or minimize legend once direct labels are in place
ax.legend().set_visible(False) # Hide the legend as direct labels are used

plt.tight_layout()
plt.show()

# %% [markdown]
# **Questions — Exercise 6**
#
# 1. List the five markers and five line styles you chose. Why is it important to vary both independently (not just one of them)?
#
# Style one is dotted with triangles as plot points, two is dashed with triangles as arrows, stule three is line with circle point points, four is a .-. pattern with diamond plot points, and style five is a dashed line with square plot points.
#
# 2. Direct labels eliminate the need for a legend. In what situations might you still prefer a legend over direct labels?
#
#    In cases where lines might be too cluttered to include labels, a legend might be better. It also might not work for every plot type, so the method in which the data is displayed also matters.
#
# 3. Describe the grayscale test: how would you apply it to your corrected chart, and what would constitute a passing result?
#
#   I may make the colors a bit darker or more contrastic. A passing result would be if i can easily tell each line apart using value contrast alone.
# 4. The starter code uses five shades of blue with very similar luminance values. Without running code, explain why similar luminance values make a chart fail in grayscale even if the hues are technically different on a color screen.
#
#    This is because the saturation and brightness levels have not changed. Those things together help to contrast different values apart.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Section 3: Color Theory for Data Visualization</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Including the 70-20-10 Rule — From Overwhelming to Intentional</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Learning Objectives</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">By the end of this section you will be able to:</p>
#   <ol style="font-size: 1.05em; color: #555; line-height: 2;">
#     <li>Explain hue, saturation, and brightness and choose values deliberately rather than by default.</li>
#     <li>Distinguish warm from cool colors and describe how each influences audience perception.</li>
#     <li>Select the correct palette type — categorical, sequential, or diverging — for a given data variable.</li>
#     <li>Describe the emotional associations of common colors and apply them consistently to data stories.</li>
#     <li>Apply the <strong>70-20-10 rule</strong> to a dashboard or chart to create a clear visual hierarchy.</li>
#     <li>Redesign an over-colored visualization by assigning neutral, secondary, and accent roles to colors.</li>
#     <li>Maintain palette consistency across multiple related charts in a single report or dashboard.</li>
#   </ol>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Hue, Saturation, and Brightness</h2>
# </div>
#
# Every color has three independent dimensions. Understanding them gives you precise control over any palette.
#
# | Dimension | Definition | Effect on charts |
# |:----------|:-----------|:-----------------|
# | **Hue** | The *identity* of the color — red, blue, green, etc. Defined by wavelength on the color wheel. | Use distinct hues to encode **categorical** distinctions (product A vs. product B). |
# | **Saturation** | The *intensity* or purity of the hue — 0 % is pure gray, 100 % is the most vivid form. | High saturation draws the eye. Reserve it for the **accent** (10 %) role. Mute everything else. |
# | **Brightness (Value)** | The *lightness* or darkness — 0 % is black, 100 % is white. | Light backgrounds reduce eye strain; dark backgrounds suit presentation screens but hurt prints. |
#
# > **Practical rule:** For most business charts, keep background saturation near 0 (neutral gray or white), secondary elements at low-to-medium saturation, and your single accent element at full or near-full saturation.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Warm vs. Cool Colors</h2>
# </div>
#
# The color wheel is commonly split into **warm** (red, orange, yellow) and **cool** (blue, green, purple) families. Each carries inherited cultural and psychological associations that your audience will apply — consciously or not — to your data.
#
# | Family | Colors | Typical perception | Common data application |
# |:-------|:-------|:-------------------|:------------------------|
# | **Warm** | Red, Orange, Yellow | Urgency, danger, energy, heat, positivity (yellow) | Alerts, anomalies, high-risk KPIs, profit/growth |
# | **Cool** | Blue, Green, Purple | Calm, trust, stability, coldness | Neutral comparisons, brand colors, financial dashboards |
#
# **Why it matters for visualization:**
# - In a dashboard showing **budget overruns**, mapping red to over-budget and blue to on-target leverages instinctive associations — no legend needed.
# - If you invert this (blue for danger, red for safe), the audience fights the chart.
# - **Diverging palettes** often run from a warm extreme (red) through a neutral center (white or gray) to a cool extreme (blue), which aligns naturally with positive/negative or above-average/below-average values.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Categorical, Sequential, and Diverging Palettes</h2>
# </div>
#
# Choosing the wrong palette type is one of the most common color mistakes in data visualization. Each type is designed for a specific kind of data.
#
# ### Categorical Palette
# - **Use when:** Your variable has distinct, unordered groups (product lines, regions, departments).
# - **Design:** Maximally distinct hues at similar brightness/saturation so no group looks more important.
# - **Limit:** 5–7 categories maximum before colors become too similar to distinguish.
# - **Example:** `[#4B2E83, #E8B923, #1976D2, #388E3C, #F57C00]`
#
# ### Sequential Palette
# - **Use when:** Your variable has a natural order from low to high (revenue, temperature, count).
# - **Design:** One hue progressively darkens (or brightens). Darker typically means higher.
# - **Mistake to avoid:** Using a rainbow (jet) colormap — it introduces false boundaries where colors change abruptly.
# - **Example:** Light lavender → deep purple for a revenue heatmap.
#
# ### Diverging Palette
# - **Use when:** Your variable has a meaningful midpoint (zero, average, target) and deviates in two directions.
# - **Design:** Two contrasting hues fade toward a neutral center.
# - **Example:** Red → white → blue for a profit-vs-loss chart, or a correlation heatmap ranging from -1 to +1.
#
# > **Quick check:** Ask yourself: *Does the order of the data values matter?* If no — categorical. If yes — *Is there a meaningful midpoint?* If yes — diverging. If no — sequential.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Emotional Perception of Color</h2>
# </div>
#
# Audiences do not read color as neutral information — they *feel* it. Colors trigger associations built from culture, nature, and experience. Ignoring this is leaving a powerful communication tool unused.
#
# | Color | Common association | Data application |
# |:------|:-------------------|:-----------------|
# | **Red** `#C62828` | Danger, loss, urgency, stop | Budget overruns, declines, alerts, negative values |
# | **Green** `#388E3C` | Growth, safety, go, profit | Positive KPIs, on-target metrics, increases |
# | **Blue** `#1976D2` | Trust, calm, technology, neutrality | Default comparisons, background categories, corporate reports |
# | **Orange** `#F57C00` | Caution, energy, warmth | Warnings (not as severe as red), secondary highlights |
# | **Purple** `#4B2E83` | Premium, creativity, sophistication | Branding for universities and luxury goods |
# | **Yellow/Gold** `#E8B923` | Attention, achievement, warmth | Highlights, callout boxes, awards |
# | **Gray** | Neutral, background, suppressed | Non-focus categories, gridlines, labels |
#
# **Cultural caveat:** These associations are predominantly Western. Red signals luck in China; white connotes mourning in many Asian cultures. Always consider your audience when choosing emotionally loaded colors.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Branding Consistency</h2>
# </div>
#
# Every organization has a visual identity — a set of approved colors, fonts, and logo treatments. When your data visualization lives inside a corporate report, a pitch deck, or a public dashboard, it must honor that identity.
#
# **Why it matters:**
# - **Trust:** Consistent branding signals professionalism. A chart that uses random colors reads as unpolished.
# - **Efficiency:** Audiences already associate your brand colors with your organization. Using them saves cognitive work.
# - **Portability:** A colleague can drop your chart into a deck and it will fit seamlessly.
#
# **Practical steps:**
# 1. Extract the exact hex codes from your organization's brand guidelines.
# 2. Set them as your matplotlib default color cycle at the top of every notebook.
# 3. Assign specific roles: primary brand color → dominant; secondary brand color → supporting; accent → one bright call-out color.
# 4. Never introduce colors outside the brand palette without explicit approval.
#
# For this course we use the University of Washington palette: `primary=#4B2E83`, `gold=#E8B923`, `dark=#32006E`, `lavender=#B7A6D5`.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Visual Hierarchy and Emphasis Through Accent Color</h2>
# </div>
#
# **Visual hierarchy** is the principle that not everything in a chart deserves equal attention. Your job as a designer is to guide the viewer's eye to the most important element first.
#
# Color is the fastest tool for creating hierarchy:
#
# | Role | Color treatment | Viewer response |
# |:-----|:----------------|:----------------|
# | **Accent (10%)** | High saturation, distinctive hue | Eye goes here first — this is the key insight |
# | **Secondary (20%)** | Medium saturation, muted hue | Supports context without competing |
# | **Base/Neutral (70%)** | Low saturation, gray or off-white | Provides structure without distraction |
#
# **Emphasis through accent color** means reserving one vivid color exclusively for the element you want the audience to notice — the best-performing product, the month revenue crossed the target, the anomalous data point.
#
# > **The accent rule:** If everything is highlighted, nothing is. One accent color. Use it once per chart, or at most for one category across all charts in a report.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Neutral vs. Saturated Backgrounds</h2>
# </div>
#
# The background is the largest color area in any chart. It sets the baseline against which every data element is perceived.
#
# **Neutral backgrounds (white, light gray, off-white):**
# - Standard for printed reports and most business dashboards.
# - Data elements pop cleanly against them.
# - Gridlines and axes remain visible without competing.
# - Recommended: `#FFFFFF`, `#F5F5F5`, `#FAFAFA`.
#
# **Saturated / dark backgrounds:**
# - Work well on presentation screens (conferences, digital dashboards viewed from a distance).
# - Require higher-contrast text and lighter data elements.
# - Can create a dramatic, premium feel — but exhaust eyes in long-form reading.
# - Use sparingly: typically only for hero slides or executive scorecards.
#
# **The rule:** Match your background choice to the **medium** and **context** of consumption, not personal aesthetic preference.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Consistency Across Multi-Chart Dashboards</h2>
# </div>
#
# A dashboard is a collection of related charts. Inconsistent color use across panels creates cognitive friction — the viewer must re-learn what each color means with every chart they look at.
#
# **Rules for multi-chart consistency:**
#
# 1. **Same category = same color.** If "Q4 Revenue" is `#4B2E83` in the bar chart, it must be `#4B2E83` in the line chart and the scatter plot.
# 2. **Same role = same treatment.** If gridlines are `#DDDDDD` and 30 % opacity in one chart, use those exact values everywhere.
# 3. **One accent, used consistently.** If your accent color flags the KPI of interest, apply it to the same category or value across all panels — never repurpose it for a different meaning in a different chart.
# 4. **Consistent background.** All panels on a dashboard should share the same figure and axes background colors.
# 5. **Define a palette dictionary at the top of your code** and import it into every chart function — never hard-code a hex string twice.
#
# ```python
# PALETTE = {
#     'primary':   '#4B2E83',
#     'gold':      '#E8B923',
#     'accent':    '#C62828',
#     'secondary': '#B7A6D5',
#     'neutral':   '#CCCCCC',
#     'bg':        '#FAFAFA',
# }
# ```

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">The 70-20-10 Color Rule</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">A Practical Framework for Visual Hierarchy in Dashboards</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">The Rule Explained</h2>
# </div>
#
# The 70-20-10 rule borrows from interior design and brand identity to provide a simple, memorable framework for allocating color in any visual composition.
#
# | Proportion | Role | Typical colors | Typical chart elements |
# |:----------:|:-----|:---------------|:-----------------------|
# | **70%** | **Dominant / Base** | Neutral: white, light gray, off-white | Figure background, axes area, gridlines, un-highlighted bars/points |
# | **20%** | **Secondary / Supporting** | Muted brand color or medium-saturation hue | Secondary category bars, axis labels, tick marks, legend text, supporting lines |
# | **10%** | **Accent / Highlight** | Vivid, high-saturation color | The KPI bar, the anomaly point, the record-breaking month, the key insight |
#
# ### Why it works
#
# Human vision evolved to detect contrast. When 90 % of a chart is quiet (neutral or muted), the 10 % accent creates an automatic, effortless focal point. The viewer does not need to read a caption — their eye is already on the insight.
#
# Without the rule, a chart where every element screams for attention forces the viewer to do all the interpretive work. With it, the chart does the work for them.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Applying 70-20-10 to a Business Dashboard</h2>
# </div>
#
# Here is how the three zones map to the concrete elements of a typical multi-panel KPI dashboard:
#
# **70% — Neutral base:**
# - Figure background: `#FAFAFA` (near-white)
# - Axes background: `white` or very light gray
# - Gridlines: `#DDDDDD`, opacity 40 %
# - Non-highlighted bars, lines, and scatter points: `#CCCCCC` (neutral gray)
# - Axis tick labels, axis titles: `#555555`
#
# **20% — Supporting color:**
# - Secondary categories (e.g., all product lines except the top performer): `#B7A6D5` (muted lavender)
# - Supporting annotation text
# - Legend markers
# - Chart titles: `#4B2E83` (brand color, but restrained by area)
#
# **10% — Accent:**
# - The top-performing bar: `#C62828` (bold red) or `#E8B923` (gold)
# - The anomalous data point: `#F57C00` (orange)
# - The month revenue crossed a target line: `#4B2E83` (primary brand, full saturation)
# - KPI tiles that are off-track: `#C62828`
#
# > **Remember:** The accent does its job because everything else is quiet. Resist the temptation to use more than one accent per chart.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Python Demonstrations</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Bad vs. Corrected Examples — Seeing the Difference in Practice</p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')

np.random.seed(42)

# ── Shared palette ─────────────────────────────────────────────────────────────
PALETTE = {
    'primary':   '#4B2E83',
    'gold':      '#E8B923',
    'dark':      '#32006E',
    'lavender':  '#B7A6D5',
    'tan':       '#85714D',
    'red':       '#C62828',
    'blue':      '#1976D2',
    'orange':    '#F57C00',
    'green':     '#388E3C',
    'purple':    '#7B1FA2',
    'neutral':   '#CCCCCC',
    'neutral2':  '#AAAAAA',
    'bg':        '#FAFAFA',
}

# ── Realistic business KPI data ────────────────────────────────────────────────
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

revenue      = [4.1, 3.8, 4.5, 5.2, 5.8, 6.1, 5.9, 6.3, 7.1, 7.4, 8.2, 9.0]
expenses     = [3.2, 3.1, 3.4, 3.6, 3.8, 4.0, 3.9, 4.1, 4.3, 4.5, 4.8, 5.1]
headcount    = [142, 145, 148, 150, 153, 155, 154, 157, 160, 162, 165, 170]
satisfaction = [7.2, 7.0, 7.4, 7.5, 7.6, 7.3, 7.8, 7.9, 8.1, 8.0, 8.3, 8.5]

departments  = ['Sales', 'Marketing', 'Engineering', 'Operations', 'Finance', 'HR']
dept_revenue = [42.3, 18.7, 8.1, 12.4, 9.9, 5.2]

print('Setup complete ✓')
# Out:
# Setup complete ✓

# %% [markdown]
# ### Bad Example 1 — The Competing-Color Dashboard
#
# The chart below shows a realistic 2×2 business dashboard. Every bar is a different bright color, every panel uses a different scheme, and there is no visual hierarchy. The result is visually exhausting — the eye has nowhere to rest, and there is no obvious message.

# %%
# ── BAD EXAMPLE 1: Competing saturated colors, no visual hierarchy ──────────────
bad_colors_bars   = ['#E53935','#8E24AA','#1E88E5','#43A047','#FB8C00','#00ACC1']
bad_colors_line1  = '#FF1744'
bad_colors_line2  = '#00E676'
bad_colors_hc     = ['#FFEB3B','#FF5722','#9C27B0','#00BCD4',
                      '#8BC34A','#FF9800','#607D8B','#F44336',
                      '#3F51B5','#009688','#CDDC39','#795548']
bad_colors_sat    = ['#E91E63','#2196F3','#4CAF50','#FF5722',
                      '#9C27B0','#FFC107','#00BCD4','#8BC34A',
                      '#FF9800','#F44336','#673AB7','#03A9F4']

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.patch.set_facecolor('#FFFFFF')
fig.suptitle('Q4 Business KPI Dashboard', fontsize=18, fontweight='bold', color='#000000')

# Panel 1: Revenue by department — every bar a different saturated color
ax1 = axes[0, 0]
ax1.bar(departments, dept_revenue, color=bad_colors_bars)
ax1.set_title('Revenue by Department ($M)', fontsize=13, color='#E53935')
ax1.set_facecolor('#FFFDE7')

# Panel 2: Monthly revenue vs expenses — competing neon lines
ax2 = axes[0, 1]
ax2.plot(months, revenue,  color=bad_colors_line1, linewidth=3, marker='D', label='Revenue')
ax2.plot(months, expenses, color=bad_colors_line2, linewidth=3, marker='*', label='Expenses')
ax2.set_title('Revenue vs Expenses ($M)', fontsize=13, color='#1E88E5')
ax2.legend()
ax2.set_facecolor('#E8F5E9')

# Panel 3: Headcount — every bar a random color
ax3 = axes[1, 0]
ax3.bar(months, headcount, color=bad_colors_hc)
ax3.set_title('Headcount by Month', fontsize=13, color='#9C27B0')
ax3.set_facecolor('#FCE4EC')

# Panel 4: Satisfaction scores — random scatter colors
ax4 = axes[1, 1]
ax4.scatter(range(12), satisfaction, c=bad_colors_sat, s=150, zorder=3)
ax4.plot(range(12), satisfaction, color='#000000', linewidth=1, zorder=2)
ax4.set_title('Employee Satisfaction', fontsize=13, color='#FF5722')
ax4.set_facecolor('#E3F2FD')

for ax in axes.flat:
    ax.grid(True, alpha=0.5)
    ax.tick_params(axis='x', rotation=45)

fig.text(0.5, -0.02,
    '⚠ BAD: Every element uses a competing saturated color. '
    'No hierarchy. No focal point. The viewer does not know where to look.',
    ha='center', fontsize=11, color='#C62828', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# **What is wrong with this chart?**
#
# - Every bar and every data point is a maximally saturated, distinct color — yet the colors encode *no information*. The blue bar in the department chart is not more important than the red one; they are equally loud.
# - Each panel uses a completely different background color and color scheme, so the four charts feel like they came from four different designers.
# - There is no accent element — nothing that says "this is the number you need to care about."
# - The viewer's cognitive load spikes immediately. Processing the chart takes effort rather than being effortless.
#
# Now let us correct it using the 70-20-10 rule.

# %%
# ── CORRECTED EXAMPLE 1: 70-20-10 applied to the same dashboard ────────────────
#
# 70% neutral: white/near-white backgrounds, gray bars/points
# 20% secondary: muted lavender for supporting categories / lines
# 10% accent: UW gold #E8B923 for the KPI that matters most

BASE    = PALETTE['neutral']     # 70% — non-highlighted bars, points
SUPPORT = PALETTE['lavender']    # 20% — secondary line, supporting labels
ACCENT  = PALETTE['gold']        # 10% — the KPI we want to call out
TITLE_C = PALETTE['primary']

# Top-performing department: Sales (index 0)
dept_colors = [ACCENT if i == 0 else BASE for i in range(len(departments))]

# Month with highest revenue: December (index 11)
hc_colors   = [ACCENT if i == 11 else BASE for i in range(12)]
sat_colors  = [ACCENT if s == max(satisfaction) else BASE for s in satisfaction]

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.patch.set_facecolor(PALETTE['bg'])
fig.suptitle('Q4 Business KPI Dashboard', fontsize=18, fontweight='bold', color=TITLE_C)

# Panel 1: Revenue by department — Sales highlighted as top earner
ax1 = axes[0, 0]
ax1.set_facecolor('white')
bars = ax1.bar(departments, dept_revenue, color=dept_colors, edgecolor='white', linewidth=0.8)
ax1.bar_label(bars, fmt='$%.1fM', fontsize=9, padding=3, color=TITLE_C)
ax1.set_title('Revenue by Department ($M)\n', fontsize=13, fontweight='bold', color=TITLE_C)
ax1.set_ylabel('Revenue ($M)', fontsize=11)
ax1.tick_params(axis='x', rotation=30)
ax1.annotate('▲ Top earner', xy=(0, dept_revenue[0]), xytext=(0.3, dept_revenue[0] + 1.5),
             color=ACCENT, fontsize=9, fontweight='bold')
ax1.grid(True, axis='y', alpha=0.35, color='#DDDDDD')
ax1.spines[['top', 'right']].set_visible(False)

# Panel 2: Revenue vs expenses — revenue in primary, expenses in muted support
ax2 = axes[0, 1]
ax2.set_facecolor('white')
ax2.plot(months, expenses, color=SUPPORT, linewidth=2, marker='o', markersize=5,
         label='Expenses', zorder=2)
ax2.plot(months, revenue,  color=TITLE_C,  linewidth=2.5, marker='o', markersize=6,
         label='Revenue', zorder=3)
# Accent: highlight December (record month)
ax2.scatter([11], [revenue[11]], color=ACCENT, s=120, zorder=5, label='Record month')
ax2.axhline(y=7.0, color=PALETTE['red'], linewidth=1, linestyle='--', alpha=0.6, label='Target $7M')
ax2.set_title('Revenue vs Expenses ($M)\n', fontsize=13, fontweight='bold', color=TITLE_C)
ax2.set_ylabel('Amount ($M)', fontsize=11)
ax2.tick_params(axis='x', rotation=30)
ax2.legend(fontsize=9, frameon=False)
ax2.grid(True, alpha=0.35, color='#DDDDDD')
ax2.spines[['top', 'right']].set_visible(False)

# Panel 3: Headcount — December highlighted
ax3 = axes[1, 0]
ax3.set_facecolor('white')
ax3.bar(months, headcount, color=hc_colors, edgecolor='white', linewidth=0.8)
ax3.set_title('Headcount by Month\n', fontsize=13, fontweight='bold', color=TITLE_C)
ax3.set_ylabel('Headcount', fontsize=11)
ax3.tick_params(axis='x', rotation=30)
ax3.annotate('▲ Year-end peak', xy=(11, headcount[11]),
             xytext=(8.5, headcount[11] + 1.5), color=ACCENT, fontsize=9, fontweight='bold')
ax3.grid(True, axis='y', alpha=0.35, color='#DDDDDD')
ax3.spines[['top', 'right']].set_visible(False)

# Panel 4: Satisfaction — best month highlighted
ax4 = axes[1, 1]
ax4.set_facecolor('white')
ax4.plot(range(12), satisfaction, color=SUPPORT, linewidth=2, zorder=2)
ax4.scatter(range(12), satisfaction, c=sat_colors, s=80, zorder=3, edgecolors='white', linewidth=0.5)
ax4.set_title('Employee Satisfaction (1–10)\n', fontsize=13, fontweight='bold', color=TITLE_C)
ax4.set_ylabel('Score', fontsize=11)
ax4.set_xticks(range(12))
ax4.set_xticklabels(months, rotation=30, fontsize=9)
peak_i = satisfaction.index(max(satisfaction))
ax4.annotate(f'Peak {max(satisfaction)}', xy=(peak_i, max(satisfaction)),
             xytext=(peak_i - 2.5, max(satisfaction) - 0.3),
             color=ACCENT, fontsize=9, fontweight='bold',
             arrowprops=dict(arrowstyle='->', color=ACCENT, lw=1.2))
ax4.grid(True, alpha=0.35, color='#DDDDDD')
ax4.spines[['top', 'right']].set_visible(False)

fig.text(0.5, -0.02,
    '✓ CORRECTED: 70% neutral (gray/white), 20% muted lavender/brand, '
    '10% gold accent on the KPI that matters. One focal point per panel.',
    ha='center', fontsize=11, color=PALETTE['green'], style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# **What changed — and why it works now:**
#
# - The background is a consistent near-white `#FAFAFA` across all four panels, providing a quiet base (70%).
# - Non-highlighted bars and scatter points are neutral gray `#CCCCCC` — they provide shape and scale without competing for attention.
# - Supporting lines and secondary labels use muted lavender `#B7A6D5` (20%).
# - The gold accent `#E8B923` appears exactly once per panel, marking the single insight the viewer should leave with: the top revenue department, the record revenue month, the peak headcount month, and the best satisfaction score.
# - All panels use the same background, the same gridline style, and the same accent color — the dashboard reads as one cohesive piece.

# %% [markdown]
# ### Bad Example 2 — The Uniform-Color Scatter Plot
#
# The chart below shows monthly sales calls vs. closed deals for a sales team. All 80 data points are rendered in bright red. There is no hierarchy — the one underperforming rep who is dragging down team numbers is completely invisible.

# %%
# ── Sales team data ──────────────────────────────────────────────────────────────
np.random.seed(7)
n_reps   = 79
calls    = np.random.normal(120, 20, n_reps).clip(60, 200).astype(int)
deals    = (calls * np.random.uniform(0.18, 0.35, n_reps)).astype(int)

# One deliberate outlier: very high calls, very low conversion
outlier_calls = np.array([195])
outlier_deals = np.array([8])

all_calls = np.concatenate([calls, outlier_calls])
all_deals = np.concatenate([deals, outlier_deals])

# ── BAD: everything in bright red, no hierarchy ──────────────────────────────────
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(all_calls, all_deals, color='#FF1744', s=80, alpha=0.8, edgecolors='white', linewidth=0.5)

ax.set_title('Sales Calls vs. Closed Deals — Rep Performance', fontsize=16,
             fontweight='bold', color='#000000')
ax.set_xlabel('Calls Made (Monthly)', fontsize=13)
ax.set_ylabel('Deals Closed (Monthly)', fontsize=13)
ax.grid(True, alpha=0.4)

fig.text(0.1, -0.03,
    '⚠ BAD: All 80 reps rendered in identical bright red. '
    'The underperforming rep with high calls but only 8 closed deals is invisible.',
    fontsize=10, color='#C62828', style='italic')

plt.tight_layout()
plt.show()

# %%
# ── CORRECTED: 70-20-10 — neutral points, accent on the outlier ─────────────────
#
# 70%  neutral gray for the 79 typical reps
# 20%  muted brand color for the trend line
# 10%  bold orange accent for the single outlier that management needs to act on

fig, ax = plt.subplots(figsize=(10, 6))
ax.set_facecolor('white')
fig.patch.set_facecolor(PALETTE['bg'])

# 70% neutral — all typical reps
ax.scatter(calls, deals,
           color=PALETTE['neutral'], s=70, alpha=0.75,
           edgecolors='white', linewidth=0.5, label='Sales reps (n=79)', zorder=2)

# 20% supporting — trend line
m, b = np.polyfit(calls, deals, 1)
x_line = np.linspace(calls.min(), calls.max(), 100)
ax.plot(x_line, m * x_line + b,
        color=PALETTE['lavender'], linewidth=2, linestyle='--',
        label='Expected trend', zorder=3)

# 10% accent — the outlier
ax.scatter(outlier_calls, outlier_deals,
           color=PALETTE['orange'], s=160, edgecolors=PALETTE['dark'],
           linewidth=1.5, zorder=5, label='Underperforming rep')
ax.annotate('195 calls → only 8 deals\n⚠ Needs coaching',
            xy=(outlier_calls[0], outlier_deals[0]),
            xytext=(outlier_calls[0] - 60, outlier_deals[0] + 7),
            fontsize=10, color=PALETTE['orange'], fontweight='bold',
            arrowprops=dict(arrowstyle='->', color=PALETTE['orange'], lw=1.5))

ax.set_title('Sales Calls vs. Closed Deals — Rep Performance',
             fontsize=16, fontweight='bold', color=PALETTE['primary'])
ax.set_xlabel('Calls Made (Monthly)', fontsize=13)
ax.set_ylabel('Deals Closed (Monthly)', fontsize=13)
ax.legend(frameon=False, fontsize=11)
ax.grid(True, alpha=0.3, color='#DDDDDD')
ax.spines[['top', 'right']].set_visible(False)

fig.text(0.1, -0.03,
    '✓ CORRECTED: 79 reps in quiet neutral gray (70%), trend line in muted lavender (20%), '
    'one orange accent on the actionable outlier (10%).',
    fontsize=10, color=PALETTE['green'], style='italic')

fig.text(0.1, -0.06, 'Source: Simulated sales rep performance data',
         fontsize=9, color='#888', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Demo — Business Dashboard Mockup Implementing 70-20-10
#
# The following chart shows a realistic executive KPI summary. The entire layout is built around the 70-20-10 framework: a quiet neutral base, one brand-color supporting metric, and one gold accent for the record-breaking data point.

# %%
# ── DEMO: Business dashboard mockup with explicit 70-20-10 labeling ─────────────
quarters  = ['Q1', 'Q2', 'Q3', 'Q4']
q_revenue = [14.4, 17.1, 21.3, 24.6]   # Q4 is the record
q_target  = [15.0, 16.0, 20.0, 22.0]

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
fig.patch.set_facecolor(PALETTE['bg'])  # 70% base background
fig.suptitle('FY Annual Revenue Performance Dashboard',
             fontsize=17, fontweight='bold', color=PALETTE['primary'])

# ── Left panel: quarterly revenue bars ──────────────────────────────────────────
ax = axes[0]
ax.set_facecolor('white')  # 70%

bar_colors = [PALETTE['neutral'] if q != 'Q4' else PALETTE['gold'] for q in quarters]
bars = ax.bar(quarters, q_revenue, color=bar_colors, width=0.5,
              edgecolor='white', linewidth=0.8, zorder=3)
label_colors = [PALETTE['primary'] if c == PALETTE['gold'] else '#888' for c in bar_colors]
labels = ax.bar_label(bars, fmt='$%.1fM', fontsize=11, padding=4, fontweight='bold')
for lbl, lc in zip(labels, label_colors):
    lbl.set_color(lc)

# Target line — 20% supporting element
ax.step([-.4, .6, 1.6, 2.6, 3.6], [q_target[0]] + q_target,
        where='post', color=PALETTE['lavender'], linewidth=2,
        linestyle='--', label='Quarterly target', zorder=4)

ax.set_title('Quarterly Revenue vs. Target', fontsize=13, fontweight='bold', color=PALETTE['primary'])
ax.set_ylabel('Revenue ($M)', fontsize=12)
ax.set_ylim(0, 30)
ax.legend(fontsize=10, frameon=False)
ax.grid(True, axis='y', alpha=0.35, color='#DDDDDD', zorder=0)
ax.spines[['top', 'right']].set_visible(False)
ax.annotate('Record quarter\n+12% vs target',
            xy=(3, q_revenue[3]), xytext=(2.3, q_revenue[3] + 2),
            fontsize=9, color=PALETTE['gold'], fontweight='bold',
            arrowprops=dict(arrowstyle='->', color=PALETTE['gold'], lw=1.2))

# ── Right panel: monthly revenue line with accent on record month ────────────────
ax2 = axes[1]
ax2.set_facecolor('white')  # 70%

# 70%: plot all points as neutral gray
ax2.plot(range(12), revenue, color=PALETTE['neutral'], linewidth=2, zorder=2)
ax2.scatter(range(12), revenue,
            c=[PALETTE['gold'] if r == max(revenue) else PALETTE['neutral'] for r in revenue],
            s=[140 if r == max(revenue) else 60 for r in revenue],
            edgecolors='white', linewidth=0.8, zorder=4)

# 20%: expense comparison in muted lavender
ax2.plot(range(12), expenses, color=PALETTE['lavender'], linewidth=1.8,
         linestyle='--', label='Expenses', zorder=2)

# 10%: target line as accent dashed red
ax2.axhline(y=7.0, color=PALETTE['red'], linewidth=1.5,
            linestyle=':', alpha=0.8, label='Monthly target $7M', zorder=3)

ax2.set_title('Monthly Revenue & Expenses ($M)', fontsize=13,
              fontweight='bold', color=PALETTE['primary'])
ax2.set_ylabel('Amount ($M)', fontsize=12)
ax2.set_xticks(range(12))
ax2.set_xticklabels(months, rotation=30, fontsize=9)
ax2.legend(fontsize=10, frameon=False)
ax2.grid(True, alpha=0.35, color='#DDDDDD', zorder=0)
ax2.spines[['top', 'right']].set_visible(False)

peak_m = revenue.index(max(revenue))
ax2.annotate(f'Dec — ${max(revenue)}M',
             xy=(peak_m, max(revenue)),
             xytext=(peak_m - 3.5, max(revenue) - 0.8),
             fontsize=9, color=PALETTE['gold'], fontweight='bold',
             arrowprops=dict(arrowstyle='->', color=PALETTE['gold'], lw=1.2))

# Color role legend
legend_elements = [
    mpatches.Patch(facecolor=PALETTE['neutral'],  label='70% Neutral base'),
    mpatches.Patch(facecolor=PALETTE['lavender'], label='20% Supporting'),
    mpatches.Patch(facecolor=PALETTE['gold'],     label='10% Accent (KPI)'),
]
fig.legend(handles=legend_elements, loc='lower center', ncol=3,
           fontsize=10, frameon=True, fancybox=True,
           bbox_to_anchor=(0.5, -0.08))

fig.text(0.1, -0.14, 'Source: Simulated annual KPI data',
         fontsize=9, color='#888', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Demo — Palette Consistency Across Three Related Charts
#
# The following three charts cover different aspects of the same sales dataset — by region, by product line, and over time. Despite showing different chart types, they feel like a single coherent report because every color assignment is identical across all three panels.

# %%
# ── DEMO: Consistent palette across 3 related charts ────────────────────────────

# Shared category → color mapping (NEVER reassign mid-report)
CAT_COLORS = {
    'North':  PALETTE['primary'],
    'South':  PALETTE['lavender'],
    'East':   PALETTE['neutral'],
    'West':   PALETTE['neutral2'],
}

# Simulated data
np.random.seed(3)
regions    = list(CAT_COLORS.keys())
annual_rev = {'North': 38.4, 'South': 24.1, 'East': 17.9, 'West': 12.6}

monthly_by_region = {
    r: (np.random.normal(annual_rev[r] / 12, annual_rev[r] / 60, 12)).clip(0)
    for r in regions
}

q_by_region = {
    r: [monthly_by_region[r][i*3:(i+1)*3].sum() for i in range(4)]
    for r in regions
}

fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.patch.set_facecolor(PALETTE['bg'])
fig.suptitle('Regional Sales Performance — FY Report',
             fontsize=17, fontweight='bold', color=PALETTE['primary'])

# Chart 1: Annual revenue bar chart
ax1 = axes[0]
ax1.set_facecolor('white')
ax1.bar(regions, [annual_rev[r] for r in regions],
        color=[CAT_COLORS[r] for r in regions],
        edgecolor='white', linewidth=0.8)
ax1.set_title('Annual Revenue by Region', fontsize=13,
              fontweight='bold', color=PALETTE['primary'])
ax1.set_ylabel('Revenue ($M)', fontsize=12)
ax1.grid(True, axis='y', alpha=0.3, color='#DDDDDD')
ax1.spines[['top', 'right']].set_visible(False)

# Chart 2: Quarterly breakdown — stacked bar
ax2 = axes[1]
ax2.set_facecolor('white')
bottom = np.zeros(4)
for r in regions:
    ax2.bar(quarters, q_by_region[r], bottom=bottom,
            color=CAT_COLORS[r], label=r, edgecolor='white', linewidth=0.5)
    bottom += np.array(q_by_region[r])
ax2.set_title('Quarterly Revenue (Stacked)', fontsize=13,
              fontweight='bold', color=PALETTE['primary'])
ax2.set_ylabel('Revenue ($M)', fontsize=12)
ax2.legend(fontsize=10, frameon=False, loc='upper left')
ax2.grid(True, axis='y', alpha=0.3, color='#DDDDDD')
ax2.spines[['top', 'right']].set_visible(False)

# Chart 3: Monthly trend lines
ax3 = axes[2]
ax3.set_facecolor('white')
for r in regions:
    lw = 2.5 if r == 'North' else 1.5
    ax3.plot(range(12), monthly_by_region[r], color=CAT_COLORS[r],
             linewidth=lw, marker='o', markersize=4, label=r)
ax3.set_title('Monthly Revenue Trend', fontsize=13,
              fontweight='bold', color=PALETTE['primary'])
ax3.set_ylabel('Revenue ($M)', fontsize=12)
ax3.set_xticks(range(12))
ax3.set_xticklabels(months, rotation=45, fontsize=8)
ax3.legend(fontsize=10, frameon=False)
ax3.grid(True, alpha=0.3, color='#DDDDDD')
ax3.spines[['top', 'right']].set_visible(False)

fig.text(0.5, -0.04,
    '✓ CONSISTENT: North is always #4B2E83, South is always #B7A6D5, '
    'East and West always in neutral gray — across all three chart types.',
    ha='center', fontsize=10, color=PALETTE['green'], style='italic')

fig.text(0.1, -0.08, 'Source: Simulated regional sales data',
         fontsize=9, color='#888', style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Exercises</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Apply the 70-20-10 Rule — Your Turn</p>
# </div>

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 7 — Apply 70-20-10 to a Bar Chart</h3>
# </div>
#
# The chart below shows monthly product sales for six products. Every bar is a different saturated color — the chart has no focal point and gives the viewer no guidance about what to care about.
#
# 🎯 **Task:**
# 1. Run the starter code to see the bad chart.
# 2. Redesign it so it follows the 70-20-10 rule:
#    - 70 % — all bars except the top-selling product should be neutral gray (`#CCCCCC`).
#    - 20 % — add a thin dashed line showing the monthly sales average in a muted brand color.
#    - 10 % — use `#E8B923` (gold) to highlight the single best-performing product bar.
# 3. Add an annotation pointing to the top performer explaining *why* it matters (e.g., "Top product — 34% of total revenue").
# 4. Answer the written questions below.
#
# 💬 **LLM Prompt**
# ```
# I have a bar chart showing monthly unit sales for 6 products.
# Each bar is currently a different bright color with no visual hierarchy.
# Help me redesign the chart using the 70-20-10 color rule in matplotlib:
# - 70% neutral gray bars
# - 20% muted dashed average line
# - 10% gold accent bar for the top product
# Include an annotation on the top bar and explain each color choice.
# ```

# %%
# ── Exercise 7 Starter: BAD chart — every bar a different saturated color ────────
products    = ['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon', 'Zeta']
unit_sales  = [4820, 3150, 6740, 2980, 5610, 1890]   # monthly units
bad_ex7_colors = ['#E53935', '#8E24AA', '#1E88E5', '#43A047', '#FB8C00', '#00ACC1']

fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(products, unit_sales, color=bad_ex7_colors, edgecolor='white', linewidth=1)

ax.set_title('Monthly Unit Sales by Product', fontsize=16, fontweight='bold')
ax.set_xlabel('Product', fontsize=13)
ax.set_ylabel('Units Sold', fontsize=13)
ax.grid(True, axis='y', alpha=0.4)

fig.text(0.1, -0.03, 'Source: Simulated product sales data — FY',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Re-using the PALETTE defined in setup004a1b2c3d4e5 for consistent colors
# Ensure PALETTE is defined if running this cell independently
if 'PALETTE' not in globals():
    PALETTE = {
        'primary':   '#4B2E83',
        'gold':      '#E8B923',
        'dark':      '#32006E',
        'lavender':  '#B7A6D5',
        'tan':       '#85714D',
        'red':       '#C62828',
        'blue':      '#1976D2',
        'orange':    '#F57C00',
        'green':     '#388E3C',
        'purple':    '#7B1FA2',
        'neutral':   '#CCCCCC',
        'neutral2':  '#AAAAAA',
        'bg':        '#FAFAFA',
    }

# Data from starter code
products    = ['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon', 'Zeta']
unit_sales  = [4820, 3150, 6740, 2980, 5610, 1890]   # monthly units

# Identify top performer and calculate average
top_product_idx = np.argmax(unit_sales)
top_product_name = products[top_product_idx]
top_product_sales = unit_sales[top_product_idx]

total_sales = sum(unit_sales)
overall_average_sales = np.mean(unit_sales)

# Define colors based on 70-20-10 rule
colors = [PALETTE['neutral']] * len(products)
colors[top_product_idx] = PALETTE['gold'] # 10% accent: top product in gold

fig, ax = plt.subplots(figsize=(10, 6))

bars = ax.bar(products, unit_sales, color=colors, edgecolor='white', linewidth=1)

# Add a muted dashed line for the monthly sales average (20% supporting)
ax.axhline(overall_average_sales, color=PALETTE['lavender'], linestyle='--', linewidth=2,
           label=f'Monthly Average: {overall_average_sales:.0f} units')

# Add data labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 50, # Adjusted padding
            f'{yval}', ha='center', va='bottom', fontsize=10, color=PALETTE['dark'])

# Annotation for the top performer (10% accent)
# Calculate percentage of total revenue for the top product
pct_of_total = (top_product_sales / total_sales) * 100
ax.annotate(f'{top_product_name} is the top performer:\n{top_product_sales} units ({pct_of_total:.1f}% of total)',
            xy=(top_product_idx, top_product_sales),
            xytext=(top_product_idx + 0.5, top_product_sales + 700),
            arrowprops=dict(facecolor=PALETTE['gold'], shrink=0.05, width=1.5, headwidth=5), # Changed headwidth from 8 to 5
            fontsize=10, color=PALETTE['dark'], fontweight='bold',
            bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=PALETTE['gold'], lw=1))


ax.set_title('Monthly Unit Sales by Product (Gamma Leads)',
             fontsize=16, fontweight='bold', color=PALETTE['primary'], pad=20)
ax.set_xlabel('Product', fontsize=13, color=PALETTE['dark'])
ax.set_ylabel('Units Sold', fontsize=13, color=PALETTE['dark'])
ax.grid(True, axis='y', alpha=0.3, color=PALETTE['neutral'])
ax.set_axisbelow(True)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_edgecolor(PALETTE['neutral'])
ax.spines['bottom'].set_edgecolor(PALETTE['neutral'])

ax.set_ylim(0, max(unit_sales) * 1.3) # Adjust y-limit for annotations
ax.legend(loc='upper left', frameon=False, fontsize=10)

fig.text(0.1, -0.05, 'Source: Simulated product sales data — FY',
         fontsize=9, color=PALETTE['neutral2'], style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Written Questions — Exercise 7**
#
# 1. Which product is the top performer, and what percentage of total monthly sales does it represent? ___
# The Gamma product is the top performer, with 6,740 monthly unit sales. It represent 26.8% of the total sales.
#
# 2. In your corrected chart, explain the role of each color you chose and which of the three 70-20-10 tiers it belongs to. ___
# we have three colors in this graph, a dark purple, a golden yellow, and a grey midtown. 70 percent of the graph is grey, with the golden yellow as the 20% highlight, and the purple color is the 10% accent color.
#
# 3. What information does the average line add that the bars alone do not convey? ___
# It shows what the standard sale is for all the products combined, and how much more the Gamma product outperformed. Also, this could be useful in showing that the average doesnt always tell the full story.
#
# 4. If you were presenting this chart to an executive, what one sentence would you say out loud to direct their attention? ___
#
# The gamma product outperformed all other test units, with roughtly 27% of the total sales attributed to this line.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 8 — Dashboard Color Consistency</h3>
# </div>
#
# The starter code below produces a 2×2 dashboard of KPI charts for a retail chain. Each panel uses a completely different color scheme — the viewer cannot tell that these four charts belong to the same report.
#
# 🎯 **Task:**
# 1. Run the starter code to observe the inconsistency.
# 2. Redesign all four panels so they share a consistent palette following 70-20-10:
#    - Define a single `PALETTE` dictionary at the top (base, supporting, accent).
#    - Assign the same color to the same category (region/metric) across all panels.
#    - Use one shared accent color to highlight the single most important data point across the entire dashboard.
#    - Ensure all four panels have the same figure background, axes background, and gridline style.
# 3. Add a shared color-role legend to the figure (not inside individual subplots).
# 4. Answer the written questions below.
#
# 💬 **LLM Prompt**
# ```
# I have a 2x2 matplotlib dashboard with 4 KPI subplots.
# Each subplot currently uses a completely different color scheme.
# Help me unify the dashboard using the 70-20-10 color rule:
# - All panels share the same neutral background and gridline style
# - The same category always gets the same color across panels
# - One accent color highlights the single most important KPI insight
# - A shared legend explains the 70/20/10 color roles
# Show the full corrected matplotlib code.
# ```

# %%
# ── Exercise 8 Starter: BAD — 4 panels with completely different color schemes ───
np.random.seed(99)

ex8_regions     = ['North', 'South', 'East', 'West']
ex8_rev         = [52.1, 38.4, 29.7, 21.3]
ex8_growth      = [8.2, 5.1, 11.4, 3.7]
ex8_months      = months
ex8_cust_count  = np.random.randint(800, 1400, 12)
ex8_ret_rate    = np.random.uniform(0.62, 0.85, 12)

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.patch.set_facecolor('#E3F2FD')  # Inconsistent blue background
fig.suptitle('Retail KPI Dashboard', fontsize=18, fontweight='bold')

# Panel 1: Revenue — rainbow colors
ax1 = axes[0, 0]
ax1.set_facecolor('#FFF9C4')
ax1.bar(ex8_regions, ex8_rev, color=['#FF1744', '#00E676', '#2979FF', '#FFEA00'])
ax1.set_title('Annual Revenue by Region ($M)', color='#FF1744')

# Panel 2: Growth — monochrome green
ax2 = axes[0, 1]
ax2.set_facecolor('#F1F8E9')
ax2.barh(ex8_regions, ex8_growth, color='#43A047')
ax2.set_title('YoY Growth Rate (%)', color='#1B5E20')

# Panel 3: Customer count — random scatter
ax3 = axes[1, 0]
ax3.set_facecolor('#FCE4EC')
ax3.scatter(range(12), ex8_cust_count,
            c=['#E91E63','#9C27B0','#673AB7','#3F51B5',
               '#2196F3','#03A9F4','#00BCD4','#009688',
               '#4CAF50','#8BC34A','#CDDC39','#FFEB3B'],
            s=100)
ax3.set_title('Monthly Active Customers', color='#880E4F')

# Panel 4: Retention — orange line on dark background
ax4 = axes[1, 1]
ax4.set_facecolor('#263238')
ax4.plot(range(12), ex8_ret_rate * 100, color='#FF6D00', linewidth=3, marker='D')
ax4.set_title('Customer Retention Rate (%)', color='#FF6D00')
ax4.tick_params(colors='white')
for spine in ax4.spines.values():
    spine.set_edgecolor('white')

for ax in axes.flat:
    ax.tick_params(axis='x', rotation=20)

fig.text(0.5, -0.02,
    '⚠ BAD: Four panels, four completely different color schemes and backgrounds.',
    ha='center', fontsize=10, color='#C62828', style='italic')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')

np.random.seed(99)

# Re-use the PALETTE defined in setup004a1b2c3d4e5 for consistent colors
# Ensure PALETTE is defined if running this cell independently
PALETTE = {
    'primary':   '#4B2E83',
    'gold':      '#E8B923',
    'dark':      '#32006E',
    'lavender':  '#B7A6D5',
    'tan':       '#85714D',
    'red':       '#C62828',
    'blue':      '#1976D2',
    'orange':    '#F57C00',
    'green':     '#388E3C',
    'purple':    '#7B1FA2',
    'neutral':   '#CCCCCC',
    'neutral2':  '#AAAAAA',
    'bg':        '#FAFAFA',
}

# --- Data (from starter code, made accessible globally) ---
ex8_regions     = ['North', 'South', 'East', 'West']
ex8_rev         = [52.1, 38.4, 29.7, 21.3]
ex8_growth      = [8.2, 5.1, 11.4, 3.7]
ex8_months      = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                   'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
ex8_cust_count  = np.random.randint(800, 1400, 12)
ex8_ret_rate    = np.random.uniform(0.62, 0.85, 12)

# --- Define consistent colors for regions and general elements ---
region_colors_map = {
    'North': PALETTE['primary'],
    'South': PALETTE['lavender'],
    'East':  PALETTE['tan'], # Will be overridden by ACCENT for the main KPI
    'West':  PALETTE['neutral']
}

# --- Determine the single most important KPI to accent with GOLD ---
# East region has the highest growth rate (11.4%), making it the overall accent KPI.
accent_region = 'East'
accent_kpi_value = max(ex8_growth)

# --- Setup the figure and shared styles ---
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.patch.set_facecolor(PALETTE['bg']) # 70% neutral base background
fig.suptitle('Retail KPI Dashboard - Unified View', fontsize=18, fontweight='bold', color=PALETTE['primary'], y=1.02)

# --- Panel 1: Annual Revenue by Region ($M) ---
ax1 = axes[0, 0]
ax1.set_facecolor('white') # 70% neutral axes background

# Highlight highest revenue (North) with primary color, others neutral
max_rev_region = ex8_regions[np.argmax(ex8_rev)]
rev_colors = [region_colors_map[r] if r == max_rev_region else PALETTE['neutral'] for r in ex8_regions]

bars1 = ax1.bar(ex8_regions, ex8_rev, color=rev_colors, edgecolor='white', linewidth=1)
ax1.set_title('Annual Revenue by Region ($M)', fontsize=13, fontweight='bold', color=PALETTE['primary'])
ax1.set_ylabel('Revenue ($M)', fontsize=11)
ax1.tick_params(axis='x', rotation=30)
ax1.grid(True, axis='y', alpha=0.3, color=PALETTE['neutral']) # Consistent gridline style
ax1.spines[['top', 'right']].set_visible(False) # Remove chartjunk
ax1.set_ylim(0, max(ex8_rev) * 1.2)
for bar in bars1:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval + 1, f'${yval:.1f}M', ha='center', va='bottom', fontsize=9, color=PALETTE['dark'])

# --- Panel 2: YoY Growth Rate (%) ---
ax2 = axes[0, 1]
ax2.set_facecolor('white') # 70% neutral axes background

# Highlight overall accent KPI (East) with gold, others neutral
growth_colors = [PALETTE['gold'] if r == accent_region else PALETTE['neutral'] for r in ex8_regions]

bars2 = ax2.barh(ex8_regions, ex8_growth, color=growth_colors, edgecolor='white', linewidth=1)
ax2.set_title('YoY Growth Rate (%)', fontsize=13, fontweight='bold', color=PALETTE['primary'])
ax2.set_xlabel('Growth (%)', fontsize=11)
ax2.grid(True, axis='x', alpha=0.3, color=PALETTE['neutral']) # Consistent gridline style
ax2.spines[['top', 'right']].set_visible(False) # Remove chartjunk
ax2.set_xlim(0, max(ex8_growth) * 1.3)
for bar in bars2:
    xval = bar.get_width()
    ax2.text(xval + 0.5, bar.get_y() + bar.get_height()/2, f'{xval:.1f}%', va='center', fontsize=9, color=PALETTE['dark'])
ax2.annotate('Overall KPI: Highest Growth', xy=(max(ex8_growth), accent_region), xytext=(max(ex8_growth) + 1.5, accent_region),
             color=PALETTE['gold'], fontsize=9, fontweight='bold', ha='left', va='center',
             arrowprops=dict(arrowstyle='->', color=PALETTE['gold'], lw=1.2, shrinkA=0.05, shrinkB=0.05))

# --- Panel 3: Monthly Active Customers ---
ax3 = axes[1, 0]
ax3.set_facecolor('white') # 70% neutral axes background

# Use primary color for line, highlight max with gold, others neutral
max_cust_idx = np.argmax(ex8_cust_count)
scatter_colors = [PALETTE['gold'] if i == max_cust_idx else PALETTE['neutral'] for i in range(len(ex8_cust_count))]

ax3.plot(ex8_months, ex8_cust_count, color=PALETTE['primary'], linewidth=1.5, zorder=1) # 20% supporting line
ax3.scatter(ex8_months, ex8_cust_count, c=scatter_colors, s=60, edgecolors='white', linewidth=0.5, zorder=2)
ax3.set_title('Monthly Active Customers', fontsize=13, fontweight='bold', color=PALETTE['primary'])
ax3.set_ylabel('Customers', fontsize=11)
ax3.tick_params(axis='x', rotation=30)
ax3.grid(True, axis='y', alpha=0.3, color=PALETTE['neutral']) # Consistent gridline style
ax3.spines[['top', 'right']].set_visible(False) # Remove chartjunk
ax3.annotate(f'Peak: {ex8_cust_count[max_cust_idx]:,} ({ex8_months[max_cust_idx]})',
             xy=(max_cust_idx, ex8_cust_count[max_cust_idx]), xytext=(max_cust_idx + 1.5, ex8_cust_count[max_cust_idx]),
             color=PALETTE['gold'], fontsize=9, fontweight='bold', ha='left', va='center',
             arrowprops=dict(arrowstyle='->', color=PALETTE['gold'], lw=1.2, shrinkA=0.05, shrinkB=0.05))

# --- Panel 4: Customer Retention Rate (%) ---
ax4 = axes[1, 1]
ax4.set_facecolor('white') # 70% neutral axes background

# Use primary color for line, highlight max with gold, others neutral
max_ret_idx = np.argmax(ex8_ret_rate)
scatter_colors_ret = [PALETTE['gold'] if i == max_ret_idx else PALETTE['neutral'] for i in range(len(ex8_ret_rate))]

ax4.plot(ex8_months, ex8_ret_rate * 100, color=PALETTE['primary'], linewidth=1.5, zorder=1) # 20% supporting line
ax4.scatter(ex8_months, ex8_ret_rate * 100, c=scatter_colors_ret, s=60, edgecolors='white', linewidth=0.5, zorder=2)
ax4.set_title('Customer Retention Rate (%)', fontsize=13, fontweight='bold', color=PALETTE['primary'])
ax4.set_ylabel('Retention (%)', fontsize=11)
ax4.tick_params(axis='x', rotation=30)
ax4.grid(True, axis='y', alpha=0.3, color=PALETTE['neutral']) # Consistent gridline style
ax4.spines[['top', 'right']].set_visible(False) # Remove chartjunk
ax4.annotate(f'Peak: {ex8_ret_rate[max_ret_idx]*100:.1f}% ({ex8_months[max_ret_idx]})',
             xy=(max_ret_idx, ex8_ret_rate[max_ret_idx]*100), xytext=(max_ret_idx + 1.5, ex8_ret_rate[max_ret_idx]*100),
             color=PALETTE['gold'], fontsize=9, fontweight='bold', ha='left', va='center',
             arrowprops=dict(arrowstyle='->', color=PALETTE['gold'], lw=1.2, shrinkA=0.05, shrinkB=0.05))

# --- Shared Color Role Legend ---
legend_elements = [
    mpatches.Patch(facecolor=PALETTE['bg'], label='70% Base: Backgrounds & Structure'),
    mpatches.Patch(facecolor='white', label='Axes Backgrounds'),
    mpatches.Patch(facecolor=PALETTE['neutral'], label='70% Base: Non-highlighted Data'),
    mpatches.Patch(facecolor=PALETTE['primary'], label='20% Supporting: Brand Color / Emphasis'),
    mpatches.Patch(facecolor=PALETTE['gold'], label='10% Accent: Key Insights (East Growth, Peak Values)')
]
fig.legend(handles=legend_elements, loc='lower center', ncol=3,
           fontsize=10, frameon=True, fancybox=True, bbox_to_anchor=(0.5, -0.08))

fig.text(0.5, -0.02,
    '✓ CORRECTED: Unified color scheme with 70-20-10 hierarchy and East Growth as overall KPI.',
    ha='center', fontsize=11, color=PALETTE['green'], style='italic')

plt.tight_layout(rect=[0, 0.08, 1, 0.98]) # Adjust layout to make space for suptitle and shared legend
plt.show()

# %% [markdown]
# **Written Questions — Exercise 8**
#
# 1. List the specific hex codes you assigned to the 70% (base), 20% (supporting), and 10% (accent) roles in your dashboard. ___
# PALETTE['primary'] (UW Purple): #4B2E83
# PALETTE['gold'] (UW Gold): #E8B923
# PALETTE['neutral'] (Light Grey for non-highlighted data): #CCCCCC
# PALETTE['lavender'] (Muted Purple for supporting elements): #B7A6D5
# PALETTE['dark'] (Dark Grey for text/labels): #32006E
# PALETTE['bg'] (Background): #FAFAFA
# PALETTE['neutral2'] (Lighter Grey for source text): #AAAAAA
# PALETTE['green'] (Green for success/corrected messages): #388E3C
# White (for axes background, bar edges, etc.): #FFFFFF
#
# 2. Which metric/region did you choose to highlight with the accent color, and why? ___
# Mainly the peaks, or largest values. Usually thats what people want to see, unless were talking about losses. This dashboard is talking about growth rates and revenues, usually meaning the largest value should the first thing people look at.
#
# 3. In the bad chart, the retention panel uses a dark background while the others use light backgrounds. What specific cognitive problem does this create for the viewer? ___
# This creates nice contrast but also confusion because no plot points or axis labels can be seen.
#
# 4. How does the shared color legend you added help a viewer who looks at the dashboard for the first time? ___
# It harmonizes the whole project and can teach people what color to expect for what statistic, ex blue for lows, reds for highs, etc.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 9 — Highlight the Anomaly</h3>
# </div>
#
# The starter code below shows a scatter plot of server response times (ms) vs. request volume for 120 hourly observations. All 120 points are rendered identically. Hidden in the data is one critical observation where response time spiked to an unacceptable level — an outage signature that the on-call team should have caught immediately.
#
# 🎯 **Task:**
# 1. Run the starter code to confirm the anomaly is invisible.
# 2. Identify the outlier: it is the observation where response time exceeds 3 standard deviations above the mean.
# 3. Redesign the scatter plot using 70-20-10:
#    - 70 % — all normal observations in neutral gray `#CCCCCC`.
#    - 20 % — draw the expected trend or a horizontal threshold line in a muted brand color.
#    - 10 % — the anomalous point(s) in bold `#C62828` (red) to signal a problem.
# 4. Add an annotation on the anomaly explaining what the value is and why it is a concern.
# 5. Answer the written questions below.
#
# 💬 **LLM Prompt**
# ```
# I have a scatter plot with 120 server response time observations.
# One point is a major outlier (response time > mean + 3 std dev).
# Currently all points look identical.
# Redesign the chart using the 70-20-10 color rule:
# - 70%: all normal points in neutral gray
# - 20%: an SLA threshold line in muted brand color
# - 10%: the anomaly in bold red with an annotation
# Show the full matplotlib code.
# ```

# %%
# ── Exercise 9 Starter: BAD — all points identical, anomaly invisible ─────────────
np.random.seed(17)

n_obs    = 119
req_vol  = np.random.randint(200, 1800, n_obs)           # requests per hour
resp_t   = 80 + req_vol * 0.04 + np.random.normal(0, 15, n_obs)  # response time (ms)

# Hidden anomaly: high volume AND extreme response time (outage signature)
anomaly_vol  = np.array([1650])
anomaly_resp = np.array([resp_t.mean() + 3.8 * resp_t.std()])   # ~3.8 std above mean

all_vol  = np.concatenate([req_vol, anomaly_vol])
all_resp = np.concatenate([resp_t, anomaly_resp])

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(all_vol, all_resp, color='#1E88E5', s=60, alpha=0.7,
           edgecolors='white', linewidth=0.4)

ax.set_title('Server Response Time vs. Request Volume', fontsize=16, fontweight='bold')
ax.set_xlabel('Request Volume (per hour)', fontsize=13)
ax.set_ylabel('Response Time (ms)', fontsize=13)
ax.grid(True, alpha=0.4)

fig.text(0.1, -0.03, 'Source: Simulated server monitoring data',
         fontsize=9, color='#888', style='italic')

fig.text(0.5, -0.07,
    '⚠ BAD: 120 identical blue dots. The critical outage signature is completely hidden.',
    ha='center', fontsize=10, color='#C62828', style='italic')

plt.tight_layout()
plt.show()

# %%
# ── Exercise 9: Your corrected chart here ────────────────────────────────────────
# Use req_vol, resp_t, anomaly_vol, anomaly_resp defined above.
# Apply 70-20-10: neutral gray for normal points, muted SLA line, red accent for the anomaly.

# YOUR CODE HERE

# %%
import numpy as np
import matplotlib.pyplot as plt

# Re-using the PALETTE defined earlier
PALETTE = {
    'primary':   '#4B2E83',
    'gold':      '#E8B923',
    'dark':      '#32006E',
    'lavender':  '#B7A6D5',
    'tan':       '#85714D',
    'red':       '#C62828',
    'blue':      '#1976D2',
    'orange':    '#F57C00',
    'green':     '#388E3C',
    'purple':    '#7B1FA2',
    'neutral':   '#CCCCCC',
    'neutral2':  '#AAAAAA',
    'bg':        '#FAFAFA',
}

# --- Data (from starter code, re-defined for clarity in this cell) ---
np.random.seed(17)
n_obs    = 119
req_vol_normal  = np.random.randint(200, 1800, n_obs)
resp_t_normal   = 80 + req_vol_normal * 0.04 + np.random.normal(0, 15, n_obs)

anomaly_vol  = np.array([1650])
anomaly_resp = np.array([resp_t_normal.mean() + 3.8 * resp_t_normal.std()])

# Separate normal points from the anomaly
# Note: all_resp and all_vol were not defined in this cell, assuming they are defined globally or data generation is self-contained
# For this fix, I'll proceed as if req_vol_normal and resp_t_normal represent 'normal' points
# and anomaly_vol/resp represent the anomaly, ensuring all points are used for min/max calculations later.

# Calculate mean and std dev for normal response times to define SLA
mean_resp = resp_t_normal.mean()
std_resp = resp_t_normal.std()
sla_threshold = mean_resp + 3 * std_resp # 3 standard deviations above mean

fig, ax = plt.subplots(figsize=(10, 6))
fig.patch.set_facecolor(PALETTE['bg'])
ax.set_facecolor('white')

# 70% Neutral: Plot normal observations
ax.scatter(req_vol_normal, resp_t_normal,
           color=PALETTE['neutral'], s=60, alpha=0.7,
           edgecolors='white', linewidth=0.4, label='Normal Observations', zorder=2)

# 20% Supporting: SLA threshold line
ax.axhline(y=sla_threshold, color=PALETTE['lavender'], linestyle='--', linewidth=2,
           label=f'SLA Threshold (Mean + 3 Std Dev: {sla_threshold:.1f}ms)', zorder=1)

# 10% Accent: Anomalous point in bold red
ax.scatter(anomaly_vol, anomaly_resp,
           color=PALETTE['red'], s=150, edgecolors='white', linewidth=1.5,
           marker='o', label='Critical Anomaly', zorder=3)

# Annotation for the anomaly
ax.annotate(f'Critical Outage Detected!\nResponse Time: {anomaly_resp[0]:.1f}ms (>{sla_threshold:.1f}ms)',
            xy=(anomaly_vol[0], anomaly_resp[0]),
            xytext=(anomaly_vol[0] - 500, anomaly_resp[0] + 40),
            color=PALETTE['red'], fontsize=10, fontweight='bold',
            arrowprops=dict(arrowstyle='->', color=PALETTE['red'], lw=1.5))

ax.set_title('Server Response Time vs. Request Volume - Critical Anomaly Highlighted',
             fontsize=16, fontweight='bold', color=PALETTE['primary'], pad=15)
ax.set_xlabel('Request Volume (per hour)', fontsize=13, color=PALETTE['dark'])
ax.set_ylabel('Response Time (ms)', fontsize=13, color=PALETTE['dark'])

# Remove chartjunk
ax.spines[['top', 'right']].set_visible(False)
ax.grid(True, alpha=0.3, color=PALETTE['neutral'])
ax.set_axisbelow(True)

# Adjust limits for better visibility
# Combine all response times and request volumes to correctly determine limits
all_responses = np.concatenate([resp_t_normal, anomaly_resp])
all_volumes = np.concatenate([req_vol_normal, anomaly_vol])
ax.set_ylim(min(0, all_responses.min() - 20), max(all_responses.max() + 50, sla_threshold + 50))
ax.set_xlim(min(all_volumes.min() - 100, anomaly_vol.min() - 200), max(all_volumes.max() + 100, anomaly_vol.max() + 200))

fig.text(0.1, -0.02, 'Source: Simulated server monitoring data',
         fontsize=9, color=PALETTE['neutral2'], style='italic')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Written Questions — Exercise 9**
#
# 1. What is the approximate response time of the anomalous observation, and how many standard deviations above the mean does it fall? ___ the approximate response time is 208.2 milliseconds, about 3.8 standard deviations above the mean, enouhg to be considered an anomaly.
#
# 2. Why is using neutral gray for the normal points essential — not just aesthetic — in an alerting context? ___ because read signals an alert. using gray around it makes it easier for the reader to see what is important.
#
# 3. You used red for the anomaly. Referring to the emotional perception of color theory, why is red the appropriate choice here rather than, say, gold or blue? ___
# Red indicates danger. Humans see red as something alarming or attention grabbing, which is why this would make the most sense. Intrinsically, it would incite some level of not necesarily fear, but more attentiveness.
#
# 4. The annotation you added explains the anomaly. What additional context would make the annotation even more actionable for an on-call engineer? ___ Maybe more words that explain how slow or fast the response time was?

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 10px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h2 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">End of Section 3 — Color Theory for Data Visualization</h2>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.2em; margin: 10px 0; font-weight: 300;">Remember: color is a tool for communication, not decoration. Use it with intention.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);"><h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Section 4: Common Misleading Graph Types</h1><p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">How Honest Data Can Be Made to Lie</p></div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Learning Objectives</h2>
# <p style="font-size: 1.05em; color: #555; line-height: 1.7;">By the end of this section you will be able to:</p>
# <ol style="font-size: 1.05em; color: #555; line-height: 1.9;">
# <li><strong>Identify</strong> at least twelve common techniques used to produce misleading visualisations.</li>
# <li><strong>Explain</strong> the psychological mechanism behind each deception — why it fools the reader's eye.</li>
# <li><strong>Critique</strong> real-world charts, naming the specific flaw and its effect on interpretation.</li>
# <li><strong>Correct</strong> misleading charts in Python by applying best-practice fixes.</li>
# <li><strong>Apply</strong> LLM-assisted prompting to audit and improve your own visualisations.</li>
# </ol></div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);"><h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">4.A — Taxonomy of Misleading Techniques</h1><p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Twelve Patterns Every Data Practitioner Must Recognise</p></div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">1. Truncated Y-Axis</h2></div>
#
# **What it is:** The y-axis starts well above zero, so differences that are small in absolute terms appear enormous.
#
# **Why it deceives:** Human perception encodes magnitude through bar height. A bar twice as tall reads as "twice as large" — even when the actual difference is 3 %.
#
# **The fix:** Start bar-chart y-axes at 0. When a zoomed view genuinely helps (e.g., showing subtle variation in a line chart), label the axis break clearly with a jagged-line symbol and note the truncation in the caption.
#
# > **Classic example:** Fox News repeatedly aired bar charts of tax rates with y-axes starting at 33 %, making a rate change from 35 % to 39.6 % look like a tripling.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">2. Manipulated Scales (Non-Linear Without Disclosure)</h2></div>
#
# **What it is:** A logarithmic or otherwise non-linear axis is used without any label or warning, compressing large values and making exponential growth look linear.
#
# **Why it deceives:** Readers assume linear spacing by default. On a log scale, the visual distance from 10 to 100 equals the distance from 100 to 1,000 — a 10× difference looks identical to a 900× difference.
#
# **The fix:** Label log axes explicitly (e.g., "log scale" in the axis title). Add a note in the caption. When in doubt, provide both a linear and a log panel side by side.
#
# > **When log scales ARE appropriate:** Displaying data spanning multiple orders of magnitude (e.g., COVID case counts during an exponential phase), or comparing growth rates rather than absolute levels.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">3. Cherry-Picked Date Windows</h2></div>
#
# **What it is:** The chart shows only a subset of the available time range — the subset that best supports the desired narrative.
#
# **Why it deceives:** A three-month rally in a flat or declining annual trend looks like proof of success. The reader has no reference point for what happened before or after the window.
#
# **The fix:** Always show the full available history, or explicitly justify and label any zoom window. A small inset panel showing the full range with the zoomed region highlighted is best practice.
#
# > **Rule:** If you chose your date range *after* looking at the data, you are almost certainly cherry-picking. Pre-register your time window before visualising.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">4. Misleading Cumulative Charts</h2></div>
#
# **What it is:** Plotting cumulative totals (always increasing by definition) instead of period-by-period values to mask a slowdown or decline.
#
# **Why it deceives:** A cumulative line never goes down. New signups, revenue, or cases can be dropping week-over-week, but the cumulative curve still rises — creating a false impression of continued growth.
#
# **The fix:** Show both the cumulative total *and* the periodic (weekly/monthly) change. When reporting growth, use the periodic chart as the primary view and reserve cumulative charts for contexts where total size is the meaningful metric (e.g., total vaccines administered).
#
# > **Tip:** Always ask: *Is the question about total stock or about flow?* Cumulative = stock. Period-over-period = flow.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">5. Dual-Axis Deception</h2></div>
#
# **What it is:** Two completely unrelated variables are plotted on a single chart using different left and right y-axes. By rescaling either axis, the maker can manufacture visual correlation between any two time series.
#
# **Why it deceives:** Lines that cross or run in parallel trigger a strong correlation inference in the reader's brain. The axes are freely rescalable, so *any* two trending series can be made to look related.
#
# **The fix:** Use dual axes only when both variables share a meaningful relationship (e.g., temperature in °C and °F, or price and volume of the *same* asset). For genuinely separate metrics, use two side-by-side charts with consistent x-axes.
#
# > **Famous example:** Charts showing that Nicolas Cage films and US pool drownings both rose together in the 2000s — a classic spurious correlation.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">6. Distorted Aspect Ratios</h2></div>
#
# **What it is:** Making a chart very wide and short (or very tall and narrow) to flatten or exaggerate the slope of a trend line.
#
# **Why it deceives:** A 45° slope is the most visually neutral representation of a trend. Extreme aspect ratios turn gradual changes into alarmist spikes, or dramatic changes into boring flatlines.
#
# **The fix:** Follow Cleveland's (1993) *banking to 45°* principle: adjust the aspect ratio so that the average absolute slope of the line segments is approximately 45°. Matplotlib's `ax.set_aspect('equal')` or manual figure sizing helps.
#
# > **Practical rule:** If your trend line hugs either the top or bottom of the chart, your aspect ratio is likely misleading.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">7. 3D Distortion</h2></div>
#
# **What it is:** Adding a false third dimension (perspective/depth) to a 2D chart — most commonly pie charts and bar charts — purely for aesthetic effect.
#
# **Why it deceives:** Perspective projection changes the apparent size of elements based on their position. Slices at the front of a 3D pie chart look larger than equally-sized slices at the back. Bars near the viewer appear taller.
#
# **The fix:** Never use 3D effects on charts that encode data in 2D. Replace 3D pie charts with flat pie charts or, better, horizontal bar charts. Remove all decorative depth.
#
# > **Edward Tufte** called chartjunk — including 3D effects — "the interior decoration of statistics": it increases ink without increasing information.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">8. Area Exaggeration (Scaling by Radius Instead of Area)</h2></div>
#
# **What it is:** When using circles or icons to represent quantities, the *radius* (or side length) is scaled proportionally to the value rather than the *area* — causing the larger symbol to be dramatically over-sized.
#
# **Why it deceives:** If Country A has twice the GDP of Country B and you double the radius of its circle, its *area* is four times larger (area = π r²), making the difference look four-fold rather than two-fold.
#
# **The fix:** Scale the area, not the radius. In matplotlib, pass `s = value` to `ax.scatter()` (bubble area) or compute `radius = sqrt(value / pi)` manually. Always include a size legend with labelled reference bubbles.
#
# > **Rule:** `marker_size ∝ sqrt(value)` for radius-based markers; `marker_area ∝ value`.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">9. Overloaded Pie Charts</h2></div>
#
# **What it is:** A pie chart with too many slices (often 7 or more), many of which are similarly sized, forcing readers to rely on labels rather than visual angles.
#
# **Why it deceives:** Human perception of angles is poor; we cannot reliably distinguish between a 12 % slice and a 15 % slice. When many thin slices cluster together, the chart communicates almost nothing visually.
#
# **The fix:** Use a pie chart only for 2–5 categories where one or two slices clearly dominate. For more categories, use a horizontal bar chart sorted by magnitude — bar length is a far more accurate perceptual encoding than angle.
#
# > **Guideline:** If you need a legend to read a pie chart, it's probably the wrong chart type.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">10. Bubble Chart Misuse</h2></div>
#
# **What it is:** Bubble charts where the size encoding is inconsistent, unlabelled, or scaled by radius rather than area — so the visual comparison between bubbles is meaningless.
#
# **Why it deceives:** Without a size legend that shows what a given bubble area means, readers cannot translate visual size into a data value. Combined with radius scaling (see #8), bubbles become pure decoration.
#
# **The fix:** Always include a size legend with at least three reference bubbles at known values. Scale by area. Choose bubble sizes so the chart is not visually dominated by a single huge bubble that obscures the others.
#
# > **Extra caution:** Overlapping bubbles should use transparency (`alpha`) and be clearly acknowledged in the caption.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">11. Misleading Choropleth Maps (Population vs. Per-Capita)</h2></div>
#
# **What it is:** A choropleth map colours regions by a raw count (e.g., total COVID cases, total crime incidents) rather than a rate (cases per 100,000 people), making densely populated regions look like outliers simply because they have more people.
#
# **Why it deceives:** Large, sparsely populated states dominate the eye by area even if they have low per-capita rates. Dense urban states look "worse" on raw-count maps for any metric that scales with population.
#
# **The fix:** Normalise by population (or land area, or some other denominator appropriate to the question). Always state in the title whether you are showing a count or a rate. When both views are relevant, show them side by side.
#
# > **Classic trap:** Maps of total opioid deaths by US state make rural states look safe. Per-capita maps tell a very different story.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">12. Unequal Bin Widths in Histograms</h2></div>
#
# **What it is:** A histogram where bins are not all the same width, but the y-axis shows *frequency* (count) rather than *frequency density* (count ÷ bin width). Wide bins look like they contain more observations than they actually do per unit of the x-axis.
#
# **Why it deceives:** A bin of width 20 that spans ages 60–80 and contains 40 people looks as "tall" as a bin of width 5 spanning ages 20–25 that contains 40 people — but the older-age group is actually 4× less dense per year.
#
# **The fix:** If you use unequal bins, plot *density* on the y-axis (use `density=True` in matplotlib). Better still, use equal-width bins unless there is a strong domain reason for variable widths (e.g., age-standardised epidemiological tables). Always label what the y-axis represents.
#
# > **Matplotlib tip:** `ax.hist(data, bins=[...], density=True)` automatically converts to frequency density.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);"><h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">4.B — Python Demonstrations</h1><p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Seeing the Deception — and the Fix — in Code</p></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.prop_cycle'] = plt.cycler(
    color=['#4B2E83', '#E8B923', '#32006E', '#85714D', '#B7A6D5',
           '#C62828', '#1976D2', '#F57C00', '#388E3C', '#7B1FA2'])

np.random.seed(42)
print('Setup complete ✓')
# Out:
# Setup complete ✓

# %% [markdown]
# <div style="border-left: 5px solid #C62828; background-color: #FFF8F8; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo 1A — Bad Example: Truncated Y-Axis</h2></div>
#
# The four bars below show quarterly revenue for a retail company. The y-axis starts at **95** instead of **0**. The difference between Q1 and Q4 is just **3 %** — but the chart makes Q4 look roughly **10x** taller than Q1, implying an explosive growth story that does not exist in the data.

# %%
# Simulated quarterly revenue (in $M) — a 3 % increase from Q1 to Q4
quarters = ['Q1 2024', 'Q2 2024', 'Q3 2024', 'Q4 2024']
revenue  = [97.2, 98.1, 99.0, 100.2]   # range: 97.2 to 100.2 — a ~3 % spread

fig, ax = plt.subplots(figsize=(9, 6))
bars = ax.bar(quarters, revenue, color='#C62828', edgecolor='white', linewidth=1.5)

# ---- THE DECEPTION: y-axis starts at 95, NOT 0 ----
ax.set_ylim(95, 102)

for bar, val in zip(bars, revenue):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
            f'${val:.1f}M', ha='center', va='bottom', fontsize=11, fontweight='bold')

ax.set_title('Quarterly Revenue — MISLEADING (truncated axis)',
             fontsize=14, fontweight='bold', color='#C62828')
ax.set_xlabel('Quarter', fontsize=12)
ax.set_ylabel('Revenue ($M)  \u26a0 y-axis starts at 95!', fontsize=12, color='#C62828')
ax.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated retail revenue data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

print(f'Actual Q1-to-Q4 change: +${revenue[-1]-revenue[0]:.1f}M  '
      f'= +{(revenue[-1]/revenue[0]-1)*100:.1f}%')
print('Yet the bar for Q4 appears ~10x taller than Q1 in this chart!')

# %% [markdown]
# <div style="border-left: 5px solid #388E3C; background-color: #F5FBF5; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #388E3C; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo 1B — Corrected: Y-Axis Starting at Zero</h2></div>
#
# The corrected version starts at **0** and annotates the actual percentage change. The bars are now nearly identical in height — faithfully representing a modest 3 % improvement.

# %%
fig, ax = plt.subplots(figsize=(9, 6))
bars = ax.bar(quarters, revenue, color='#388E3C', edgecolor='white', linewidth=1.5)

# ---- THE FIX: y-axis starts at 0 ----
ax.set_ylim(0, 115)

for bar, val in zip(bars, revenue):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.8,
            f'${val:.1f}M', ha='center', va='bottom', fontsize=11, fontweight='bold')

# Annotate the actual change
pct_change = (revenue[-1] / revenue[0] - 1) * 100
ax.annotate(
    f'Q1 \u2192 Q4: +{pct_change:.1f}% actual growth',
    xy=(3, revenue[-1]), xytext=(2.2, 108),
    arrowprops=dict(arrowstyle='->', color='#333', lw=1.5),
    fontsize=11, color='#333',
    bbox=dict(boxstyle='round,pad=0.3', facecolor='#E8F5E9', edgecolor='#388E3C')
)

ax.set_title('Quarterly Revenue — CORRECTED (y-axis from 0)',
             fontsize=14, fontweight='bold', color='#388E3C')
ax.set_xlabel('Quarter', fontsize=12)
ax.set_ylabel('Revenue ($M)', fontsize=12)
ax.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated retail revenue data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #C62828; background-color: #FFF8F8; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo 2A — Bad Example: Cherry-Picked Date Window</h2></div>
#
# This line chart shows monthly online sales for an e-commerce company. Only the **3 best consecutive months** (April–June) are displayed, making the business look like it has strong upward momentum — when the full annual picture tells a very different story.

# %%
# Simulated monthly online sales ($K) — a flat-to-declining year with one seasonal peak
months_full = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sales_full  = [210, 195, 205, 240, 265, 280,   # spring peak
               230, 215, 200, 190, 185, 178]    # steady decline through year-end

# --- CHERRY-PICKED WINDOW: April (index 3) through June (index 5) ---
cherry_months = months_full[3:6]
cherry_sales  = sales_full[3:6]

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(cherry_months, cherry_sales, marker='o', linewidth=2.5, markersize=9,
        color='#C62828')
ax.fill_between(cherry_months, cherry_sales, alpha=0.15, color='#C62828')

ax.set_title('Online Sales — MISLEADING (cherry-picked window: Apr–Jun)',
             fontsize=13, fontweight='bold', color='#C62828')
ax.set_xlabel('Month', fontsize=12)
ax.set_ylabel('Sales ($K)', fontsize=12)
ax.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated e-commerce sales data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

print('Shown: Apr-Jun  (peak season) — looks like strong growth')
print(f'Hidden: Jul-Dec trend:  ${sales_full[6]}K -> ${sales_full[-1]}K  '
      f'({(sales_full[-1]/sales_full[6]-1)*100:.1f}% decline)')

# %% [markdown]
# <div style="border-left: 5px solid #388E3C; background-color: #F5FBF5; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #388E3C; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo 2B — Corrected: Full Time Range with Context</h2></div>
#
# The corrected chart shows all 12 months. The cherry-picked window is shaded so the reader can see exactly what was hidden, and an annotation calls out the post-peak decline.

# %%
fig, ax = plt.subplots(figsize=(11, 6))

ax.plot(months_full, sales_full, marker='o', linewidth=2.5, markersize=8,
        color='#388E3C', label='Monthly sales')

# Shade the cherry-picked window so the reader sees what was hidden
ax.axvspan(2.5, 5.5, alpha=0.12, color='#C62828',
           label='Cherry-picked window (Apr\u2013Jun only)')

# Annotate post-peak decline
ax.annotate(
    f'Post-peak decline:\n${sales_full[6]}K \u2192 ${sales_full[-1]}K\n'
    f'({(sales_full[-1]/sales_full[6]-1)*100:.1f}% Jul\u2013Dec)',
    xy=(10, sales_full[-1]), xytext=(7.2, 230),
    arrowprops=dict(arrowstyle='->', color='#333', lw=1.5),
    fontsize=10, color='#333',
    bbox=dict(boxstyle='round,pad=0.4', facecolor='#FFF3E0', edgecolor='#F57C00')
)

ax.set_title('Online Sales — CORRECTED (full 12-month view)',
             fontsize=14, fontweight='bold', color='#388E3C')
ax.set_xlabel('Month (2024)', fontsize=12)
ax.set_ylabel('Sales ($K)', fontsize=12)
ax.legend(frameon=True, fancybox=True, shadow=True, fontsize=10)
ax.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated e-commerce sales data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #C62828; background-color: #FFF8F8; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo 3 — Dual-Axis Deception vs. Honest Side-by-Side</h2></div>
#
# Two completely unrelated metrics — a company's quarterly **ad spending** and the **average outdoor temperature** in their city — are forced onto a dual-axis chart. By rescaling the right axis, we can make them appear perfectly correlated. The corrected version uses two separate panels.

# %%
quarters_dual = ['Q1', 'Q2', 'Q3', 'Q4']
ad_spend      = [120, 185, 210, 140]   # $K — peaks in summer campaign season
avg_temp      = [38,   62,  78,  45]   # °F  — seasonal temperature, entirely unrelated

# ---- MISLEADING: dual-axis implies correlation ----
fig, ax1 = plt.subplots(figsize=(9, 6))
ax2 = ax1.twinx()

l1, = ax1.plot(quarters_dual, ad_spend, marker='o', linewidth=2.5, markersize=9,
               color='#4B2E83', label='Ad Spend ($K)')
l2, = ax2.plot(quarters_dual, avg_temp, marker='s', linewidth=2.5, markersize=9,
               color='#E8B923', linestyle='--', label='Avg Temp (°F)')

# Scale right axis to align the lines visually
ax2.set_ylim(20, 100)
ax1.set_ylim(80, 260)

ax1.set_xlabel('Quarter', fontsize=12)
ax1.set_ylabel('Ad Spend ($K)', fontsize=12, color='#4B2E83')
ax2.set_ylabel('Avg Temperature (°F)', fontsize=12, color='#E8B923')
ax1.set_title('Ad Spend & Temperature — MISLEADING (dual axis implies correlation)',
              fontsize=12, fontweight='bold', color='#C62828')

lines = [l1, l2]
ax1.legend(lines, [l.get_label() for l in lines],
           frameon=True, fancybox=True, shadow=True, fontsize=10)
ax1.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated marketing and weather data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()
print('These two variables have NO causal relationship. The dual axis manufactured the visual correlation.')

# %%
# ---- CORRECTED: two honest side-by-side panels ----
fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(13, 5))

ax_left.plot(quarters_dual, ad_spend, marker='o', linewidth=2.5,
             markersize=9, color='#4B2E83')
ax_left.set_title('Ad Spend per Quarter', fontsize=13, fontweight='bold', color='#4B2E83')
ax_left.set_xlabel('Quarter', fontsize=12)
ax_left.set_ylabel('Ad Spend ($K)', fontsize=12)
ax_left.set_ylim(0, 250)
ax_left.grid(True, alpha=0.3)

ax_right.plot(quarters_dual, avg_temp, marker='s', linewidth=2.5,
              markersize=9, color='#E8B923', linestyle='--')
ax_right.set_title('Average Temperature per Quarter', fontsize=13, fontweight='bold', color='#85714D')
ax_right.set_xlabel('Quarter', fontsize=12)
ax_right.set_ylabel('Avg Temperature (\u00b0F)', fontsize=12)
ax_right.set_ylim(0, 100)
ax_right.grid(True, alpha=0.3)

fig.suptitle('CORRECTED: Separate panels — no implied correlation',
             fontsize=14, fontweight='bold', color='#388E3C', y=1.03)
fig.text(0.1, -0.03, 'Source: Simulated marketing and weather data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #C62828; background-color: #FFF8F8; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo 4 — 3D Pie Chart vs. Clean Horizontal Bar Chart</h2></div>
#
# A 3D perspective pie chart distorts the apparent size of slices. The front slice ("West") looks larger than it is; the back slices look smaller. The horizontal bar chart below communicates the same information accurately.

# %%
regions  = ['Northeast', 'Southeast', 'Midwest', 'West', 'Southwest']
shares   = [22, 18, 20, 25, 15]   # market share %
explode  = (0, 0, 0, 0.12, 0)     # pull West slice to the front

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# ---- LEFT: 3D-style (wedge shadows + explode + tilt illusion) ----
colors_pie = ['#4B2E83', '#E8B923', '#85714D', '#C62828', '#1976D2']

wedges, texts, autotexts = axes[0].pie(
    shares, labels=regions, colors=colors_pie, autopct='%1.0f%%',
    explode=explode, startangle=200, pctdistance=0.6,
    shadow=True,   # <-- the 3D illusion
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)
for t in autotexts:
    t.set_fontweight('bold'); t.set_color('white'); t.set_fontsize(11)
axes[0].set_title('Market Share by Region\nMISLEADING: 3D distortion exaggerates \'West\'',
                  fontsize=11, fontweight='bold', color='#C62828')

# ---- RIGHT: Honest horizontal bar chart ----
sorted_idx = np.argsort(shares)
sorted_regions = [regions[i] for i in sorted_idx]
sorted_shares  = [shares[i]  for i in sorted_idx]
bar_colors     = [colors_pie[i] for i in sorted_idx]

axes[1].barh(sorted_regions, sorted_shares, color=bar_colors, edgecolor='white', linewidth=1.5)
for i, val in enumerate(sorted_shares):
    axes[1].text(val + 0.3, i, f'{val}%', va='center', fontsize=11, fontweight='bold')
axes[1].set_xlim(0, 32)
axes[1].set_xlabel('Market Share (%)', fontsize=12)
axes[1].set_title('Market Share by Region\nCORRECTED: Horizontal bar (accurate lengths)',
                  fontsize=11, fontweight='bold', color='#388E3C')
axes[1].grid(True, axis='x', alpha=0.3)
axes[1].axvline(20, color='#333', linewidth=0.8, linestyle=':', alpha=0.5)

fig.text(0.1, -0.02, 'Source: Simulated retail market share data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-left: 5px solid #C62828; background-color: #FFF8F8; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #C62828; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Demo 5 — Unequal Histogram Bins That Hide the True Distribution</h2></div>
#
# The left histogram uses deliberately unequal bin widths (wide bins in the upper tail) while plotting raw counts — making the distribution look bimodal. The right histogram uses equal-width bins and reveals the true right-skewed shape.

# %%
# Simulate patient BMI data — log-normal, right-skewed
np.random.seed(7)
bmi = np.random.lognormal(mean=3.3, sigma=0.18, size=800)  # BMI roughly 18–45
bmi = bmi[(bmi >= 15) & (bmi <= 55)]

# Unequal bins: fine resolution in the centre, coarse in the tails
unequal_bins = [15, 18, 20, 22, 24, 26, 28, 30, 35, 40, 55]

fig, (ax_bad, ax_good) = plt.subplots(1, 2, figsize=(14, 6))

# ---- LEFT: unequal bins with COUNT on y-axis ----
ax_bad.hist(bmi, bins=unequal_bins, color='#C62828', edgecolor='white', linewidth=0.8)
ax_bad.set_title('BMI Distribution — MISLEADING\n(unequal bins, count on y-axis)',
                 fontsize=12, fontweight='bold', color='#C62828')
ax_bad.set_xlabel('BMI', fontsize=12)
ax_bad.set_ylabel('Count  (not density!)', fontsize=12, color='#C62828')

# Mark the wide tail bin
ax_bad.axvspan(40, 55, alpha=0.15, color='#F57C00',
               label='Width = 15  \u26a0 inflated count')
ax_bad.legend(fontsize=9)
ax_bad.grid(True, alpha=0.3)

bin_edges = []
for start, end in zip(unequal_bins[:-1], unequal_bins[1:]):
    ax_bad.annotate(f'{end-start}', xy=((start+end)/2, 5),
                    ha='center', fontsize=8, color='#555')

# ---- RIGHT: equal bins with DENSITY on y-axis ----
ax_good.hist(bmi, bins=30, density=True, color='#388E3C', edgecolor='white', linewidth=0.8, alpha=0.85)
ax_good.set_title('BMI Distribution — CORRECTED\n(equal bins, density on y-axis)',
                  fontsize=12, fontweight='bold', color='#388E3C')
ax_good.set_xlabel('BMI', fontsize=12)
ax_good.set_ylabel('Density', fontsize=12)
ax_good.axvline(np.median(bmi), color='#C62828', linewidth=2, linestyle='--',
                label=f'Median BMI = {np.median(bmi):.1f}')
ax_good.legend(fontsize=10)
ax_good.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated patient BMI data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);"><h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">4.C — Applied Exercises</h1><p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Detect, Diagnose, and Fix Misleading Charts</p></div>

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #F57C00; margin-top: 0;">Exercise 10 — Detect and Fix Truncated Axes</h3></div>
#
# The code below generates a bar chart comparing **monthly gym membership sign-ups** across five branches of a fitness chain. The chart has been deliberately designed to mislead.
#
# 🎯 **Task:**
#
# 1. Run the cell and observe the chart carefully.
# 2. Identify **exactly what makes this chart misleading** — state the specific technique, the y-axis range used, and the actual numerical difference between the highest and lowest bars.
# 3. Fix the chart in the second code cell so that it accurately represents the data. Your corrected chart must:
#    - Start the y-axis at 0.
#    - Add a data-label annotation on each bar showing the actual count.
#    - Add an annotation that calculates and displays the actual percentage difference between the highest and lowest branches.
# 4. Write a 2–3 sentence explanation in the answer cell below describing the deception and why it matters in a business context.

# %%
# Exercise 10 — Starter code (DO NOT MODIFY THIS CELL)
branches    = ['Downtown', 'Eastside', 'Northgate', 'Westwood', 'Southpark']
sign_ups    = [487, 492, 498, 503, 511]   # monthly sign-ups — range of only 24

fig, ax = plt.subplots(figsize=(9, 6))
colors_ex10 = ['#4B2E83', '#E8B923', '#32006E', '#85714D', '#1976D2']
bars = ax.bar(branches, sign_ups, color=colors_ex10, edgecolor='white', linewidth=1.5)

ax.set_ylim(480, 520)   # <-- truncated axis
ax.set_title('Monthly Gym Sign-Ups by Branch', fontsize=14, fontweight='bold', color='#4B2E83')
ax.set_xlabel('Branch', fontsize=12)
ax.set_ylabel('Sign-Ups', fontsize=12)
ax.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Fitness chain internal data (simulated)',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %%
# Exercise 10 — YOUR CORRECTED CHART
# Fix the misleading chart above. Requirements:
#   1. Start the y-axis at 0.
#   2. Add data-label annotations on each bar.
#   3. Annotate the actual % difference between the highest and lowest branches.

# --- Your code here ---

# %% [markdown]
# **Exercise 10 — Written Answer**
#
# *Write your written answer here.*
#
# 1. **Technique used:** \_\_\_ Truncating y axis
# 2. **Y-axis range in the misleading chart:** \_\_\_ 480-520
# 3. **Actual numerical difference (highest minus lowest):** 24 sign-ups
# 4. **Actual percentage difference:** \_\_\_ 4.9%
# 5. **Business impact of this deception (2–3 sentences):** \_\_\_ This makes the sign up rate look a lot more inflated than it is, which could lead to incorrect business desicions. this in turn could harm future prospects.

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have a bar chart comparing monthly gym sign-ups across 5 branches.
# The values are: Downtown=487, Eastside=492, Northgate=498, Westwood=503, Southpark=511.
# The y-axis currently starts at 480 instead of 0.
#
# 1. Explain in plain language why a truncated y-axis is misleading here.
#    Quantify how much larger the tallest bar appears relative to the shortest bar
#    on the truncated chart, versus the true ratio.
# 2. Write corrected matplotlib code that:
#    - Starts the y-axis at 0 with ylim(0, 560).
#    - Adds a value label on top of each bar.
#    - Adds an annotation showing the actual percentage spread across branches.
#    - Uses the colour palette: #4B2E83, #E8B923, #32006E, #85714D, #1976D2.
# 3. In what business context might someone deliberately truncate an axis like this,
#    and what decision could that mislead?
# ```

# %% [markdown]
# ### 1. Why a Truncated Y-Axis is Misleading
#
# A truncated y-axis (one that doesn't start at zero) visually exaggerates differences between values. Our brains interpret the *height* of a bar as its magnitude. When the axis is truncated, a small absolute difference can appear as a massive relative difference.
#
# For the given chart:
#
# *   **Tallest Bar (Southpark):** 511 sign-ups. On the truncated axis (starting at 480), its visible height is 511 - 480 = 31 units.
# *   **Shortest Bar (Downtown):** 487 sign-ups. On the truncated axis, its visible height is 487 - 480 = 7 units.
#
# Visually, Southpark's bar appears approximately **4.43 times taller** (31 / 7) than Downtown's. However, the true ratio is only about **1.05 times taller** (511 / 487). This creates a highly distorted perception of the data, making small variations seem much more significant than they are.

# %% [markdown]
# ### 2. Corrected Matplotlib Code

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from starter code
branches    = ['Downtown', 'Eastside', 'Northgate', 'Westwood', 'Southpark']
sign_ups    = [487, 492, 498, 503, 511]   # monthly sign-ups — range of only 24

# Color palette as requested
colors_ex10 = ['#4B2E83', '#E8B923', '#32006E', '#85714D', '#1976D2']

fig, ax = plt.subplots(figsize=(9, 6))
bars = ax.bar(branches, sign_ups, color=colors_ex10, edgecolor='white', linewidth=1.5)

# --- FIX: Set y-axis to start at 0 ---
ax.set_ylim(0, 560) # Adjusted max to accommodate labels and annotation

# --- Add value labels on top of each bar ---
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 10, # Adjust padding as needed
            f'{int(yval)}', ha='center', va='bottom', fontsize=10, fontweight='bold', color='#333')

# --- Add annotation for percentage spread ---
min_sign_ups = min(sign_ups)
max_sign_ups = max(sign_ups)

pct_spread = ((max_sign_ups - min_sign_ups) / min_sign_ups) * 100

ax.annotate(f'Actual Spread: {max_sign_ups - min_sign_ups} sign-ups ({pct_spread:.1f}% difference)',
            xy=(len(branches) - 1, max_sign_ups),
            xytext=(0.5, 540), # Position the annotation in the plot area
            fontsize=11, color='#C62828', fontweight='bold',
            ha='center',
            bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="#C62828", lw=1))


ax.set_title('Monthly Gym Sign-Ups by Branch (Corrected: Y-axis from 0)',
             fontsize=14, fontweight='bold', color='#4B2E83')
ax.set_xlabel('Branch', fontsize=12, color='#333')
ax.set_ylabel('Sign-Ups', fontsize=12, color='#333')
ax.grid(True, axis='y', alpha=0.3, color='#DDDDDD') # Keep light horizontal gridlines
ax.set_axisbelow(True)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_edgecolor('#DDDDDD')
ax.spines['bottom'].set_edgecolor('#DDDDDD')

fig.text(0.1, -0.02, 'Source: Fitness chain internal data (simulated)',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Business Context for Deliberate Truncation
#
# In a business context, someone might deliberately truncate an axis to **exaggerate the significance of minor differences or trends**, often to support a particular narrative or influence a decision. For instance:
#
# *   **To inflate success:** A manager might truncate the y-axis to make a modest increase in sales or user engagement look like explosive growth, securing more resources or positive performance reviews.
# *   **To magnify problems:** Conversely, they might truncate an axis to make a slight decline appear catastrophic, potentially to push for a new initiative or budget increase.
#
# This kind of deception can mislead crucial decisions, such as allocating budgets, making investment choices, evaluating employee performance, or determining marketing strategies, by misrepresenting the true magnitude of a situation.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #F57C00; margin-top: 0;">Exercise 11 — Cherry-Picked Data &amp; Dual-Axis Deception</h3></div>
#
# The starter code below creates a dual-axis chart overlaying **monthly coffee shop revenue** and **city-wide coffee bean import volumes** (two completely unrelated metrics). The chart is then restricted to a cherry-picked 5-month window where both series happen to trend upward.
#
# 🎯 **Task:**
#
# 1. Run the starter cell and describe what narrative the chart implies.
# 2. Identify **both** deception techniques present (dual-axis + cherry-picking) and explain how each one independently distorts the reader's interpretation.
# 3. Fix the chart: separate the two metrics into two honest side-by-side panels showing the **full 18-month dataset**. Both panels must start their y-axes at 0.
# 4. Answer: after seeing the full data, is there any evidence that city-wide bean imports drive coffee shop revenue? Explain in 2–3 sentences.

# %%
# Exercise 11 — Starter code (DO NOT MODIFY THIS CELL)
np.random.seed(21)

months_18 = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
             'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec',
             'Jan\'25', 'Feb\'25', 'Mar\'25', 'Apr\'25', 'May\'25', 'Jun\'25']

# Coffee shop revenue ($K) — seasonal pattern, no clear trend
revenue_18 = [42, 38, 45, 52, 61, 68, 65, 60, 55, 48, 44, 39,
              43, 37, 46, 54, 63, 70]

# City-wide bean imports (tons) — driven by global commodity cycle, unrelated to one shop
imports_18 = [850 + int(np.random.normal(0, 40)) for _ in range(18)]
# Force an upward drift in the cherry-picked window (months 4-8) for the illusion
for i in range(4, 9):
    imports_18[i] += (i - 3) * 30

# ---- CHERRY-PICK: show only months 4-8 (May to Sep) ----
window = slice(4, 9)
m_window = months_18[window]
r_window = revenue_18[window]
i_window = imports_18[window]

fig, ax1 = plt.subplots(figsize=(9, 6))
ax2 = ax1.twinx()

l1, = ax1.plot(m_window, r_window, marker='o', linewidth=2.5,
               markersize=9, color='#4B2E83', label='Revenue ($K)')
l2, = ax2.plot(m_window, i_window, marker='s', linewidth=2.5,
               markersize=9, color='#E8B923', linestyle='--', label='Bean Imports (tons)')

# Rescale to maximise visual alignment
ax1.set_ylim(55, 75)
ax2.set_ylim(870, 1070)

ax1.set_xlabel('Month', fontsize=12)
ax1.set_ylabel('Revenue ($K)', fontsize=12, color='#4B2E83')
ax2.set_ylabel('Bean Imports (tons)', fontsize=12, color='#E8B923')
ax1.set_title('Revenue & Bean Imports — MISLEADING\n(cherry-picked window + dual axis)',
              fontsize=12, fontweight='bold', color='#C62828')

ax1.legend([l1, l2], [l1.get_label(), l2.get_label()],
           frameon=True, fancybox=True, fontsize=10, loc='upper left')
ax1.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated coffee shop and commodity data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

# %%
# Exercise 11 — YOUR CORRECTED CHART
# Requirements:
#   1. Two side-by-side panels — one for revenue, one for bean imports.
#   2. Both panels show the FULL 18-month dataset.
#   3. Both y-axes start at 0.
#   4. Both panels share the same x-axis range (rotate tick labels if needed).

# --- Your code here ---

# %% [markdown]
# **Exercise 11 — Written Answer**
#
# *Write your written answer here.*
#
# 1. **Narrative implied by the misleading chart:** revenue is dropping dramatically while bean exports are skyrocketing. Basically, someone could panic and say we make are selling our beans for too cheap and its bringing in bad money.
# 2. **How the dual axis creates the deception:** theyre both truncated and the axis are not leveled so it creates a strange plot with values that dont make sense.
# 3. **How the cherry-picked window reinforces the deception:** \_\_\_ the window is small which makes the change look so much larger.
# 4. **After viewing the full 18-month data, is there evidence of a causal link? Why or why not?** \_\_\_ No, there seems more ot be a causal link with city temprature, with demand higher in summer weather for coffee, so there is more exports, while exports go down simultaneously with the weather and demand for coffee form the shop.

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have a dual-axis line chart that overlays:
#   - Monthly coffee shop revenue ($K) — seasonal, no trend
#   - City-wide coffee bean imports (tons) — commodity-driven, unrelated
#
# The chart only shows 5 months (May–Sep) where both happen to rise,
# and the y-axes are rescaled to align the lines.
#
# 1. Explain each of the two deception techniques present and how they
#    interact to amplify the misleading impression.
# 2. Write matplotlib code for an honest version:
#    - Two side-by-side subplots sharing the same x-axis.
#    - Both showing all 18 months.
#    - Left panel: revenue, y from 0 to 80, colour #4B2E83.
#    - Right panel: bean imports, y from 0 to 1100, colour #E8B923.
#    - Rotate x-tick labels 45 degrees on both panels.
# 3. What statistical test would you run to actually determine whether
#    bean imports are correlated with coffee shop revenue?
# ```

# %% [markdown]
# ### 1. Explanation of Deception Techniques
#
# The misleading chart leverages two powerful deception techniques that, when combined, create a strong but false impression of correlation:
#
# 1.  **Dual-Axis Deception:** This technique allows two entirely unrelated metrics (coffee shop revenue and city-wide bean imports) to be plotted on the same chart, each with its own independent y-axis. By arbitrarily scaling these axes, the chart maker can force the lines to appear to move in sync, suggesting a causal relationship that doesn't exist. The human eye is naturally drawn to similar visual patterns, interpreting aligned trends as evidence of a link, even when the underlying data are measuring completely different phenomena.
#
# 2.  **Cherry-Picked Data Window:** The chart displays only a specific, limited subset of the overall data (a 5-month window from May to September). This window is intentionally chosen because, by chance, both revenue and imports happened to trend upwards during this short period. By omitting the full 18-month context, the chart hides the broader, often inconsistent, trends that would reveal the lack of a consistent relationship between the two variables.
#
# **Interaction and Amplification:** The two techniques amplify each other. The cherry-picked window identifies a coincidence (both variables rising briefly), and the dual-axis then visually exaggerates this coincidence into a strong, compelling alignment. Without the full context or a consistent axis scale, viewers are easily led to believe that coffee bean imports directly influence coffee shop revenue, or vice-versa, when in reality, their movements are largely independent and likely driven by different underlying factors (e.g., seasonality for revenue, global commodity markets for imports).

# %% [markdown]
# ### 2. Corrected Matplotlib Code

# %%
# Exercise 11 — YOUR CORRECTED CHART
# Requirements:
#   1. Two side-by-side panels — one for revenue, one for bean imports.
#   2. Both panels show the FULL 18-month dataset.
#   3. Both y-axes start at 0.
#   4. Both panels share the same x-axis range (rotate tick labels if needed).

# Data from starter code is already available in the kernel: months_18, revenue_18, imports_18

fig, (ax_revenue, ax_imports) = plt.subplots(1, 2, figsize=(15, 6))

# --- Left panel: Coffee Shop Revenue ---
ax_revenue.plot(months_18, revenue_18, marker='o', linewidth=2.0,
               markersize=6, color='#4B2E83', label='Revenue ($K)')
ax_revenue.set_title('Monthly Coffee Shop Revenue', fontsize=13, fontweight='bold', color='#4B2E83')
ax_revenue.set_xlabel('Month', fontsize=11)
ax_revenue.set_ylabel('Revenue ($K)', fontsize=11)
ax_revenue.set_ylim(0, 80) # As requested
ax_revenue.set_xticks(np.arange(len(months_18))) # Ensure all months are shown
ax_revenue.set_xticklabels(months_18, rotation=45, ha='right', fontsize=9)
ax_revenue.grid(True, alpha=0.3, axis='y')
ax_revenue.spines[['top', 'right']].set_visible(False)

# --- Right panel: City-wide Coffee Bean Imports ---
ax_imports.plot(months_18, imports_18, marker='s', linewidth=2.0,
               markersize=6, color='#E8B923', label='Bean Imports (tons)')
ax_imports.set_title('City-wide Coffee Bean Imports', fontsize=13, fontweight='bold', color='#32006E')
ax_imports.set_xlabel('Month', fontsize=11)
ax_imports.set_ylabel('Bean Imports (tons)', fontsize=11)
ax_imports.set_ylim(0, 1100) # As requested
ax_imports.set_xticks(np.arange(len(months_18))) # Ensure all months are shown
ax_imports.set_xticklabels(months_18, rotation=45, ha='right', fontsize=9)
ax_imports.grid(True, alpha=0.3, axis='y')
ax_imports.spines[['top', 'right']].set_visible(False)

plt.suptitle('Corrected: Coffee Shop Revenue vs. Bean Imports (Full 18-Month View)',
             fontsize=15, fontweight='bold', color='#388E3C', y=1.05)
fig.text(0.1, -0.01, 'Source: Simulated coffee shop and commodity data', # Adjusted position
         fontsize=8, color='#888', style='italic')

plt.tight_layout(rect=[0, 0.05, 1, 0.98]) # Adjust layout to make space for suptitle and footer
plt.show()

# %% [markdown]
# ### 3. Statistical Test for Correlation
#
# To determine if there is a statistically significant linear relationship between bean imports and coffee shop revenue, you would typically calculate the **Pearson correlation coefficient (r)**. This coefficient measures the strength and direction of a linear association between two continuous variables. Along with `r`, it is important to calculate the **p-value**, which indicates the probability of observing such a correlation (or a stronger one) by chance if there were truly no correlation. A low p-value (e.g., < 0.05) suggests that the observed correlation is statistically significant.
#
# ```python
# from scipy.stats import pearsonr
#
# # Assuming revenue_18 and imports_18 are lists or numpy arrays of your data
# correlation_coefficient, p_value = pearsonr(revenue_18, imports_18)
#
# print(f"Pearson Correlation Coefficient: {correlation_coefficient:.2f}")
# print(f"P-value: {p_value:.3f}")
# ```

# %% [markdown]
# **Exercise 11 — Written Answer**
#
# *Write your written answer here.*
#
# 1. **Narrative implied by the misleading chart:** The misleading chart implies a strong, positive correlation between monthly coffee shop revenue and city-wide coffee bean imports, suggesting that an increase in one directly leads to an increase in the other.
# 2. **How the dual axis creates the deception:** The dual axis creates deception by allowing the independent scaling of the two y-axes. This enables the chart creator to visually align unrelated trends, making them appear to be moving together or influencing each other, even when their absolute magnitudes or variations are quite different.
# 3. **How the cherry-picked window reinforces the deception:** The cherry-picked window reinforces the deception by selecting only a short segment of data where both metrics coincidentally show an upward trend. This hides the longer-term, more variable, or even contradictory patterns that exist in the full dataset, thereby fabricating a consistent positive relationship.
# 4. **After viewing the full 18-month data, is there evidence of a causal link? Why or why not?** After viewing the full 18-month data, there is no clear evidence of a causal link between coffee shop revenue and city-wide bean imports. While both may show some seasonality (like rising in warmer months), their individual peaks and troughs do not consistently align, and their overall patterns appear largely independent, indicating they are likely driven by different factors rather than directly influencing each other.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #F57C00; margin-top: 0;">Exercise 12 — Unequal Bins &amp; 3D Distortion</h3></div>
#
# The starter code creates a histogram of **patient recovery times (days)** after a minor surgical procedure. It uses **unequal bin widths** (narrow bins early, one very wide bin for long recoveries) and plots raw **counts** on the y-axis — making the long-recovery tail look artificially tall. As a finishing touch, a 3D bar shadow effect has been added.
#
# 🎯 **Task:**
#
# 1. Run the starter cell. Identify the two distinct problems present: the binning issue and the 3D distortion issue.
# 2. For the binning problem: explain in one sentence why plotting counts (instead of density) with unequal bins misleads the reader about where most patients fall.
# 3. Fix the chart in the second code cell by:
#    - Using **equal-width bins** (use 15 bins of equal width).
#    - Plotting **density** on the y-axis instead of counts.
#    - Removing all 3D effects.
#    - Adding a vertical line for the median and mean, with labels.
# 4. Describe in 2–3 sentences what a hospital administrator might incorrectly conclude from the misleading chart, and what the corrected chart actually reveals.

# %%
# Exercise 12 — Starter code (DO NOT MODIFY THIS CELL)
np.random.seed(99)

# Simulate recovery times (days) — log-normal: most patients recover in 3-10 days,
# a minority take much longer (right-skewed)
recovery_days = np.random.lognormal(mean=1.9, sigma=0.5, size=600)
recovery_days = recovery_days[(recovery_days >= 1) & (recovery_days <= 45)]

# Unequal bins: fine resolution 1-15, one huge bin 15-45
unequal_bins_ex12 = [1, 3, 5, 7, 9, 11, 13, 15, 45]

fig, ax = plt.subplots(figsize=(10, 6))

n_vals, bin_edges, patches = ax.hist(
    recovery_days, bins=unequal_bins_ex12,
    color='#7B1FA2', edgecolor='white', linewidth=0.8
    # Note: density=False — counts on y-axis
)

# Add fake 3D shadow effect
for patch in patches:
    shadow = mpatches.FancyBboxPatch(
        (patch.get_x() + 0.15, patch.get_y() - 3),
        patch.get_width(), patch.get_height(),
        boxstyle='square', linewidth=0,
        facecolor='#BDB0C9', zorder=0, alpha=0.6
    )
    ax.add_patch(shadow)

# Annotate bin widths
for left, right, count in zip(bin_edges[:-1], bin_edges[1:], n_vals):
    mid = (left + right) / 2
    ax.text(mid, count + 2, f'w={int(right-left)}', ha='center',
            fontsize=8, color='#444')

ax.set_title('Patient Recovery Time — MISLEADING\n(unequal bins + counts + 3D shadow)',
             fontsize=13, fontweight='bold', color='#C62828')
ax.set_xlabel('Recovery Time (days)', fontsize=12)
ax.set_ylabel('Count  (not density!)', fontsize=12, color='#C62828')
ax.grid(True, alpha=0.3)

fig.text(0.1, -0.02, 'Source: Simulated post-surgical recovery data',
         fontsize=9, color='#888', style='italic')
plt.tight_layout()
plt.show()

print(f'Wide tail bin (15-45 days): width = 30, count = {int(n_vals[-1])}')
print(f'Narrow bins (e.g. 1-3 days): width = 2, count = {int(n_vals[0])}')
print(f'Density in tail bin: {n_vals[-1]/30:.1f} per day vs narrow bin: {n_vals[0]/2:.1f} per day')
# Out:
# Wide tail bin (15-45 days): width = 30, count = 30
# Narrow bins (e.g. 1-3 days): width = 2, count = 31
# Density in tail bin: 1.0 per day vs narrow bin: 15.5 per day

# %%
# Exercise 12 — YOUR CORRECTED CHART
# Requirements:
#   1. Use 15 equal-width bins (use np.linspace(1, 45, 16) for bin edges).
#   2. Plot DENSITY on the y-axis (density=True).
#   3. Remove all 3D/shadow effects.
#   4. Add vertical lines for the median (red dashed) and mean (gold dash-dot)
#      with labels showing their values.
#   5. Use colour #388E3C for the bars.

# --- Your code here ---

# %% [markdown]
# **Exercise 12 — Written Answer**
#
# *Write your written answer here.*
#
# 1. **Binning problem — why counts mislead with unequal bins:** It looks like this could be because the final three columns have their values added up and inflated to one bin for all three, contributing to the uneven bar.
# 2. **3D distortion problem — which bars are visually inflated or deflated?** the final bin is obviously inflate.
# 3. **What might a hospital administrator incorrectly conclude from the misleading chart?** They might conclude that from 15-40 days onward, recovery times remained the same.
# 4. **What does the corrected chart actually reveal about the recovery time distribution?** recovery time got smaller and smaller as more days passed by.

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have a histogram of patient recovery times (days) after minor surgery.
# The data is right-skewed (log-normal) with most patients recovering in 3-10 days.
#
# The misleading chart has two problems:
#   A) Unequal bin widths: bins of width 2 for days 1-15, then one bin of width 30
#      for days 15-45 — but counts (not density) are shown on the y-axis.
#   B) A 3D shadow effect is applied to each bar.
#
# 1. Explain mathematically why plotting counts with a 30-day bin makes it look
#    as if many patients take 15-45 days to recover, when actually the density
#    per day is very low in that range.
# 2. Write corrected matplotlib code that:
#    - Uses equal-width bins: np.linspace(1, 45, 16).
#    - Uses density=True so the y-axis is frequency density.
#    - Removes all 3D effects.
#    - Adds a red dashed vertical line for the median and a gold dash-dot line
#      for the mean, each with a text annotation.
#    - Uses colour #388E3C for bars.
# 3. In what other real-world domains are unequal histogram bins commonly misused?
#    Give two examples.
# ```

# %% [markdown]
# ### 1. Explanation of Misleading Unequal Bins
#
# When plotting counts on the y-axis of a histogram, the **area** of each bar should ideally be proportional to the frequency of observations within that bin. However, when bins have unequal widths, plotting raw counts on the y-axis makes the visual **height** of the bar represent the count, not the density.
#
# Mathematically, a wide bin (e.g., 30 days for 15-45 days) will accumulate more raw counts simply because it covers a larger range of the x-axis. Even if the *density* of patients (patients per day) in that wide bin is very low, its large width can make the bar appear visually significant. For instance, if a narrow bin (e.g., 2 days for 1-3 days) has a count of 30, and a wide bin (30 days for 15-45 days) also has a count of 30, the narrow bin represents 15 patients per day, while the wide bin represents only 1 patient per day. However, in a counts-based histogram with unequal bins, both bars would have the same height, falsely implying an equivalent concentration of patients. This distorts the perceived distribution, making regions with low density but large width appear more populous than they are.

# %%
# Exercise 12 — YOUR CORRECTED CHART
# Requirements:
#   1. Use 15 equal-width bins (use np.linspace(1, 45, 16) for bin edges).
#   2. Plot DENSITY on the y-axis (density=True).
#   3. Remove all 3D/shadow effects.
#   4. Add vertical lines for the median (red dashed) and mean (gold dash-dot)
#      with labels showing their values.
#   5. Use colour #388E3C for the bars.

# Data from starter code (recovery_days is already defined from the previous execution)
# Ensure PALETTE is defined for consistent colors
if 'PALETTE' not in globals():
    PALETTE = {
        'primary':   '#4B2E83',
        'gold':      '#E8B923',
        'dark':      '#32006E',
        'lavender':  '#B7A6D5',
        'tan':       '#85714D',
        'red':       '#C62828',
        'blue':      '#1976D2',
        'orange':    '#F57C00',
        'green':     '#388E3C',
        'purple':    '#7B1FA2',
        'neutral':   '#CCCCCC',
        'neutral2':  '#AAAAAA',
        'bg':        '#FAFAFA',
    }

# 2. Corrected Matplotlib Code
# Define equal-width bins
equal_bins_ex12 = np.linspace(1, 45, 16)

fig, ax = plt.subplots(figsize=(10, 6))

# Plot histogram with equal bins and density=True
n_vals_corr, bin_edges_corr, patches_corr = ax.hist(
    recovery_days, bins=equal_bins_ex12, density=True,
    color=PALETTE['green'], edgecolor='white', linewidth=0.8
)

# Calculate median and mean
median_recovery = np.median(recovery_days)
mean_recovery = np.mean(recovery_days)

# Add vertical line for median (red dashed)
ax.axvline(median_recovery, color=PALETTE['red'], linestyle='--', linewidth=2,
           label=f'Median: {median_recovery:.1f} days')
ax.text(median_recovery + 0.5, ax.get_ylim()[1] * 0.9, f'Median: {median_recovery:.1f}',
        color=PALETTE['red'], fontsize=10, ha='left', va='top', fontweight='bold')

# Add vertical line for mean (gold dash-dot)
ax.axvline(mean_recovery, color=PALETTE['gold'], linestyle='-.', linewidth=2,
           label=f'Mean: {mean_recovery:.1f} days')
ax.text(mean_recovery + 0.5, ax.get_ylim()[1] * 0.8, f'Mean: {mean_recovery:.1f}',
        color=PALETTE['gold'], fontsize=10, ha='left', va='top', fontweight='bold')

ax.set_title('Patient Recovery Time — CORRECTED (equal bins + density)',
             fontsize=13, fontweight='bold', color=PALETTE['primary'])
ax.set_xlabel('Recovery Time (days)', fontsize=12, color=PALETTE['dark'])
ax.set_ylabel('Density (patients per day)', fontsize=12, color=PALETTE['dark'])
ax.grid(True, alpha=0.3, color=PALETTE['neutral'])
ax.set_axisbelow(True)

# Remove top and right spines
ax.spines[['top', 'right']].set_visible(False)

fig.text(0.1, -0.02, 'Source: Simulated post-surgical recovery data',
         fontsize=9, color=PALETTE['neutral2'], style='italic')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Other Real-World Domains Where Unequal Histogram Bins Are Commonly Misused
#
# Unequal histogram bins are often misused in contexts where specific ranges are of interest, but without normalizing by density, they can create a skewed perception of the data distribution. Two common examples are:
#
# 1.  **Income Distribution:** Economic reports or social studies often use unequal bins for income brackets (e.g., $0-25k, $25-50k, $50-100k, $100k-500k). If counts (number of households) are plotted on the y-axis, the wide higher-income bins can appear to contain a much larger proportion of the population than they actually do per dollar range, making the wealth distribution seem less concentrated at the lower end or more evenly spread than it is.
#
# 2.  **Age Demographics:** When analyzing populations, age groups might be binned unequally, especially at the extremes (e.g., 0-5 years, 5-18 years, 18-65 years, 65+ years). Plotting raw counts can make the broad 'working-age' or 'senior' bins seem disproportionately large in terms of daily or yearly population density compared to narrower childhood bins, potentially leading to misinterpretations about the actual age structure of a population.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 10px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h2 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">End of Section 4</h2>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.2em; margin: 10px 0; font-weight: 300;">A chart that misleads — even unintentionally — erodes trust and drives bad decisions. When in doubt, show more context, not less.</p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);"><h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Section 5: Detecting Statistical Deception</h1><p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Recognizing misleading statistics, charts, and narratives — and how to fix them</p></div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2><ul style="color: #333; font-size: 1.05em; line-height: 1.9; margin-bottom: 0;"><li>Identify common statistical sleights of hand used in data presentations and media reporting.</li><li>Distinguish between relative and absolute change, and explain when each is appropriate.</li><li>Recognise how the choice of mean versus median can distort the perception of a distribution.</li><li>Explain survivorship bias, omitted variable bias, and how selective filtering manufactures false narratives.</li><li>Differentiate correlation from causation and name confounding variables in realistic scenarios.</li><li>Redesign deceptive visualisations into honest, context-rich alternatives.</li><li>Use LLM tools to critically audit statistical claims before accepting them.</li></ul></div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. A Taxonomy of Statistical Deception</h2><p style="color: #333; font-size: 1.05em; margin-bottom: 6px;">Statistical deception rarely involves outright lying. It usually exploits omission, framing, or a mismatch between what a number measures and what the audience assumes it measures. The table below maps the most common patterns to their tell-tale signs and remedies.</p><table style="width:100%; border-collapse: collapse; font-size: 0.97em; margin-top: 14px;"><thead><tr style="background-color: #4B2E83; color: #FFF;"><th style="padding: 10px 14px; text-align: left;">Deception Pattern</th><th style="padding: 10px 14px; text-align: left;">What is Hidden</th><th style="padding: 10px 14px; text-align: left;">Remedy</th></tr></thead><tbody><tr style="background-color: #F5F0FF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Missing sample size</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">A percentage means nothing without knowing <em>n</em>.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Always report <em>n</em> alongside every proportion.</td></tr><tr style="background-color: #FFFFFF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Missing uncertainty intervals</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Point estimates suppress the spread of plausible values.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Show 95 % CIs or error bars on every estimate.</td></tr><tr style="background-color: #F5F0FF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Mean vs median distortion</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Extreme values inflate the mean far above the typical value.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Report both; use box plots to show the full distribution.</td></tr><tr style="background-color: #FFFFFF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Relative vs absolute change</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">&ldquo;300 % increase&rdquo; from 1 to 4 sounds huge; 3 extra events may not matter.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">State both the relative and absolute change, plus the baseline.</td></tr><tr style="background-color: #F5F0FF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Percentages without baseline</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">&ldquo;50 % more effective&rdquo; — more effective than what?</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Anchor every percentage to a clearly stated reference value.</td></tr><tr style="background-color: #FFFFFF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Survivorship bias</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Only successes are visible; failures have been filtered out.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Ask: &ldquo;What data is missing from this picture?&rdquo;</td></tr><tr style="background-color: #F5F0FF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Omitted variables</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">An unmeasured third variable drives both observed variables.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Enumerate plausible confounders; use controlled comparisons.</td></tr><tr style="background-color: #FFFFFF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Correlation vs causation</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">A regression line does not imply that X causes Y.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">State the causal mechanism explicitly; design an experiment if needed.</td></tr><tr style="background-color: #F5F0FF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Selective filtering (cherry-picking)</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Only the time window or subgroup that supports the narrative is shown.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Show the full dataset; state inclusion / exclusion criteria up front.</td></tr><tr style="background-color: #FFFFFF;"><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;"><strong>Overplotting hiding clusters</strong></td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Dense point clouds look uniform, masking sub-groups or outliers.</td><td style="padding: 9px 14px; border-bottom: 1px solid #DDD;">Use transparency, jitter, or 2-D density plots to reveal structure.</td></tr><tr style="background-color: #F5F0FF;"><td style="padding: 9px 14px;"><strong>Fake trends from small samples</strong></td><td style="padding: 9px 14px;">A trend line through 4&ndash;5 points has enormous uncertainty.</td><td style="padding: 9px 14px;">Report confidence bands around regression lines; show residuals.</td></tr></tbody></table></div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;"><h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Python Demonstrations</h2><p style="color: #333; font-size: 1.05em; margin-bottom: 0;">Each demonstration below first shows a <strong style="color: #C62828;">deceptive</strong> visualisation and then presents a <strong style="color: #388E3C;">corrected</strong> version. Pay attention to what information was omitted in the bad version and how adding context transforms the message.</p></div>

# %% [markdown]
# <div style="background-color: #FFEBEE; border-left: 4px solid #C62828; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #C62828; margin-top: 0;">Demo 1 (Bad) — &ldquo;300% Increase!&rdquo; Bar Chart Without Baseline</h3><p style="color: #333; margin-bottom: 0;">A metric jumps from <strong>2 to 8</strong>. The headline screams &ldquo;300% increase!&rdquo; But the denominator is only <em>n = 10</em> users. Absolute change: +6 users. Is this meaningful? The bar chart below — with a y-axis starting at 0 but no sample-size annotation — makes it look like a major achievement.</p></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# ── Shared style ────────────────────────────────────────────────────────────
PRIMARY   = '#4B2E83'
GOLD      = '#E8B923'
DARK      = '#32006E'
TAN       = '#85714D'
LAVENDER  = '#B7A6D5'
RED       = '#C62828'
BLUE      = '#1976D2'
ORANGE    = '#F57C00'
GREEN     = '#388E3C'
PURPLE    = '#7B1FA2'

plt.rcParams.update({
    'figure.facecolor': 'white',
    'axes.facecolor':   'white',
    'font.size': 12,
})
np.random.seed(42)

# ── Bad chart ───────────────────────────────────────────────────────────────
labels  = ['Before', 'After']
values  = [2, 8]

fig, ax = plt.subplots(figsize=(5, 5))
bars = ax.bar(labels, values, color=[LAVENDER, PRIMARY], width=0.5,
              edgecolor='white', linewidth=1.5)
ax.set_title('Feature Adoption\n"300% Increase!"', fontsize=15,
             fontweight='bold', color=RED)
ax.set_ylabel('Users', fontsize=12)
ax.set_ylim(0, 10)
for bar, val in zip(bars, values):
    ax.text(bar.get_x() + bar.get_width() / 2, val + 0.2,
            str(val), ha='center', va='bottom', fontweight='bold', fontsize=13)
plt.tight_layout()
plt.show()
print('Headline: "Our new feature adoption TRIPLED — 300% increase!"')
print('What is missing? Sample size (n=10), absolute change (+6 users),')
print('and any confidence interval around these tiny counts.')

# %% [markdown]
# <div style="background-color: #E8F5E9; border-left: 4px solid #388E3C; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #388E3C; margin-top: 0;">Demo 1 (Corrected) — Absolute Numbers, Sample Size, and Context</h3><p style="color: #333; margin-bottom: 0;">The corrected version shows both absolute counts and the sample size denominator, labels the baseline explicitly, and adds a subtitle that prevents headline inflation.</p></div>

# %%
n_total  = 10
before   = 2
after    = 8
rel_chg  = (after - before) / before * 100
abs_chg  = after - before

fig, axes = plt.subplots(1, 2, figsize=(11, 5))

# Left panel — absolute counts with denominator
ax = axes[0]
bars = ax.bar(['Before', 'After'], [before, after],
              color=[LAVENDER, PRIMARY], width=0.5,
              edgecolor='white', linewidth=1.5)
ax.set_title(f'Feature Adoption (n = {n_total} users)', fontsize=13,
             fontweight='bold', color=PRIMARY)
ax.set_ylabel('Users who adopted feature', fontsize=11)
ax.set_ylim(0, n_total + 1)
# Add a dashed line at total n for reference
ax.axhline(n_total, color=TAN, linestyle='--', linewidth=1.2, label=f'Total users = {n_total}')
ax.legend(fontsize=10)
for bar, val in zip(bars, [before, after]):
    pct = val / n_total * 100
    ax.text(bar.get_x() + bar.get_width() / 2, val + 0.15,
            f'{val} ({pct:.0f}%)', ha='center', va='bottom',
            fontweight='bold', fontsize=12)
ax.set_xlabel(
    f'Relative change: +{rel_chg:.0f}%  |  Absolute change: +{abs_chg} users',
    fontsize=10, color='#555')

# Right panel — adoption rate with 95% Wilson CI
ax2 = axes[1]
from statsmodels.stats.proportion import proportion_confint
ci_before = proportion_confint(before, n_total, method='wilson')
ci_after  = proportion_confint(after,  n_total, method='wilson')
rates  = [before / n_total, after  / n_total]
errs_lo = [rates[0] - ci_before[0], rates[1] - ci_after[0]]
errs_hi = [ci_before[1] - rates[0], ci_after[1]  - rates[1]]
ax2.bar(['Before', 'After'], rates,
        color=[LAVENDER, PRIMARY], width=0.5,
        edgecolor='white', linewidth=1.5, yerr=[errs_lo, errs_hi],
        capsize=8, error_kw=dict(ecolor='#555', lw=2))
ax2.set_title('Adoption Rate with 95% Confidence Interval', fontsize=13,
              fontweight='bold', color=PRIMARY)
ax2.set_ylabel('Proportion of users', fontsize=11)
ax2.set_ylim(0, 1.15)
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.0%}'))
ax2.text(0.5, 1.05,
         'Wide CIs reveal the estimate is highly uncertain at n = 10',
         ha='center', transform=ax2.transAxes, fontsize=10,
         color='#555', style='italic')

plt.suptitle('Honest reporting: same data, full context', fontsize=14,
             fontweight='bold', color=GREEN, y=1.01)
plt.tight_layout()
plt.show()
print('Key takeaway: a 300% relative increase from 2 to 8 users (out of 10)')
print('is statistically meaningless. The 95% CI for the "after" rate spans')
print('roughly 45%–98%, making any strong claim premature.')

# %% [markdown]
# <div style="background-color: #FFEBEE; border-left: 4px solid #C62828; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #C62828; margin-top: 0;">Demo 2 (Bad) — Average Department Salary Inflated by One Executive</h3><p style="color: #333; margin-bottom: 0;">A single $2 M executive salary pulls the Engineering department's <em>mean</em> far above what any typical engineer earns. Reported as a bar chart of means, the Engineering bar looks outrageously high — which misleads both recruiters and employees.</p></div>

# %%
np.random.seed(7)

# Simulate salary data
engineering = np.concatenate([
    np.random.normal(95_000, 12_000, 29),   # 29 regular engineers
    [2_000_000]                             # 1 CTO
])
marketing   = np.random.normal(72_000, 8_000, 30)
ops         = np.random.normal(65_000, 7_000, 30)
hr          = np.random.normal(60_000, 6_000, 30)

depts  = ['Engineering', 'Marketing', 'Operations', 'HR']
arrays = [engineering, marketing, ops, hr]
means  = [a.mean() for a in arrays]

fig, ax = plt.subplots(figsize=(8, 5))
colors = [PRIMARY, GOLD, BLUE, ORANGE]
bars = ax.bar(depts, [m / 1000 for m in means], color=colors,
              edgecolor='white', linewidth=1.5)
ax.set_title('Average Salary by Department', fontsize=14,
             fontweight='bold', color=PRIMARY)
ax.set_ylabel('Salary ($ thousands)', fontsize=12)
for bar, val in zip(bars, means):
    ax.text(bar.get_x() + bar.get_width() / 2,
            val / 1000 + 1,
            f'${val/1000:.0f}k', ha='center', va='bottom',
            fontweight='bold', fontsize=11)
plt.tight_layout()
plt.show()
print('Engineering mean: ${:,.0f}'.format(means[0]))
print('This is driven by ONE $2,000,000 executive salary.')
print('No typical engineer earns anywhere near this figure.')

# %% [markdown]
# <div style="background-color: #E8F5E9; border-left: 4px solid #388E3C; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #388E3C; margin-top: 0;">Demo 2 (Corrected) — Box Plot Revealing the Full Distribution + Median</h3><p style="color: #333; margin-bottom: 0;">Switching to a box plot (or showing both mean and median) immediately exposes the outlier and gives a realistic picture of what a typical employee earns.</p></div>

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 6))

# Left — box plot
ax = axes[0]
bp = ax.boxplot(
    [a / 1000 for a in arrays],
    labels=depts, patch_artist=True,
    medianprops=dict(color=GOLD, linewidth=2.5),
    flierprops=dict(marker='o', color=RED, alpha=0.6, markersize=7)
)
for patch, c in zip(bp['boxes'], colors):
    patch.set_facecolor(c)
    patch.set_alpha(0.7)
ax.set_title('Salary Distribution by Department\n(Box Plot)', fontsize=13,
             fontweight='bold', color=PRIMARY)
ax.set_ylabel('Salary ($ thousands)', fontsize=12)
ax.tick_params(axis='x', rotation=15)
ax.annotate('CTO outlier\n$2 M', xy=(1, 2000), xytext=(1.5, 1800),
            arrowprops=dict(arrowstyle='->', color=RED),
            color=RED, fontsize=10, fontweight='bold')

# Right — mean vs median comparison
ax2 = axes[1]
medians = [np.median(a) / 1000 for a in arrays]
x       = np.arange(len(depts))
w       = 0.35
b1 = ax2.bar(x - w/2, [m / 1000 for m in means],  width=w,
             label='Mean',   color=RED,   alpha=0.8, edgecolor='white')
b2 = ax2.bar(x + w/2, medians, width=w,
             label='Median', color=GREEN, alpha=0.8, edgecolor='white')
ax2.set_xticks(x)
ax2.set_xticklabels(depts, rotation=15)
ax2.set_title('Mean vs Median Salary by Department', fontsize=13,
              fontweight='bold', color=PRIMARY)
ax2.set_ylabel('Salary ($ thousands)', fontsize=12)
ax2.legend(fontsize=11)
ax2.annotate(
    'Mean inflated\nby outlier',
    xy=(0 - w/2, means[0] / 1000),
    xytext=(1.0, means[0] / 1000 + 20),
    arrowprops=dict(arrowstyle='->', color=RED, lw=1.5),
    color=RED, fontsize=9, fontweight='bold'
)

plt.suptitle('Honest view: box plot and median resist outlier distortion',
             fontsize=13, fontweight='bold', color=GREEN, y=1.01)
plt.tight_layout()
plt.show()
print('Engineering MEDIAN salary: ${:,.0f}  (vs MEAN: ${:,.0f})'.format(
    np.median(engineering), engineering.mean()))
print('The median is a far better summary of a typical engineer\'s pay.')

# %% [markdown]
# <div style="background-color: #E3F2FD; border-left: 4px solid #1976D2; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #1976D2; margin-top: 0;">Demo 3 — Scatter Plot Implying Causality: Ice Cream Sales vs Drowning Deaths</h3><p style="color: #333; margin-bottom: 0;">Both variables rise in summer. The correlation is real — but <strong>neither causes the other</strong>. The confounding variable is <em>ambient temperature / season</em>, which independently drives both ice cream consumption and swimming activity.</p></div>

# %%
np.random.seed(21)

# Confound: temperature index (0 = winter, 1 = summer)
months  = np.arange(1, 13)
temp    = np.sin((months - 3) * np.pi / 6) * 0.5 + 0.5   # 0..1 seasonal wave

ice_cream = 100 + 300 * temp + np.random.normal(0, 20, 12)
drownings =  10 +  50 * temp + np.random.normal(0,  4, 12)

r, p = stats.pearsonr(ice_cream, drownings)

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Left — deceptive scatter
ax = axes[0]
ax.scatter(ice_cream, drownings, color=PRIMARY, s=80, zorder=3)
m_slope, m_int, *_ = stats.linregress(ice_cream, drownings)
x_line = np.linspace(ice_cream.min(), ice_cream.max(), 200)
ax.plot(x_line, m_slope * x_line + m_int, color=RED, linewidth=2,
        label=f'r = {r:.2f}, p = {p:.3f}')
ax.set_xlabel('Ice Cream Sales (units / month)', fontsize=11)
ax.set_ylabel('Drowning Deaths per Month', fontsize=11)
ax.set_title('"Ice Cream Causes Drowning?"\nDeceptive framing', fontsize=13,
             fontweight='bold', color=RED)
ax.legend(fontsize=10)
ax.text(0.05, 0.93, 'Strong positive correlation!',
        transform=ax.transAxes, color=RED, fontsize=10, style='italic')

# Right — honest version showing confounder
ax2 = axes[1]
sc = ax2.scatter(ice_cream, drownings, c=temp, cmap='RdPu', s=100,
                 zorder=3, edgecolors='#444', linewidths=0.5)
cbar = plt.colorbar(sc, ax=ax2)
cbar.set_label('Temperature Index (0=cold, 1=hot)', fontsize=10)
for i, m in enumerate(months):
    import calendar
    ax2.annotate(calendar.month_abbr[m],
                 (ice_cream[i], drownings[i]),
                 textcoords='offset points', xytext=(5, 4), fontsize=8)
ax2.set_xlabel('Ice Cream Sales (units / month)', fontsize=11)
ax2.set_ylabel('Drowning Deaths per Month', fontsize=11)
ax2.set_title('Honest framing: colour reveals the\nconfounding variable (temperature)',
              fontsize=13, fontweight='bold', color=GREEN)
ax2.text(0.05, 0.93,
         'Both variables are driven by summer heat,\nnot by each other.',
         transform=ax2.transAxes, color='#333', fontsize=9, style='italic')

plt.suptitle('Correlation does NOT imply causation', fontsize=14,
             fontweight='bold', color=PRIMARY, y=1.01)
plt.tight_layout()
plt.show()
print(f'Pearson r = {r:.3f}  (p = {p:.4f}) — strong correlation, zero causal link.')

# %% [markdown]
# <div style="background-color: #E3F2FD; border-left: 4px solid #1976D2; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #1976D2; margin-top: 0;">Demo 4 — Bar Chart Hiding Overlapping Confidence Intervals</h3><p style="color: #333; margin-bottom: 0;">Two bars that <em>look</em> different in height can have completely overlapping 95% confidence intervals, meaning the difference is not statistically significant. Omitting error bars is one of the most common ways to manufacture apparent differences.</p></div>

# %%
np.random.seed(3)

n_a, n_b = 30, 30
group_a  = np.random.normal(52, 18, n_a)
group_b  = np.random.normal(58, 20, n_b)

mean_a, se_a = group_a.mean(), stats.sem(group_a)
mean_b, se_b = group_b.mean(), stats.sem(group_b)
ci_a = stats.t.interval(0.95, df=n_a-1, loc=mean_a, scale=se_a)
ci_b = stats.t.interval(0.95, df=n_b-1, loc=mean_b, scale=se_b)

fig, axes = plt.subplots(1, 2, figsize=(11, 5))

# Bad — no error bars
ax = axes[0]
ax.bar(['Group A', 'Group B'], [mean_a, mean_b],
       color=[LAVENDER, PRIMARY], width=0.5, edgecolor='white')
ax.set_title('"Group B scores higher!"\n(No uncertainty shown)', fontsize=13,
             fontweight='bold', color=RED)
ax.set_ylabel('Score', fontsize=12)
ax.set_ylim(0, 80)
for x, val in enumerate([mean_a, mean_b]):
    ax.text(x, val + 0.8, f'{val:.1f}', ha='center', fontweight='bold', fontsize=12)

# Good — with 95% CI
ax2 = axes[1]
errs  = [[mean_a - ci_a[0], mean_b - ci_b[0]],
          [ci_a[1] - mean_a, ci_b[1] - mean_b]]
ax2.bar(['Group A', 'Group B'], [mean_a, mean_b],
        color=[LAVENDER, PRIMARY], width=0.5, edgecolor='white',
        yerr=errs, capsize=9,
        error_kw=dict(ecolor='#333', lw=2, capthick=2))
ax2.set_title('With 95% Confidence Intervals\n(Overlap is visible)', fontsize=13,
              fontweight='bold', color=GREEN)
ax2.set_ylabel('Score', fontsize=12)
ax2.set_ylim(0, 80)
ax2.text(0.5, 0.07,
         f'CIs overlap — difference NOT significant\n'
         f'(A: [{ci_a[0]:.1f}, {ci_a[1]:.1f}]  B: [{ci_b[0]:.1f}, {ci_b[1]:.1f}])',
         ha='center', transform=ax2.transAxes, fontsize=9.5,
         color='#555', style='italic')

plt.suptitle('Error bars prevent false conclusions about group differences',
             fontsize=13, fontweight='bold', color=PRIMARY, y=1.01)
plt.tight_layout()
plt.show()
t_stat, p_val = stats.ttest_ind(group_a, group_b)
print(f't-test: t = {t_stat:.3f},  p = {p_val:.3f}  — NOT significant at alpha=0.05')

# %% [markdown]
# <div style="background-color: #E3F2FD; border-left: 4px solid #1976D2; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #1976D2; margin-top: 0;">Demo 5 — Cherry-Picked Monthly Trend vs Full Year</h3><p style="color: #333; margin-bottom: 0;">Selecting just three months that happen to rise creates a convincing growth narrative. Showing the full 12 months reveals the trend is flat (or even slightly negative).</p></div>

# %%
np.random.seed(99)

import calendar
months_full = np.arange(1, 13)
month_names = [calendar.month_abbr[m] for m in months_full]

# Flat trend with noise — but months 4,5,6 happen to rise
revenue = 100 + np.array([2, -5, 1, 3, 8, 12, -4, -7, 2, -3, 1, -2],
                          dtype=float) + np.random.normal(0, 1.5, 12)

cherry = [3, 4, 5]   # 0-indexed: Apr, May, Jun
cherry_names = [month_names[i] for i in cherry]
cherry_vals  = revenue[cherry]

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Bad — cherry-picked
ax = axes[0]
ax.plot(cherry_names, cherry_vals, 'o-', color=RED,
        linewidth=2.5, markersize=9)
slope_c, int_c, *_ = stats.linregress([0, 1, 2], cherry_vals)
ax.plot(cherry_names,
        [slope_c * i + int_c for i in range(3)],
        '--', color=ORANGE, linewidth=2, label='"Trend" line')
ax.set_title('"Consistent Monthly Growth!"\n(3 months cherry-picked)',
             fontsize=13, fontweight='bold', color=RED)
ax.set_ylabel('Revenue Index', fontsize=12)
ax.legend(fontsize=10)
ax.set_ylim(90, 125)

# Good — full year
ax2 = axes[1]
ax2.plot(month_names, revenue, 'o-', color=PRIMARY,
         linewidth=2, markersize=7, label='Monthly revenue')
slope_f, int_f, *_ = stats.linregress(months_full, revenue)
ax2.plot(month_names,
         slope_f * months_full + int_f,
         '--', color=TAN, linewidth=2, label=f'Full-year trend (slope={slope_f:.2f})')
for i in cherry:
    ax2.scatter(month_names[i], revenue[i], color=RED, s=120, zorder=5)
ax2.set_title('Full Year: No Real Trend\n(Cherry-picked months highlighted in red)',
              fontsize=13, fontweight='bold', color=GREEN)
ax2.set_ylabel('Revenue Index', fontsize=12)
ax2.tick_params(axis='x', rotation=40)
ax2.legend(fontsize=9)
ax2.set_ylim(85, 125)

plt.suptitle('Cherry-picking creates growth where none exists',
             fontsize=13, fontweight='bold', color=PRIMARY, y=1.01)
plt.tight_layout()
plt.show()
print(f'Full-year trend slope: {slope_f:.3f} — essentially flat.')

# %% [markdown]
# <div style="background-color: #E3F2FD; border-left: 4px solid #1976D2; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #1976D2; margin-top: 0;">Demo 6 — Fake Trend from a Small Sample (n = 5)</h3><p style="color: #333; margin-bottom: 0;">A regression line through only 5 data points can look compelling in a polished chart. But the confidence band is enormous — reflecting near-total uncertainty about the true relationship. Showing the band honestly communicates how little we know.</p></div>

# %%
np.random.seed(5)

n_small = 5
x_s  = np.array([1, 2, 3, 4, 5], dtype=float)
y_s  = x_s * 1.5 + np.random.normal(0, 3, n_small)

slope_s, int_s, r_s, p_s, se_s = stats.linregress(x_s, y_s)

x_pred = np.linspace(0.5, 5.5, 200)
y_pred = slope_s * x_pred + int_s

# Prediction interval
n = len(x_s)
t_crit = stats.t.ppf(0.975, df=n-2)
x_mean = x_s.mean()
SSx    = ((x_s - x_mean)**2).sum()
residuals = y_s - (slope_s * x_s + int_s)
MSE    = (residuals**2).sum() / (n - 2)
se_pred = np.sqrt(MSE * (1/n + (x_pred - x_mean)**2 / SSx))
ci_low  = y_pred - t_crit * se_pred
ci_high = y_pred + t_crit * se_pred

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Bad — line only
ax = axes[0]
ax.scatter(x_s, y_s, color=PRIMARY, s=110, zorder=4)
ax.plot(x_pred, y_pred, color=RED, linewidth=2.5,
        label=f'Trend: y = {slope_s:.2f}x + {int_s:.2f}')
ax.set_title('"Clear Upward Trend!"\n(n = 5, no uncertainty shown)',
             fontsize=13, fontweight='bold', color=RED)
ax.set_xlabel('X', fontsize=12)
ax.set_ylabel('Y', fontsize=12)
ax.legend(fontsize=10)

# Good — with confidence band
ax2 = axes[1]
ax2.scatter(x_s, y_s, color=PRIMARY, s=110, zorder=4, label='Data (n=5)')
ax2.plot(x_pred, y_pred, color=RED, linewidth=2.5,
         label=f'y = {slope_s:.2f}x + {int_s:.2f}')
ax2.fill_between(x_pred, ci_low, ci_high,
                 alpha=0.25, color=LAVENDER, label='95% prediction interval')
ax2.set_title('Honest: 95% Prediction Interval\nShows Massive Uncertainty',
              fontsize=13, fontweight='bold', color=GREEN)
ax2.set_xlabel('X', fontsize=12)
ax2.set_ylabel('Y', fontsize=12)
ax2.legend(fontsize=9)
ax2.text(0.05, 0.06,
         f'r² = {r_s**2:.2f},  p = {p_s:.3f}  — uncertain with only 5 points',
         transform=ax2.transAxes, fontsize=9.5, color='#555', style='italic')

plt.suptitle('Small samples produce wide uncertainty — never hide it',
             fontsize=13, fontweight='bold', color=PRIMARY, y=1.01)
plt.tight_layout()
plt.show()
print(f'n=5 regression: slope={slope_s:.2f},  r²={r_s**2:.3f},  p={p_s:.3f}')
print('Even a significant p-value here is unreliable with only 5 observations.')

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);"><h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">D. Exercises</h1><p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Apply what you have learned to spot, explain, and redesign deceptive visualisations</p></div>

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #F57C00; margin-top: 0;">Exercise 13 — Relative vs Absolute: Spot the Deception</h3></div>
#
# **Context:** A startup's A/B test shows a "500% increase in conversions" when comparing a new landing page (variant B) against the control (variant A).
#
# The code below generates the deceptive bar chart. Study it carefully — then answer the questions and redesign the plot.
#
# **Deceptive data (do not modify):**
#
# | Group | Visitors | Conversions | Rate |
# |-------|----------|-------------|------|
# | Control A | 10,000 | 1 | 0.01% |
# | Variant B | 10,000 | 6 | 0.06% |
#
# The headline: **"500% increase in conversions — Variant B wins!"**

# %%
# ── Exercise 13 starter code — run this to see the deceptive chart ──────────
visitors_a, conv_a = 10_000, 1
visitors_b, conv_b = 10_000, 6

rel_increase = (conv_b - conv_a) / conv_a * 100   # 500%

fig, ax = plt.subplots(figsize=(5, 5))
ax.bar(['Control A', 'Variant B'], [conv_a, conv_b],
       color=[LAVENDER, PRIMARY], width=0.5, edgecolor='white', linewidth=1.5)
ax.set_title(f'"Conversions up {rel_increase:.0f}%!\nVariant B is the winner!"',
             fontsize=13, fontweight='bold', color=RED)
ax.set_ylabel('Conversions', fontsize=12)
ax.set_ylim(0, 8)
for x, val in enumerate([conv_a, conv_b]):
    ax.text(x, val + 0.15, str(val), ha='center',
            fontweight='bold', fontsize=14)
plt.tight_layout()
plt.show()
print(f'Relative increase: {rel_increase:.0f}%')
print(f'Absolute increase: {conv_b - conv_a} conversions out of {visitors_a:,} visitors')

# %% [markdown]
# 🎯 **Task:**
#
# 1. Identify **three specific things** this chart omits that would change how you interpret the result.
# 2. Calculate the absolute conversion **rate** for both groups and explain whether the difference is practically significant.
# 3. In the code cell below, redesign the chart to show: the conversion rate (not raw count), the sample size, and Wilson 95% confidence intervals. Colour-code bars by group and add annotations.
# 4. State a **plain-language conclusion** a product manager should actually draw from this data.

# %% [markdown]
# *Write your written answer here.*
#
# 1. ___
# 2. ___
# 3. (see code cell below)
# 4. ___

# %%
# Exercise 13 — Your corrected visualisation
# Hint: use statsmodels proportion_confint(count, nobs, method='wilson')
# from statsmodels.stats.proportion import proportion_confint

# --- your code here ---

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have an A/B test result:
#   Control A: 1 conversion out of 10,000 visitors (0.01%)
#   Variant B: 6 conversions out of 10,000 visitors (0.06%)
#
# The headline says "500% increase in conversions".
#
# 1. Is this claim statistically meaningful? Compute the Wilson confidence interval for both rates and interpret the overlap.
# 2. What is the minimum detectable effect and required sample size to reliably detect a real lift of this magnitude (from 0.01% to 0.06%)?
# 3. List three other pieces of context a decision-maker would need before declaring Variant B the winner.
# 4. Rewrite the headline to be accurate, honest, and still useful to a product manager.
# ```

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #F57C00; margin-top: 0;">Exercise 14 — Mean vs Median: Salary Deception</h3></div>
#
# **Context:** A real-estate agency publishes "average home prices by neighbourhood" to attract buyers. One neighbourhood (Lakeview) contains a single billionaire mansion assessed at $45 M. The agency uses the **mean**, which makes Lakeview look like the most expensive neighbourhood by far — deterring middle-income buyers who would actually find it affordable.
#
# The starter code below generates the deceptive bar chart.

# %%
# ── Exercise 14 starter code — run this to see the deceptive chart ──────────
np.random.seed(14)

neighbourhoods = ['Riverside', 'Midtown', 'Lakeview', 'Eastside', 'Old Town']

prices = {
    'Riverside': np.random.normal(380_000,  40_000, 40),
    'Midtown':   np.random.normal(520_000,  55_000, 40),
    'Lakeview':  np.concatenate([np.random.normal(410_000, 35_000, 39),
                                  [45_000_000]]),          # billionaire mansion
    'Eastside':  np.random.normal(295_000,  30_000, 40),
    'Old Town':  np.random.normal(460_000,  50_000, 40),
}

means = {k: v.mean() / 1e6 for k, v in prices.items()}

fig, ax = plt.subplots(figsize=(9, 5))
bar_colors = [PRIMARY, GOLD, RED, BLUE, ORANGE]
ax.bar(list(means.keys()), list(means.values()),
       color=bar_colors, edgecolor='white', linewidth=1.5)
ax.set_title('Average Home Price by Neighbourhood ($M)',
             fontsize=13, fontweight='bold', color=PRIMARY)
ax.set_ylabel('Mean Price ($M)', fontsize=12)
for i, (k, v) in enumerate(means.items()):
    ax.text(i, v + 0.02, f'${v:.2f}M', ha='center',
            fontweight='bold', fontsize=10)
plt.tight_layout()
plt.show()
print('Lakeview mean: ${:,.0f}  |  Lakeview median: ${:,.0f}'.format(
    prices['Lakeview'].mean(), np.median(prices['Lakeview'])))

# %% [markdown]
# 🎯 **Task:**
#
# 1. Explain precisely why the mean is a misleading summary for Lakeview's home prices.
# 2. Compute the **median** and **IQR** for each neighbourhood and compare them with the means.
# 3. In the code cell below, create a side-by-side figure:
#    - **Left panel:** a box plot for all five neighbourhoods (use a log-scaled y-axis to handle the outlier).
#    - **Right panel:** a grouped bar chart showing both mean (red) and median (green) per neighbourhood.
# 4. Write one sentence explaining which statistic a middle-income buyer should rely on, and why.

# %% [markdown]
# *Write your written answer here.*
#
# 1. ___
# 2. ___
# 3. (see code cell below)
# 4. ___

# %%
# Exercise 14 — Your corrected visualisation
# Hint: use ax.set_yscale('log') for the box plot panel
# and annotate the outlier explicitly

# --- your code here ---

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# A real-estate agency reports "average home prices by neighbourhood".
# One neighbourhood (Lakeview) has 39 homes priced around $410,000
# plus one billionaire mansion at $45,000,000.
#
# 1. Compute the mean and median for Lakeview. Explain the numerical difference.
# 2. Why is the mean a statistically inappropriate summary here? Reference skewness and the influence of outliers.
# 3. What visualisation would be most honest for a potential buyer? Justify your choice.
# 4. A journalist writes: "Lakeview is the most expensive neighbourhood to buy in." Is this claim accurate? What nuance is being omitted?
# 5. Propose a corrected one-sentence description the agency should use instead.
# ```

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;"><h3 style="color: #F57C00; margin-top: 0;">Exercise 15 — Correlation vs Causation: The Full Story</h3></div>
#
# **Context:** A popular online article claims: *"Countries that eat more cheese per capita win more Nobel Prizes — proof that dairy boosts intellectual performance."* A scatter plot with a regression line is shown as evidence.
#
# The starter code below replicates this scatter plot. Your task is to redesign it to be statistically honest.

# %%
# ── Exercise 15 starter code — run this to see the deceptive chart ──────────
np.random.seed(15)

# Simulate 25 countries
n_countries = 25
country_labels = [
    'Norway','Sweden','Switzerland','Denmark','Germany','France',
    'Netherlands','Austria','Belgium','UK','Finland','Iceland',
    'Canada','Australia','USA','Japan','Israel','Ireland',
    'Hungary','Poland','Greece','Spain','Portugal','Brazil','India'
]

# GDP per capita is the true confounder
gdp_index = np.random.uniform(0.2, 1.0, n_countries)

# Both cheese consumption and Nobel prizes are driven by GDP (wealth)
cheese_kg    = 5  + 20 * gdp_index + np.random.normal(0, 2, n_countries)
nobel_per_10m = 0 + 12 * gdp_index + np.random.normal(0, 1.5, n_countries)
nobel_per_10m = np.clip(nobel_per_10m, 0, None)

slope_d, int_d, r_d, p_d, _ = stats.linregress(cheese_kg, nobel_per_10m)

fig, ax = plt.subplots(figsize=(7, 6))
ax.scatter(cheese_kg, nobel_per_10m, color=PRIMARY, s=80, zorder=3)
x_line = np.linspace(cheese_kg.min()-1, cheese_kg.max()+1, 200)
ax.plot(x_line, slope_d * x_line + int_d,
        color=RED, linewidth=2.5,
        label=f'r = {r_d:.2f},  p = {p_d:.4f}')
ax.set_xlabel('Cheese Consumption (kg per capita / year)', fontsize=11)
ax.set_ylabel('Nobel Prizes per 10M population', fontsize=11)
ax.set_title('"Cheese Consumption Predicts Nobel Prizes!"',
             fontsize=13, fontweight='bold', color=RED)
ax.legend(fontsize=10)
# Label a few countries
for i, name in enumerate(country_labels[:8]):
    ax.annotate(name, (cheese_kg[i], nobel_per_10m[i]),
                textcoords='offset points', xytext=(5, 3), fontsize=7.5)
plt.tight_layout()
plt.show()
print(f'r = {r_d:.3f},  r² = {r_d**2:.3f},  p = {p_d:.4f}')
print('The article concludes: "Eat more cheese, win more Nobel Prizes."')

# %% [markdown]
# 🎯 **Task:**
#
# 1. Identify the likely **confounding variable** (it is embedded in the data generation above). Explain the causal pathway from the confounder to both cheese consumption and Nobel prizes.
# 2. In the code cell below, redesign the scatter plot to:
#    - **Color each point** by the `gdp_index` (use a sequential colormap and add a colorbar).
#    - **Annotate** all 25 country labels.
#    - **Add a text box** (use `ax.text` with `bbox`) stating clearly: *"Correlation: r = X.XX — Confounded by GDP / wealth. Do NOT interpret as causal."*
#    - **Add residual annotations**: compute the residuals from the regression line and annotate the three countries with the largest residuals (absolute value).
# 3. Show a second figure: a 1×2 panel showing (left) cheese vs GDP_index and (right) Nobel prizes vs GDP_index. Both should have their own regression lines. This illustrates that GDP drives both variables independently.
# 4. Write a corrected 2–3 sentence paragraph that honestly describes what the data show.

# %% [markdown]
# *Write your written answer here.*
#
# 1. ___
# 2. (see code cell below)
# 3. (see code cell below)
# 4. ___

# %%
# Exercise 15 — Your corrected visualisation
# Variables available: cheese_kg, nobel_per_10m, gdp_index, country_labels
# slope_d, int_d already computed above

# --- your code here ---

# %% [markdown]
# 💬 **LLM Prompt**
#
# ```
# I have cross-country data showing a strong positive correlation
# between cheese consumption (kg per capita) and Nobel prizes won
# (per 10M population), r = 0.87, p < 0.001.
#
# 1. Explain, step by step, why this correlation does NOT imply causation.
# 2. Identify the most plausible confounding variable and describe the causal
#    pathway: confound → cheese AND confound → Nobel prizes.
# 3. What statistical technique could partial out the confound and give a
#    cleaner estimate of any direct cheese-Nobel relationship?
# 4. Design a headline and one-paragraph summary that accurately represents
#    this finding for a general audience — honest but still engaging.
# 5. Give two real-world examples from published research where a similar
#    spurious correlation led to a misleading public health or policy claim.
# ```

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 10px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h2 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">End of Module 5</h2>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.2em; margin: 10px 0; font-weight: 300;">Every chart tells a story. Make sure yours tells the truth.</p>
# </div>
